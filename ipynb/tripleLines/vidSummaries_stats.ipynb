# %% [markdown]
# # statistical analysis of metrics

# %% [markdown]
# Leanne Friedrich 10/08/21

# %% [markdown]
# ## initialization

# %%
# %load_ext autoreload
# %autoreload 2
LOGGERDEFINED = False

# %%
import os
import sys
sys.path.append("../")
from py.config import cfg
import py.logs as logs
import py.metrics as me
from printVals import *
from plainIm import plainIm
import matplotlib.pyplot as plt
import metricPlots as mp
import regression as rg
import matplotlib.cm as cm
LOGGERDEFINED = logs.openLog('vidSummaries.ipynb', LOGGERDEFINED, level='DEBUG', exportLog=False)

# %% [markdown]
# ## analyzing data

# %%
ss,u = me.importStillsSummary(diag=True)
seg, useg = me.importStillsSummary(file='segmentsSummary.csv', diag=False)
ss = ss.merge(seg[['folder', 'horiz_segments']], on='folder', suffixes=['', '_manual'], how='left')
# Out:
# Independents: ['folder', 'fullpath', 'bn', 'date', 'sigma', 'di', 'do', 'fluFile', 'calibFile', 'viscRatio', 'vRatio', 'ReRatio', 'rGrav', 'dEst', 'hDragP', 'vDragP', 'int_CaInv', 'int_Re', 'pressureCh0', 'ink_shortname', 'ink_days', 'ink_rheModifier', 'ink_surfactant', 'ink_dye', 'ink_var', 'ink_val', 'ink_base', 'ink_type', 'ink_tau0', 'ink_eta0', 'ink_density', 'ink_v', 'ink_rate', 'ink_visc0', 'ink_CaInv', 'ink_Re', 'ink_WeInv', 'ink_OhInv', 'ink_dPR', 'ink_dnormInv', 'ink_Bm', 'sup_shortname', 'sup_days', 'sup_rheModifier', 'sup_surfactant', 'sup_dye', 'sup_var', 'sup_val', 'sup_base', 'sup_type', 'sup_tau0', 'sup_eta0', 'sup_density', 'sup_v', 'sup_rate', 'sup_visc0', 'sup_CaInv', 'sup_Re', 'sup_WeInv', 'sup_OhInv', 'sup_dPR', 'sup_dnormInv', 'sup_Bm', 'sup_Ca', 'ink_Ca', 'sweepType', 'sup_dnorm', 'ink_dnorm', 'sup_We', 'ink_We', 'sup_Oh', 'ink_Oh', 'int_Ca']
#
# Dependents: ['xs_aspect', 'xs_xshift', 'xs_yshift', 'xs_area', 'xs_areaN', 'xs_wN', 'xs_hN', 'xs_roughness', 'vert_wN', 'vert_hN', 'vert_vN', 'vert_vintegral', 'vert_viN', 'vert_vleak', 'vert_vleakN', 'vert_roughness', 'vert_meanTN', 'vert_stdevTN', 'vert_minmaxTN', 'horiz_segments', 'horiz_maxlenN', 'horiz_totlenN', 'horiz_vN', 'horiz_roughness', 'horiz_meanTN', 'horiz_stdevTN', 'horiz_minmaxTN', 'vHorizEst']

# %%
vs,uv = me.importStillsSummary(file='videoSummary.csv', diag=True)
seg, useg = me.importStillsSummary(file='segmentsSummary.csv', diag=False)
vs = vs.merge(seg[['folder', 'wetting', 'horiz_segments']], on='folder', suffixes=['', ''], how='left')
# Out:
# Independents: ['folder', 'fullpath', 'bn', 'date', 'sigma', 'di', 'do', 'fluFile', 'calibFile', 'viscRatio', 'vRatio', 'ReRatio', 'rGrav', 'dEst', 'hDragP', 'vDragP', 'int_CaInv', 'int_Re', 'pressureCh0', 'ink_shortname', 'ink_days', 'ink_rheModifier', 'ink_surfactant', 'ink_dye', 'ink_var', 'ink_val', 'ink_base', 'ink_type', 'ink_tau0', 'ink_eta0', 'ink_density', 'ink_v', 'ink_rate', 'ink_visc0', 'ink_CaInv', 'ink_Re', 'ink_WeInv', 'ink_OhInv', 'ink_dPR', 'ink_dnormInv', 'ink_Bm', 'sup_shortname', 'sup_days', 'sup_rheModifier', 'sup_surfactant', 'sup_dye', 'sup_var', 'sup_val', 'sup_base', 'sup_type', 'sup_tau0', 'sup_eta0', 'sup_density', 'sup_v', 'sup_rate', 'sup_visc0', 'sup_CaInv', 'sup_Re', 'sup_WeInv', 'sup_OhInv', 'sup_dPR', 'sup_dnormInv', 'sup_Bm', 'sup_Ca', 'ink_Ca', 'sweepType', 'sup_dnorm', 'ink_dnorm', 'sup_We', 'ink_We', 'sup_Oh', 'ink_Oh', 'int_Ca']
#
# Dependents: ['projectionN', 'projShiftN', 'vertDispBotN', 'vertDispTopN', 'vertDispMidN']

# %%
ss.sup_Re.min(), ss.sup_Re.max(), ss.ink_Re.min(), ss.ink_Re.max()
# Out:
# (0.0001979461612272, 0.212537061977812, 0.000100528466527, 0.1041090553958053)

# %% [markdown]
# ## regression tables

# %%
xsregs = mp.regressionTable(ss, 'xs_aspect', nickname = 'cross-section aspect ratio', logy=True, printOut=True, export=True)
varlist = [('vert_meanTN', 'normalized vertical line thickness'), 
           ('vert_hN', 'normalized vertical line length')]
vertregs = [mp.regressionTable(ss, i[0], nickname=i[1], logy=False, export=True, printOut=True) for i in varlist]
varlist = [('horiz_totlenN', 'normalized horizontal line total length', False),
           ('horiz_maxlenN', 'normalized horizontal line max segment length', False),
          ('horiz_segments_manual', 'number of horizontal line segments', False),
           ('horiz_roughness', 'horizontal line roughness', False)]
horizregs = [mp.regressionTable(ss, i[0], nickname=i[1], export=True, printOut=True, logy=i[2]) for i in varlist]
mp.regressionTable(vs, 'projectionN', nickname='projection into bath', export=True, printOut=True, logy=False)
# Out:
# \begin{filecontents*}{xsaspectRegNonZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $\bm{Ca}$,$\bm{0.36}$,0.09,0.14,$\bm{0.67}$,$\bm{3.8e-27}$
# $Ca_{ink}$,0.03,0.03,0.14,0.21,2.3e-03
# $Ca_{sup}$,0.30,0.08,0.13,0.58,7.9e-20
# $Ca_{ink}\times Ca_{sup}$,0.18,0.04,0.15,0.52,3.9e-15
# $Ca_{ink}/Ca_{sup}$,0.13,-0.05,0.10,-0.38,2.6e-08
# $\overline{d_{PR.ink}}$,0.04,0.03,0.16,0.25,4.6e-04
# $\bm{\overline{d_{PR.sup}}}$,$\bm{0.26}$,0.04,0.19,$\bm{0.68}$,$\bm{1.2e-28}$
# $\bm{\overline{d_{PR.ink}}\times \overline{d_{PR.sup}}}$,$\bm{0.28}$,0.04,0.25,$\bm{0.63}$,$\bm{1.6e-23}$
# $\overline{d_{PR.ink}}/\overline{d_{PR.sup}}$,0.11,-0.02,0.12,-0.38,3.2e-08
# $We_{ink}$,0.05,0.03,0.21,0.22,1.9e-03
# $We_{sup}$,0.01,0.01,0.15,0.11,1.3e-01
# $We_{ink}\times We_{sup}$,0.02,0.01,0.18,0.20,5.3e-03
# $We_{ink}/We_{sup}$,0.08,0.08,0.14,0.09,2.1e-01
# $Oh_{ink}$,0.01,0.02,0.10,0.09,1.8e-01
# $\bm{Oh_{sup}}$,$\bm{0.29}$,0.09,0.01,$\bm{0.63}$,$\bm{3.1e-23}$
# $Oh_{ink}\times Oh_{sup}$,0.23,0.06,-0.02,0.52,1.3e-15
# $Oh_{ink}/Oh_{sup}$,0.18,-0.06,0.10,-0.51,1.0e-14
# $Re_{ink}$,0.01,0.03,0.19,0.11,1.1e-01
# $Re_{sup}$,0.15,-0.05,-0.01,-0.40,2.7e-09
# $Re_{ink}\times Re_{sup}$,0.06,-0.03,-0.01,-0.27,8.9e-05
# $\bm{Re_{ink}/Re_{sup}}$,$\bm{0.21}$,0.06,0.11,$\bm{0.56}$,$\bm{1.2e-17}$
# $Bm_{ink}$,0.00,0.03,0.15,0.06,4.0e-01
# $Bm_{sup}$,0.10,0.04,0.18,0.36,1.1e-07
# $Bm_{ink}\times Bm_{sup}$,0.11,0.05,0.24,0.34,8.1e-07
# $Bm_{ink}/Bm_{sup}$,0.08,-0.04,0.13,-0.34,9.7e-07
# $\eta_{ink}$,0.00,-0.02,0.12,-0.10,1.4e-01
# $\eta_{sup}$,0.15,0.05,0.10,0.39,6.8e-09
# $\eta_{ink}\times \eta_{sup}$,0.08,0.03,0.11,0.29,3.5e-05
# $\bm{\eta_{ink}/\eta_{sup}}$,$\bm{0.18}$,-0.06,0.10,$\bm{-0.51}$,$\bm{1.6e-14}$
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{xsaspectRegNonZero.csv}\tabxsaspectRegNonZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\xsaspectRegNonZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for cross-section aspect ratio at nonzero surface tension.]{Table of linear regressions of log-scaled x and y variables and Spearman rank correlations for \textbf{cross-section aspect ratio} at nonzero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $y = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4[+1]}{before row=\hline}
# ]\tabxsaspectRegNonZero
# \label{tab:xsaspectRegNonZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\xsaspectRegNonZero.tex
# ---------------------------
#
#
# \begin{filecontents*}{xsaspectRegZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $Re_{ink}$,0.28,0.16,0.69,0.52,2.4e-09
# $Re_{sup}$,0.19,-0.13,-0.08,-0.47,7.0e-08
# $Re_{ink}\times Re_{sup}$,0.00,0.01,0.30,0.03,7.1e-01
# $\bm{Re_{ink}/Re_{sup}}$,$\bm{0.61}$,0.19,0.27,$\bm{0.76}$,$\bm{1.2e-23}$
# $\bm{Bm_{ink}}$,$\bm{0.14}$,-0.14,0.07,$\bm{-0.69}$,$\bm{8.6e-18}$
# $Bm_{sup}$,0.11,0.15,0.44,0.58,5.9e-12
# $Bm_{ink}\times Bm_{sup}$,0.01,-0.02,0.20,0.30,1.0e-03
# $\bm{Bm_{ink}/Bm_{sup}}$,$\bm{0.26}$,-0.15,0.24,$\bm{-0.75}$,$\bm{4.7e-22}$
# $\eta_{ink}$,0.34,-0.26,0.34,-0.59,2.6e-12
# $\eta_{sup}$,0.24,0.20,0.18,0.54,5.1e-10
# $\eta_{ink}\times \eta_{sup}$,0.00,-0.01,0.26,-0.02,8.0e-01
# $\bm{\eta_{ink}/\eta_{sup}}$,$\bm{0.59}$,-0.23,0.24,$\bm{-0.77}$,$\bm{5.4e-24}$
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{xsaspectRegZero.csv}\tabxsaspectRegZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\xsaspectRegZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for cross-section aspect ratio in water/Laponite inks.]{Table of linear regressions of log-scaled x and y variables and Spearman rank correlations for \textbf{cross-section aspect ratio} in water/Laponite inks. For example, ${Re}_{ink}$ indicates a regression fit to $y = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4}{before row=\hline}
# ]\tabxsaspectRegZero
# \label{tab:xsaspectRegZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\xsaspectRegZero.tex
# ---------------------------
#
#
# \begin{filecontents*}{vertmeanTNRegNonZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $\bm{Ca}$,$\bm{0.66}$,-0.52,1.18,$\bm{-0.84}$,$\bm{5.4e-51}$
# $Ca_{ink}$,0.05,-0.16,1.19,-0.21,4.8e-03
# $\bm{Ca_{sup}}$,$\bm{0.61}$,-0.51,1.18,$\bm{-0.79}$,$\bm{2.4e-41}$
# $Ca_{ink}\times Ca_{sup}$,0.37,-0.24,1.10,-0.62,1.4e-20
# $Ca_{ink}/Ca_{sup}$,0.32,0.36,1.39,0.55,3.6e-16
# $\overline{d_{PR.ink}}$,0.06,-0.15,1.03,-0.26,4.2e-04
# $\bm{\overline{d_{PR.sup}}}$,$\bm{0.62}$,-0.28,0.77,$\bm{-0.88}$,$\bm{4.8e-60}$
# $\bm{\overline{d_{PR.ink}}\times \overline{d_{PR.sup}}}$,$\bm{0.64}$,-0.25,0.44,$\bm{-0.84}$,$\bm{9.0e-51}$
# $\overline{d_{PR.ink}}/\overline{d_{PR.sup}}$,0.30,0.17,1.24,0.51,2.5e-13
# $We_{ink}$,0.04,-0.12,0.92,-0.13,7.5e-02
# $We_{sup}$,0.01,-0.06,1.10,-0.17,2.1e-02
# $We_{ink}\times We_{sup}$,0.02,-0.05,1.00,-0.17,2.2e-02
# $We_{ink}/We_{sup}$,0.05,-0.37,1.19,0.05,4.9e-01
# $Oh_{ink}$,0.03,-0.21,1.48,-0.19,1.2e-02
# $\bm{Oh_{sup}}$,$\bm{0.63}$,-0.57,1.95,$\bm{-0.85}$,$\bm{2.8e-52}$
# $Oh_{ink}\times Oh_{sup}$,0.56,-0.44,2.22,-0.76,2.0e-35
# $Oh_{ink}/Oh_{sup}$,0.36,0.38,1.35,0.62,6.7e-21
# $Re_{ink}$,0.00,0.00,1.28,0.01,8.6e-01
# $Re_{sup}$,0.36,0.35,2.16,0.56,1.7e-16
# $Re_{ink}\times Re_{sup}$,0.22,0.21,2.33,0.45,2.1e-10
# $\bm{Re_{ink}/Re_{sup}}$,$\bm{0.37}$,-0.37,1.31,$\bm{-0.64}$,$\bm{2.2e-22}$
# $Bm_{ink}$,0.03,-0.53,0.69,-0.20,7.5e-03
# $Bm_{sup}$,0.34,-0.36,0.76,-0.54,3.0e-15
# $\bm{Bm_{ink}\times Bm_{sup}}$,$\bm{0.41}$,-0.41,0.22,$\bm{-0.61}$,$\bm{2.7e-20}$
# $Bm_{ink}/Bm_{sup}$,0.25,0.29,1.18,0.42,3.4e-09
# $\eta_{ink}$,0.00,-0.06,1.27,-0.01,8.9e-01
# $\bm{\eta_{sup}}$,$\bm{0.36}$,-0.37,1.37,$\bm{-0.56}$,$\bm{8.2e-17}$
# $\eta_{ink}\times \eta_{sup}$,0.26,-0.26,1.32,-0.46,2.9e-11
# $\bm{\eta_{ink}/\eta_{sup}}$,$\bm{0.36}$,0.38,1.40,$\bm{0.62}$,$\bm{9.9e-21}$
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{vertmeanTNRegNonZero.csv}\tabvertmeanTNRegNonZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\vertmeanTNRegNonZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized vertical line thickness at nonzero surface tension.]{Table of linear regressions of log-scaled x variables and Spearman rank correlations for \textbf{normalized vertical line thickness} at nonzero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $y = b*log_{10}(Re_{ink}) + c$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4[+1]}{before row=\hline}
# ]\tabvertmeanTNRegNonZero
# \label{tab:vertmeanTNRegNonZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\vertmeanTNRegNonZero.tex
# ---------------------------
#
#
# \begin{filecontents*}{vertmeanTNRegZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $Re_{ink}$,0.00,0.01,0.83,0.04,7.1e-01
# $Re_{sup}$,0.03,0.07,1.00,0.26,3.1e-02
# $Re_{ink}\times Re_{sup}$,0.02,0.03,0.99,0.22,7.0e-02
# $Re_{ink}/Re_{sup}$,0.01,-0.04,0.81,-0.12,3.3e-01
# $Bm_{ink}$,0.07,0.11,0.96,-0.20,1.1e-01
# $Bm_{sup}$,0.00,0.02,0.83,-0.10,3.9e-01
# $Bm_{ink}\times Bm_{sup}$,0.05,0.07,0.98,0.06,6.4e-01
# $Bm_{ink}/Bm_{sup}$,0.04,0.07,0.83,0.14,2.4e-01
# $\eta_{ink}$,0.01,0.04,0.79,-0.01,9.1e-01
# $\eta_{sup}$,0.02,-0.07,0.85,-0.23,6.0e-02
# $\eta_{ink}\times \eta_{sup}$,0.00,-0.02,0.82,-0.13,3.0e-01
# $\eta_{ink}/\eta_{sup}$,0.02,0.06,0.82,0.16,1.9e-01
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{vertmeanTNRegZero.csv}\tabvertmeanTNRegZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\vertmeanTNRegZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized vertical line thickness in water/Laponite inks.]{Table of linear regressions of log-scaled x variables and Spearman rank correlations for \textbf{normalized vertical line thickness} in water/Laponite inks. For example, ${Re}_{ink}$ indicates a regression fit to $y = b*log_{10}(Re_{ink}) + c$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4}{before row=\hline}
# ]\tabvertmeanTNRegZero
# \label{tab:vertmeanTNRegZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\vertmeanTNRegZero.tex
# ---------------------------
#
#
# \begin{filecontents*}{verthNRegNonZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $\bm{Ca}$,$\bm{0.69}$,0.40,0.65,$\bm{0.87}$,$\bm{4.2e-57}$
# $Ca_{ink}$,0.05,0.12,0.64,0.20,7.8e-03
# $\bm{Ca_{sup}}$,$\bm{0.59}$,0.38,0.65,$\bm{0.80}$,$\bm{1.2e-42}$
# $Ca_{ink}\times Ca_{sup}$,0.36,0.18,0.70,0.62,4.4e-21
# $Ca_{ink}/Ca_{sup}$,0.31,-0.27,0.49,-0.56,1.3e-16
# $\overline{d_{PR.ink}}$,0.06,0.11,0.76,0.26,4.7e-04
# $\bm{\overline{d_{PR.sup}}}$,$\bm{0.52}$,0.20,0.93,$\bm{0.85}$,$\bm{1.0e-52}$
# $\bm{\overline{d_{PR.ink}}\times \overline{d_{PR.sup}}}$,$\bm{0.55}$,0.17,1.16,$\bm{0.81}$,$\bm{1.6e-44}$
# $\overline{d_{PR.ink}}/\overline{d_{PR.sup}}$,0.25,-0.12,0.60,-0.50,9.0e-13
# $We_{ink}$,0.07,0.12,0.95,0.20,6.3e-03
# $We_{sup}$,0.02,0.06,0.74,0.20,6.5e-03
# $We_{ink}\times We_{sup}$,0.04,0.05,0.85,0.21,3.4e-03
# $We_{ink}/We_{sup}$,0.12,0.43,0.67,-0.03,6.4e-01
# $Oh_{ink}$,0.01,0.10,0.48,0.13,7.0e-02
# $\bm{Oh_{sup}}$,$\bm{0.59}$,0.42,0.08,$\bm{0.83}$,$\bm{1.0e-47}$
# $Oh_{ink}\times Oh_{sup}$,0.47,0.31,-0.09,0.71,2.8e-29
# $Oh_{ink}/Oh_{sup}$,0.38,-0.29,0.51,-0.65,1.5e-23
# $Re_{ink}$,0.02,0.10,0.83,0.12,1.1e-01
# $Re_{sup}$,0.31,-0.25,-0.06,-0.53,1.5e-14
# $Re_{ink}\times Re_{sup}$,0.15,-0.13,-0.09,-0.37,1.9e-07
# $\bm{Re_{ink}/Re_{sup}}$,$\bm{0.42}$,0.30,0.54,$\bm{0.68}$,$\bm{1.6e-26}$
# $Bm_{ink}$,0.01,0.22,0.82,0.14,5.2e-02
# $Bm_{sup}$,0.22,0.22,0.90,0.47,2.4e-11
# $\bm{Bm_{ink}\times Bm_{sup}}$,$\bm{0.26}$,0.25,1.21,$\bm{0.51}$,$\bm{9.0e-14}$
# $Bm_{ink}/Bm_{sup}$,0.18,-0.18,0.64,-0.39,4.0e-08
# $\eta_{ink}$,0.01,-0.12,0.57,-0.12,9.5e-02
# $\eta_{sup}$,0.29,0.25,0.51,0.52,3.9e-14
# $\eta_{ink}\times \eta_{sup}$,0.16,0.16,0.55,0.38,1.2e-07
# $\bm{\eta_{ink}/\eta_{sup}}$,$\bm{0.38}$,-0.29,0.48,$\bm{-0.65}$,$\bm{1.9e-23}$
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{verthNRegNonZero.csv}\tabverthNRegNonZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\verthNRegNonZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized vertical line length at nonzero surface tension.]{Table of linear regressions of log-scaled x variables and Spearman rank correlations for \textbf{normalized vertical line length} at nonzero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $y = b*log_{10}(Re_{ink}) + c$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4[+1]}{before row=\hline}
# ]\tabverthNRegNonZero
# \label{tab:verthNRegNonZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\verthNRegNonZero.tex
# ---------------------------
#
#
# \begin{filecontents*}{verthNRegZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $Re_{ink}$,0.04,0.09,1.29,0.20,9.5e-02
# $Re_{sup}$,0.11,-0.15,0.63,-0.35,3.2e-03
# $Re_{ink}\times Re_{sup}$,0.01,-0.03,0.90,-0.09,4.7e-01
# $Re_{ink}/Re_{sup}$,0.16,0.14,1.04,0.45,9.6e-05
# $Bm_{ink}$,0.06,-0.11,0.91,0.07,5.5e-01
# $Bm_{sup}$,0.03,-0.10,0.94,-0.22,7.2e-02
# $Bm_{ink}\times Bm_{sup}$,0.08,-0.09,0.82,-0.19,1.2e-01
# $Bm_{ink}/Bm_{sup}$,0.01,-0.03,1.04,-0.08,4.9e-01
# $\eta_{ink}$,0.09,-0.19,1.11,-0.27,2.4e-02
# $\eta_{sup}$,0.03,0.09,1.01,0.27,2.3e-02
# $\eta_{ink}\times \eta_{sup}$,0.01,-0.04,1.08,0.00,9.8e-01
# $\eta_{ink}/\eta_{sup}$,0.11,-0.14,1.02,-0.40,5.1e-04
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{verthNRegZero.csv}\tabverthNRegZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\verthNRegZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized vertical line length in water/Laponite inks.]{Table of linear regressions of log-scaled x variables and Spearman rank correlations for \textbf{normalized vertical line length} in water/Laponite inks. For example, ${Re}_{ink}$ indicates a regression fit to $y = b*log_{10}(Re_{ink}) + c$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4}{before row=\hline}
# ]\tabverthNRegZero
# \label{tab:verthNRegZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\verthNRegZero.tex
# ---------------------------
#
#
# \begin{filecontents*}{horiztotlenNRegNonZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $\bm{Ca}$,$\bm{0.73}$,0.36,0.75,$\bm{0.90}$,$\bm{1.3e-53}$
# $Ca_{ink}$,0.04,0.10,0.72,0.17,3.9e-02
# $Ca_{sup}$,0.55,0.33,0.75,0.80,4.4e-33
# $Ca_{ink}\times Ca_{sup}$,0.40,0.19,0.83,0.66,8.5e-20
# $Ca_{ink}/Ca_{sup}$,0.23,-0.18,0.58,-0.45,9.5e-09
# $\overline{d_{PR.ink}}$,0.06,0.11,0.84,0.30,2.3e-04
# $\bm{\overline{d_{PR.sup}}}$,$\bm{0.48}$,0.15,0.92,$\bm{0.82}$,$\bm{1.8e-36}$
# $\bm{\overline{d_{PR.ink}}\times \overline{d_{PR.sup}}}$,$\bm{0.61}$,0.16,1.24,$\bm{0.84}$,$\bm{2.5e-39}$
# $\overline{d_{PR.ink}}/\overline{d_{PR.sup}}$,0.22,-0.09,0.65,-0.48,1.3e-09
# $We_{ink}$,0.07,0.11,0.98,0.22,8.3e-03
# $We_{sup}$,0.00,-0.01,0.63,-0.03,7.6e-01
# $We_{ink}\times We_{sup}$,0.02,0.03,0.81,0.09,2.6e-01
# $We_{ink}/We_{sup}$,0.22,0.33,0.72,0.25,2.4e-03
# $Oh_{ink}$,0.00,0.04,0.61,0.03,6.8e-01
# $\bm{Oh_{sup}}$,$\bm{0.54}$,0.32,0.28,$\bm{0.77}$,$\bm{3.0e-30}$
# $Oh_{ink}\times Oh_{sup}$,0.45,0.25,0.13,0.65,3.3e-19
# $Oh_{ink}/Oh_{sup}$,0.35,-0.22,0.59,-0.66,7.4e-20
# $Re_{ink}$,0.02,0.08,0.85,0.17,3.5e-02
# $Re_{sup}$,0.34,-0.20,0.13,-0.59,7.2e-15
# $Re_{ink}\times Re_{sup}$,0.15,-0.10,0.13,-0.39,9.2e-07
# $\bm{Re_{ink}/Re_{sup}}$,$\bm{0.44}$,0.22,0.61,$\bm{0.72}$,$\bm{2.5e-24}$
# $Bm_{ink}$,0.00,0.05,0.71,0.01,8.9e-01
# $Bm_{sup}$,0.23,0.18,0.88,0.44,3.0e-08
# $Bm_{ink}\times Bm_{sup}$,0.25,0.19,1.12,0.44,2.0e-08
# $Bm_{ink}/Bm_{sup}$,0.19,-0.15,0.68,-0.45,9.3e-09
# $\eta_{ink}$,0.01,-0.07,0.64,-0.13,1.1e-01
# $\eta_{sup}$,0.31,0.20,0.58,0.58,9.5e-15
# $\eta_{ink}\times \eta_{sup}$,0.19,0.13,0.61,0.42,1.4e-07
# $\bm{\eta_{ink}/\eta_{sup}}$,$\bm{0.35}$,-0.22,0.57,$\bm{-0.66}$,$\bm{1.7e-19}$
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{horiztotlenNRegNonZero.csv}\tabhoriztotlenNRegNonZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\horiztotlenNRegNonZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized horizontal line total length at nonzero surface tension.]{Table of linear regressions of log-scaled x variables and Spearman rank correlations for \textbf{normalized horizontal line total length} at nonzero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $y = b*log_{10}(Re_{ink}) + c$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4[+1]}{before row=\hline}
# ]\tabhoriztotlenNRegNonZero
# \label{tab:horiztotlenNRegNonZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\horiztotlenNRegNonZero.tex
# ---------------------------
#
#
# \begin{filecontents*}{horiztotlenNRegZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $Re_{ink}$,0.02,-0.04,0.90,-0.06,5.2e-01
# $Re_{sup}$,0.01,-0.03,0.92,-0.14,1.4e-01
# $Re_{ink}\times Re_{sup}$,0.03,-0.03,0.85,-0.08,4.0e-01
# $Re_{ink}/Re_{sup}$,0.00,-0.01,1.00,0.04,6.6e-01
# $Bm_{ink}$,0.00,-0.01,0.99,0.21,2.6e-02
# $Bm_{sup}$,0.11,-0.13,0.85,-0.34,2.3e-04
# $Bm_{ink}\times Bm_{sup}$,0.05,-0.05,0.87,-0.27,4.9e-03
# $Bm_{ink}/Bm_{sup}$,0.04,0.05,1.01,0.21,2.7e-02
# $\eta_{ink}$,0.00,0.01,1.00,-0.01,8.9e-01
# $\eta_{sup}$,0.01,-0.03,1.02,0.04,6.6e-01
# $\eta_{ink}\times \eta_{sup}$,0.00,-0.01,1.01,-0.04,6.6e-01
# $\eta_{ink}/\eta_{sup}$,0.01,0.02,1.00,-0.02,8.0e-01
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{horiztotlenNRegZero.csv}\tabhoriztotlenNRegZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\horiztotlenNRegZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized horizontal line total length in water/Laponite inks.]{Table of linear regressions of log-scaled x variables and Spearman rank correlations for \textbf{normalized horizontal line total length} in water/Laponite inks. For example, ${Re}_{ink}$ indicates a regression fit to $y = b*log_{10}(Re_{ink}) + c$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4}{before row=\hline}
# ]\tabhoriztotlenNRegZero
# \label{tab:horiztotlenNRegZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\horiztotlenNRegZero.tex
# ---------------------------
#
#
# \begin{filecontents*}{horizmaxlenNRegNonZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $\bm{Ca}$,$\bm{0.66}$,0.40,0.71,$\bm{0.87}$,$\bm{6.6e-47}$
# $Ca_{ink}$,0.08,0.17,0.71,0.30,2.2e-04
# $Ca_{sup}$,0.47,0.35,0.70,0.74,4.4e-27
# $Ca_{ink}\times Ca_{sup}$,0.41,0.23,0.81,0.68,1.6e-21
# $Ca_{ink}/Ca_{sup}$,0.13,-0.16,0.53,-0.31,1.3e-04
# $\overline{d_{PR.ink}}$,0.12,0.17,0.90,0.43,5.8e-08
# $\bm{\overline{d_{PR.sup}}}$,$\bm{0.38}$,0.16,0.88,$\bm{0.76}$,$\bm{2.0e-28}$
# $\bm{\overline{d_{PR.ink}}\times \overline{d_{PR.sup}}}$,$\bm{0.57}$,0.19,1.26,$\bm{0.83}$,$\bm{7.8e-39}$
# $\overline{d_{PR.ink}}/\overline{d_{PR.sup}}$,0.14,-0.08,0.59,-0.34,2.5e-05
# $We_{ink}$,0.09,0.14,1.04,0.25,2.2e-03
# $We_{sup}$,0.00,-0.01,0.56,-0.05,5.5e-01
# $We_{ink}\times We_{sup}$,0.02,0.04,0.80,0.10,2.2e-01
# $We_{ink}/We_{sup}$,0.30,0.45,0.69,0.35,1.6e-05
# $Oh_{ink}$,0.02,0.13,0.47,0.14,8.3e-02
# $\bm{Oh_{sup}}$,$\bm{0.47}$,0.35,0.19,$\bm{0.72}$,$\bm{1.2e-24}$
# $\bm{Oh_{ink}\times Oh_{sup}}$,$\bm{0.45}$,0.30,-0.02,$\bm{0.66}$,$\bm{1.2e-19}$
# $Oh_{ink}/Oh_{sup}$,0.25,-0.22,0.53,-0.56,2.2e-13
# $Re_{ink}$,0.01,0.06,0.74,0.11,1.9e-01
# $Re_{sup}$,0.30,-0.22,0.02,-0.54,1.7e-12
# $Re_{ink}\times Re_{sup}$,0.15,-0.12,-0.02,-0.38,2.2e-06
# $\bm{Re_{ink}/Re_{sup}}$,$\bm{0.35}$,0.24,0.55,$\bm{0.64}$,$\bm{3.1e-18}$
# $Bm_{ink}$,0.01,0.15,0.75,0.07,3.8e-01
# $Bm_{sup}$,0.16,0.17,0.82,0.34,3.2e-05
# $Bm_{ink}\times Bm_{sup}$,0.18,0.19,1.07,0.36,8.2e-06
# $Bm_{ink}/Bm_{sup}$,0.13,-0.14,0.62,-0.35,1.5e-05
# $\eta_{ink}$,0.00,-0.01,0.59,-0.04,6.1e-01
# $\bm{\eta_{sup}}$,$\bm{0.25}$,0.22,0.52,$\bm{0.52}$,$\bm{1.9e-11}$
# $\eta_{ink}\times \eta_{sup}$,0.17,0.15,0.55,0.40,5.3e-07
# $\bm{\eta_{ink}/\eta_{sup}}$,$\bm{0.25}$,-0.21,0.51,$\bm{-0.55}$,$\bm{4.8e-13}$
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{horizmaxlenNRegNonZero.csv}\tabhorizmaxlenNRegNonZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\horizmaxlenNRegNonZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized horizontal line max segment length at nonzero surface tension.]{Table of linear regressions of log-scaled x variables and Spearman rank correlations for \textbf{normalized horizontal line max segment length} at nonzero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $y = b*log_{10}(Re_{ink}) + c$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4[+1]}{before row=\hline}
# ]\tabhorizmaxlenNRegNonZero
# \label{tab:horizmaxlenNRegNonZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\horizmaxlenNRegNonZero.tex
# ---------------------------
#
#
# \begin{filecontents*}{horizmaxlenNRegZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $Re_{ink}$,0.03,-0.04,0.87,-0.08,4.0e-01
# $Re_{sup}$,0.01,-0.02,0.93,-0.12,2.0e-01
# $Re_{ink}\times Re_{sup}$,0.03,-0.03,0.84,-0.08,3.8e-01
# $Re_{ink}/Re_{sup}$,0.01,-0.02,0.99,0.02,8.4e-01
# $Bm_{ink}$,0.00,0.01,1.00,0.23,1.5e-02
# $Bm_{sup}$,0.12,-0.13,0.83,-0.36,1.0e-04
# $Bm_{ink}\times Bm_{sup}$,0.04,-0.05,0.87,-0.26,6.7e-03
# $Bm_{ink}/Bm_{sup}$,0.06,0.06,1.00,0.23,1.4e-02
# $\eta_{ink}$,0.01,0.03,0.98,0.01,9.0e-01
# $\eta_{sup}$,0.01,-0.04,1.01,0.02,8.1e-01
# $\eta_{ink}\times \eta_{sup}$,0.00,-0.01,1.00,-0.03,7.2e-01
# $\eta_{ink}/\eta_{sup}$,0.02,0.04,1.00,0.00,9.6e-01
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{horizmaxlenNRegZero.csv}\tabhorizmaxlenNRegZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\horizmaxlenNRegZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized horizontal line max segment length in water/Laponite inks.]{Table of linear regressions of log-scaled x variables and Spearman rank correlations for \textbf{normalized horizontal line max segment length} in water/Laponite inks. For example, ${Re}_{ink}$ indicates a regression fit to $y = b*log_{10}(Re_{ink}) + c$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4}{before row=\hline}
# ]\tabhorizmaxlenNRegZero
# \label{tab:horizmaxlenNRegZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\horizmaxlenNRegZero.tex
# ---------------------------
#
#
# \begin{filecontents*}{horizsegmentsmanualRegNonZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $Ca$,0.07,-2.50,4.86,-0.47,2.9e-10
# $\bm{Ca_{ink}}$,$\bm{0.11}$,-3.63,3.35,$\bm{-0.61}$,$\bm{2.3e-18}$
# $Ca_{sup}$,0.01,-0.93,5.19,-0.37,1.2e-06
# $\bm{Ca_{ink}\times Ca_{sup}}$,$\bm{0.07}$,-1.61,4.13,$\bm{-0.55}$,$\bm{1.5e-14}$
# $Ca_{ink}/Ca_{sup}$,0.04,-1.88,4.74,-0.25,1.5e-03
# $\bm{\overline{d_{PR.ink}}}$,$\bm{0.16}$,-3.55,-0.57,$\bm{-0.68}$,$\bm{1.0e-23}$
# $\overline{d_{PR.sup}}$,0.00,-0.05,5.31,-0.28,2.3e-04
# $\overline{d_{PR.ink}}\times \overline{d_{PR.sup}}$,0.05,-1.03,1.83,-0.51,3.9e-12
# $\overline{d_{PR.ink}}/\overline{d_{PR.sup}}$,0.04,-0.84,5.47,-0.23,3.1e-03
# $We_{ink}$,0.06,-2.20,-1.22,-0.31,4.3e-05
# $We_{sup}$,0.01,0.71,7.37,-0.07,3.9e-01
# $We_{ink}\times We_{sup}$,0.01,-0.38,3.17,-0.18,1.9e-02
# $We_{ink}/We_{sup}$,0.41,-11.32,2.87,-0.39,2.5e-07
# $\bm{Oh_{ink}}$,$\bm{0.09}$,-5.06,10.16,$\bm{-0.51}$,$\bm{3.7e-12}$
# $Oh_{sup}$,0.02,-1.55,7.21,-0.29,1.6e-04
# $Oh_{ink}\times Oh_{sup}$,0.08,-2.54,10.78,-0.46,4.3e-10
# $Oh_{ink}/Oh_{sup}$,0.00,-0.36,5.31,-0.04,6.0e-01
# $Re_{ink}$,0.00,1.03,7.90,0.16,4.4e-02
# $Re_{sup}$,0.02,1.29,8.70,0.12,1.3e-01
# $Re_{ink}\times Re_{sup}$,0.02,0.99,10.37,0.14,7.2e-02
# $Re_{ink}/Re_{sup}$,0.01,-0.94,5.51,-0.07,3.4e-01
# $Bm_{ink}$,0.02,-5.85,-1.14,-0.36,2.2e-06
# $Bm_{sup}$,0.02,1.33,7.22,0.15,5.9e-02
# $Bm_{ink}\times Bm_{sup}$,0.01,1.14,8.25,0.06,4.8e-01
# $Bm_{ink}/Bm_{sup}$,0.03,-1.36,5.75,-0.18,2.0e-02
# $\eta_{ink}$,0.02,-2.70,5.20,-0.22,4.8e-03
# $\eta_{sup}$,0.00,-0.18,5.44,-0.04,5.7e-01
# $\eta_{ink}\times \eta_{sup}$,0.00,-0.53,5.50,-0.11,1.8e-01
# $\eta_{ink}/\eta_{sup}$,0.00,-0.39,5.26,-0.05,5.5e-01
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{horizsegmentsmanualRegNonZero.csv}\tabhorizsegmentsmanualRegNonZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\horizsegmentsmanualRegNonZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for number of horizontal line segments at nonzero surface tension.]{Table of linear regressions of log-scaled x variables and Spearman rank correlations for \textbf{number of horizontal line segments} at nonzero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $y = b*log_{10}(Re_{ink}) + c$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4[+1]}{before row=\hline}
# ]\tabhorizsegmentsmanualRegNonZero
# \label{tab:horizsegmentsmanualRegNonZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\horizsegmentsmanualRegNonZero.tex
# ---------------------------
#
#
# INFO: All horiz_segments_manual values the same for zero surface tension
# ---------------------------
#
#
# \begin{filecontents*}{horizroughnessRegNonZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $\bm{Ca}$,$\bm{0.00}$,0.00,0.01,$\bm{0.68}$,$\bm{3.7e-21}$
# $Ca_{ink}$,0.00,0.00,0.01,-0.05,5.5e-01
# $Ca_{sup}$,0.00,0.00,0.01,0.56,3.3e-13
# $Ca_{ink}\times Ca_{sup}$,0.00,0.00,0.01,0.43,5.3e-08
# $Ca_{ink}/Ca_{sup}$,0.00,-0.00,0.01,-0.52,1.1e-11
# $\overline{d_{PR.ink}}$,0.01,0.00,0.01,0.06,4.8e-01
# $\bm{\overline{d_{PR.sup}}}$,$\bm{0.00}$,0.00,0.01,$\bm{0.69}$,$\bm{2.5e-22}$
# $\overline{d_{PR.ink}}\times \overline{d_{PR.sup}}$,0.01,0.00,0.01,0.59,2.7e-15
# $\overline{d_{PR.ink}}/\overline{d_{PR.sup}}$,0.00,-0.00,0.01,-0.57,5.1e-14
# $We_{ink}$,0.00,-0.00,0.00,0.14,9.3e-02
# $We_{sup}$,0.00,-0.00,0.00,-0.08,3.3e-01
# $We_{ink}\times We_{sup}$,0.00,-0.00,0.00,0.05,5.2e-01
# $We_{ink}/We_{sup}$,0.01,0.00,0.01,0.14,9.2e-02
# $Oh_{ink}$,0.01,0.01,0.00,-0.18,3.4e-02
# $Oh_{sup}$,0.01,0.00,0.00,0.63,2.8e-17
# $Oh_{ink}\times Oh_{sup}$,0.01,0.00,-0.00,0.42,1.4e-07
# $\bm{Oh_{ink}/Oh_{sup}}$,$\bm{0.00}$,-0.00,0.01,$\bm{-0.70}$,$\bm{8.7e-23}$
# $Re_{ink}$,0.01,-0.00,-0.00,0.22,6.5e-03
# $Re_{sup}$,0.01,-0.00,-0.00,-0.57,5.7e-14
# $Re_{ink}\times Re_{sup}$,0.01,-0.00,-0.01,-0.35,1.6e-05
# $\bm{Re_{ink}/Re_{sup}}$,$\bm{0.00}$,0.00,0.01,$\bm{0.73}$,$\bm{1.0e-25}$
# $Bm_{ink}$,0.01,0.01,0.02,-0.13,1.2e-01
# $\bm{Bm_{sup}}$,$\bm{0.00}$,0.00,0.01,$\bm{0.52}$,$\bm{1.2e-11}$
# $Bm_{ink}\times Bm_{sup}$,0.01,0.00,0.01,0.46,6.7e-09
# $\bm{Bm_{ink}/Bm_{sup}}$,$\bm{0.00}$,-0.00,0.01,$\bm{-0.54}$,$\bm{2.7e-12}$
# $\eta_{ink}$,0.01,0.01,0.01,-0.17,4.1e-02
# $\eta_{sup}$,0.01,0.00,0.00,0.59,2.5e-15
# $\eta_{ink}\times \eta_{sup}$,0.01,0.00,0.00,0.41,3.6e-07
# $\bm{\eta_{ink}/\eta_{sup}}$,$\bm{0.00}$,-0.00,0.01,$\bm{-0.70}$,$\bm{1.5e-22}$
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{horizroughnessRegNonZero.csv}\tabhorizroughnessRegNonZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\horizroughnessRegNonZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for horizontal line roughness at nonzero surface tension.]{Table of linear regressions of log-scaled x variables and Spearman rank correlations for \textbf{horizontal line roughness} at nonzero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $y = b*log_{10}(Re_{ink}) + c$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4[+1]}{before row=\hline}
# ]\tabhorizroughnessRegNonZero
# \label{tab:horizroughnessRegNonZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\horizroughnessRegNonZero.tex
# ---------------------------
#
#
# \begin{filecontents*}{horizroughnessRegZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $Re_{ink}$,0.07,0.08,0.38,0.26,5.6e-03
# $\bm{Re_{sup}}$,$\bm{0.32}$,-0.18,-0.32,$\bm{-0.64}$,$\bm{1.0e-13}$
# $Re_{ink}\times Re_{sup}$,0.03,-0.04,-0.02,-0.21,3.0e-02
# $\bm{Re_{ink}/Re_{sup}}$,$\bm{0.40}$,0.15,0.17,$\bm{0.69}$,$\bm{1.8e-16}$
# $Bm_{ink}$,0.08,-0.10,0.04,-0.43,3.2e-06
# $\bm{Bm_{sup}}$,$\bm{0.16}$,0.18,0.38,$\bm{0.69}$,$\bm{5.5e-17}$
# $Bm_{ink}\times Bm_{sup}$,0.00,0.01,0.19,0.49,5.8e-08
# $\bm{Bm_{ink}/Bm_{sup}}$,$\bm{0.24}$,-0.14,0.16,$\bm{-0.73}$,$\bm{2.9e-19}$
# $\eta_{ink}$,0.14,-0.16,0.22,-0.39,3.4e-05
# $\bm{\eta_{sup}}$,$\bm{0.37}$,0.25,0.06,$\bm{0.72}$,$\bm{8.4e-19}$
# $\eta_{ink}\times \eta_{sup}$,0.03,0.05,0.13,0.19,4.8e-02
# $\bm{\eta_{ink}/\eta_{sup}}$,$\bm{0.48}$,-0.20,0.15,$\bm{-0.78}$,$\bm{4.3e-23}$
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{horizroughnessRegZero.csv}\tabhorizroughnessRegZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\horizroughnessRegZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for horizontal line roughness in water/Laponite inks.]{Table of linear regressions of log-scaled x variables and Spearman rank correlations for \textbf{horizontal line roughness} in water/Laponite inks. For example, ${Re}_{ink}$ indicates a regression fit to $y = b*log_{10}(Re_{ink}) + c$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4}{before row=\hline}
# ]\tabhorizroughnessRegZero
# \label{tab:horizroughnessRegZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\horizroughnessRegZero.tex
# ---------------------------
#
#
# \begin{filecontents*}{projectionNRegNonZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $Ca$,0.10,0.12,-0.59,0.34,5.6e-07
# $Ca_{ink}$,0.22,-0.20,-0.72,-0.45,9.8e-12
# $Ca_{sup}$,0.08,0.11,-0.59,0.25,2.3e-04
# $Ca_{ink}\times Ca_{sup}$,0.01,-0.02,-0.63,-0.06,3.8e-01
# $\bm{Ca_{ink}/Ca_{sup}}$,$\bm{0.49}$,-0.27,-0.70,$\bm{-0.70}$,$\bm{8.6e-32}$
# $\overline{d_{PR.ink}}$,0.22,-0.17,-0.89,-0.41,1.4e-09
# $\overline{d_{PR.sup}}$,0.26,0.11,-0.42,0.52,1.9e-15
# $\overline{d_{PR.ink}}\times \overline{d_{PR.sup}}$,0.04,0.04,-0.48,0.22,1.2e-03
# $\bm{\overline{d_{PR.ink}}/\overline{d_{PR.sup}}}$,$\bm{0.45}$,-0.12,-0.59,$\bm{-0.68}$,$\bm{3.5e-29}$
# $We_{ink}$,0.08,-0.10,-0.92,-0.12,7.9e-02
# $We_{sup}$,0.12,-0.13,-0.96,-0.17,1.4e-02
# $We_{ink}\times We_{sup}$,0.11,-0.06,-0.96,-0.12,8.8e-02
# $We_{ink}/We_{sup}$,0.03,0.14,-0.58,-0.08,2.5e-01
# $Oh_{ink}$,0.25,-0.35,-0.27,-0.54,9.0e-17
# $Oh_{sup}$,0.27,0.22,-0.87,0.49,5.7e-14
# $Oh_{ink}\times Oh_{sup}$,0.03,0.06,-0.74,0.13,6.4e-02
# $\bm{Oh_{ink}/Oh_{sup}}$,$\bm{0.53}$,-0.27,-0.67,$\bm{-0.78}$,$\bm{1.0e-42}$
# $Re_{ink}$,0.05,0.14,-0.26,0.34,7.6e-07
# $Re_{sup}$,0.34,-0.20,-1.13,-0.54,5.2e-17
# $Re_{ink}\times Re_{sup}$,0.14,-0.10,-1.12,-0.28,4.0e-05
# $\bm{Re_{ink}/Re_{sup}}$,$\bm{0.52}$,0.25,-0.64,$\bm{0.77}$,$\bm{3.9e-41}$
# $Bm_{ink}$,0.16,-0.72,-1.40,-0.45,1.2e-11
# $Bm_{sup}$,0.33,0.21,-0.31,0.52,1.3e-15
# $Bm_{ink}\times Bm_{sup}$,0.26,0.19,-0.13,0.43,1.7e-10
# $\bm{Bm_{ink}/Bm_{sup}}$,$\bm{0.38}$,-0.21,-0.55,$\bm{-0.60}$,$\bm{2.8e-21}$
# $\eta_{ink}$,0.04,-0.16,-0.62,-0.32,3.1e-06
# $\eta_{sup}$,0.39,0.23,-0.67,0.56,1.4e-18
# $\eta_{ink}\times \eta_{sup}$,0.20,0.14,-0.64,0.33,1.6e-06
# $\bm{\eta_{ink}/\eta_{sup}}$,$\bm{0.53}$,-0.27,-0.71,$\bm{-0.78}$,$\bm{4.8e-43}$
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{projectionNRegNonZero.csv}\tabprojectionNRegNonZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\projectionNRegNonZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for projection into bath at nonzero surface tension.]{Table of linear regressions of log-scaled x variables and Spearman rank correlations for \textbf{projection into bath} at nonzero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $y = b*log_{10}(Re_{ink}) + c$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4[+1]}{before row=\hline}
# ]\tabprojectionNRegNonZero
# \label{tab:projectionNRegNonZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\projectionNRegNonZero.tex
# ---------------------------
#
#
# \begin{filecontents*}{projectionNRegZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $Re_{ink}$,0.08,0.10,-0.20,0.36,9.7e-05
# $Re_{sup}$,0.21,-0.16,-0.88,-0.49,7.2e-08
# $Re_{ink}\times Re_{sup}$,0.01,-0.03,-0.61,-0.07,4.8e-01
# $\bm{Re_{ink}/Re_{sup}}$,$\bm{0.37}$,0.17,-0.46,$\bm{0.68}$,$\bm{1.6e-16}$
# $Bm_{ink}$,0.07,-0.12,-0.62,-0.19,4.2e-02
# $Bm_{sup}$,0.05,0.12,-0.32,0.35,1.7e-04
# $Bm_{ink}\times Bm_{sup}$,0.00,-0.02,-0.52,0.12,2.2e-01
# $Bm_{ink}/Bm_{sup}$,0.13,-0.12,-0.48,-0.48,1.5e-07
# $\eta_{ink}$,0.13,-0.18,-0.41,-0.46,3.7e-07
# $\eta_{sup}$,0.20,0.21,-0.55,0.49,4.4e-08
# $\eta_{ink}\times \eta_{sup}$,0.01,0.03,-0.49,0.02,8.3e-01
# $\bm{\eta_{ink}/\eta_{sup}}$,$\bm{0.33}$,-0.20,-0.48,$\bm{-0.69}$,$\bm{5.6e-17}$
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{projectionNRegZero.csv}\tabprojectionNRegZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\projectionNRegZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for projection into bath in water/Laponite inks.]{Table of linear regressions of log-scaled x variables and Spearman rank correlations for \textbf{projection into bath} in water/Laponite inks. For example, ${Re}_{ink}$ indicates a regression fit to $y = b*log_{10}(Re_{ink}) + c$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4}{before row=\hline}
# ]\tabprojectionNRegZero
# \label{tab:projectionNRegZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\projectionNRegZero.tex
# ---------------------------
# [                                           variables        $r^2$     b     c  \
#  0                                               $Ca$         0.10  0.12 -0.59
#  1                                         $Ca_{ink}$         0.22 -0.20 -0.72
#  2                                         $Ca_{sup}$         0.08  0.11 -0.59
#  3                          $Ca_{ink}\times Ca_{sup}$         0.01 -0.02 -0.63
#  4                           $\bm{Ca_{ink}/Ca_{sup}}$  $\bm{0.49}$ -0.27 -0.70
#  0                            $\overline{d_{PR.ink}}$         0.22 -0.17 -0.89
#  1                            $\overline{d_{PR.sup}}$         0.26  0.11 -0.42
#  2  $\overline{d_{PR.ink}}\times \overline{d_{PR.s...         0.04  0.04 -0.48
#  3  $\bm{\overline{d_{PR.ink}}/\overline{d_{PR.sup...  $\bm{0.45}$ -0.12 -0.59
#  0                                         $We_{ink}$         0.08 -0.10 -0.92
#  1                                         $We_{sup}$         0.12 -0.13 -0.96
#  2                          $We_{ink}\times We_{sup}$         0.11 -0.06 -0.96
#  3                                $We_{ink}/We_{sup}$         0.03  0.14 -0.58
#  0                                         $Oh_{ink}$         0.25 -0.35 -0.27
#  1                                         $Oh_{sup}$         0.27  0.22 -0.87
#  2                          $Oh_{ink}\times Oh_{sup}$         0.03  0.06 -0.74
#  3                           $\bm{Oh_{ink}/Oh_{sup}}$  $\bm{0.53}$ -0.27 -0.67
#  0                                         $Re_{ink}$         0.05  0.14 -0.26
#  1                                         $Re_{sup}$         0.34 -0.20 -1.13
#  2                          $Re_{ink}\times Re_{sup}$         0.14 -0.10 -1.12
#  3                           $\bm{Re_{ink}/Re_{sup}}$  $\bm{0.52}$  0.25 -0.64
#  0                                         $Bm_{ink}$         0.16 -0.72 -1.40
#  1                                         $Bm_{sup}$         0.33  0.21 -0.31
#  2                          $Bm_{ink}\times Bm_{sup}$         0.26  0.19 -0.13
#  3                           $\bm{Bm_{ink}/Bm_{sup}}$  $\bm{0.38}$ -0.21 -0.55
#  0                                       $\eta_{ink}$         0.04 -0.16 -0.62
#  1                                       $\eta_{sup}$         0.39  0.23 -0.67
#  2                      $\eta_{ink}\times \eta_{sup}$         0.20  0.14 -0.64
#  3                       $\bm{\eta_{ink}/\eta_{sup}}$  $\bm{0.53}$ -0.27 -0.71
#
#    Spearman coeff      Spearman p
#  0           0.34         5.6e-07
#  1          -0.45         9.8e-12
#  2           0.25         2.3e-04
#  3          -0.06         3.8e-01
#  4   $\bm{-0.70}$  $\bm{8.6e-32}$
#  0          -0.41         1.4e-09
#  1           0.52         1.9e-15
#  2           0.22         1.2e-03
#  3   $\bm{-0.68}$  $\bm{3.5e-29}$
#  0          -0.12         7.9e-02
#  1          -0.17         1.4e-02
#  2          -0.12         8.8e-02
#  3          -0.08         2.5e-01
#  0          -0.54         9.0e-17
#  1           0.49         5.7e-14
#  2           0.13         6.4e-02
#  3   $\bm{-0.78}$  $\bm{1.0e-42}$
#  0           0.34         7.6e-07
#  1          -0.54         5.2e-17
#  2          -0.28         4.0e-05
#  3    $\bm{0.77}$  $\bm{3.9e-41}$
#  0          -0.45         1.2e-11
#  1           0.52         1.3e-15
#  2           0.43         1.7e-10
#  3   $\bm{-0.60}$  $\bm{2.8e-21}$
#  0          -0.32         3.1e-06
#  1           0.56         1.4e-18
#  2           0.33         1.6e-06
#  3   $\bm{-0.78}$  $\bm{4.8e-43}$  ,
#                         variables        $r^2$     b     c Spearman coeff  \
#  0                     $Re_{ink}$         0.08  0.10 -0.20           0.36
#  1                     $Re_{sup}$         0.21 -0.16 -0.88          -0.49
#  2      $Re_{ink}\times Re_{sup}$         0.01 -0.03 -0.61          -0.07
#  3       $\bm{Re_{ink}/Re_{sup}}$  $\bm{0.37}$  0.17 -0.46    $\bm{0.68}$
#  0                     $Bm_{ink}$         0.07 -0.12 -0.62          -0.19
#  1                     $Bm_{sup}$         0.05  0.12 -0.32           0.35
#  2      $Bm_{ink}\times Bm_{sup}$         0.00 -0.02 -0.52           0.12
#  3            $Bm_{ink}/Bm_{sup}$         0.13 -0.12 -0.48          -0.48
#  0                   $\eta_{ink}$         0.13 -0.18 -0.41          -0.46
#  1                   $\eta_{sup}$         0.20  0.21 -0.55           0.49
#  2  $\eta_{ink}\times \eta_{sup}$         0.01  0.03 -0.49           0.02
#  3   $\bm{\eta_{ink}/\eta_{sup}}$  $\bm{0.33}$ -0.20 -0.48   $\bm{-0.69}$
#
#         Spearman p
#  0         9.7e-05
#  1         7.2e-08
#  2         4.8e-01
#  3  $\bm{1.6e-16}$
#  0         4.2e-02
#  1         1.7e-04
#  2         2.2e-01
#  3         1.5e-07
#  0         3.7e-07
#  1         4.4e-08
#  2         8.3e-01
#  3  $\bm{5.6e-17}$  ]

# %%
mp.regressionTable(vs[vs.wetting==1], 'vertDispBotN', tag='wetting', nickname='bottom position with wetting', export=True, printOut=True, logy=False);
mp.regressionTable(vs[vs.wetting==0], 'vertDispBotN', tag='nonwetting', nickname='bottom position without wetting', export=True, printOut=True, logy=False);
# Out:
# \begin{filecontents*}{vertDispBotNwettingRegNonZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $Ca$,0.16,-0.30,0.58,-0.29,1.3e-02
# $\bm{Ca_{ink}}$,$\bm{0.32}$,-0.51,0.41,$\bm{-0.53}$,$\bm{1.2e-06}$
# $Ca_{sup}$,0.16,-0.30,0.58,-0.29,1.3e-02
# $Ca_{ink}\times Ca_{sup}$,0.28,-0.24,0.49,-0.43,1.7e-04
# $Ca_{ink}/Ca_{sup}$,0.01,-0.09,0.59,-0.22,6.2e-02
# $\bm{\overline{d_{PR.ink}}}$,$\bm{0.32}$,-0.43,-0.01,$\bm{-0.53}$,$\bm{1.8e-06}$
# $\overline{d_{PR.sup}}$,0.11,-0.15,0.36,-0.17,1.6e-01
# $\overline{d_{PR.ink}}\times \overline{d_{PR.sup}}$,0.26,-0.17,0.06,-0.36,2.0e-03
# $\overline{d_{PR.ink}}/\overline{d_{PR.sup}}$,0.00,0.00,0.61,-0.18,1.3e-01
# $We_{ink}$,0.09,-0.24,-0.09,-0.27,2.1e-02
# $We_{sup}$,0.09,-0.22,0.00,-0.20,9.0e-02
# $We_{ink}\times We_{sup}$,0.09,-0.12,-0.04,-0.20,9.1e-02
# $We_{ink}/We_{sup}$,0.08,-6.23,-0.79,-0.38,8.3e-04
# $\bm{Oh_{ink}}$,$\bm{0.52}$,-1.19,1.90,$\bm{-0.60}$,$\bm{2.8e-08}$
# $Oh_{sup}$,0.10,-0.28,0.96,-0.19,1.1e-01
# $Oh_{ink}\times Oh_{sup}$,0.30,-0.38,1.50,-0.37,1.4e-03
# $Oh_{ink}/Oh_{sup}$,0.01,-0.08,0.60,-0.22,6.6e-02
# $Re_{ink}$,0.18,0.76,2.57,0.36,1.6e-03
# $Re_{sup}$,0.01,0.10,0.87,-0.02,8.5e-01
# $Re_{ink}\times Re_{sup}$,0.06,0.15,1.40,0.14,2.3e-01
# $Re_{ink}/Re_{sup}$,0.01,0.08,0.61,0.21,7.2e-02
# $Bm_{ink}$,0.16,-1.71,-1.21,-0.50,7.2e-06
# $Bm_{sup}$,0.03,-0.14,0.41,-0.01,9.4e-01
# $Bm_{ink}\times Bm_{sup}$,0.06,-0.20,0.11,-0.14,2.3e-01
# $Bm_{ink}/Bm_{sup}$,0.01,0.07,0.59,-0.09,4.7e-01
# $\eta_{ink}$,0.18,-0.72,0.61,-0.36,1.9e-03
# $\eta_{sup}$,0.01,-0.10,0.64,0.02,8.5e-01
# $\eta_{ink}\times \eta_{sup}$,0.06,-0.15,0.65,-0.15,2.0e-01
# $\eta_{ink}/\eta_{sup}$,0.01,-0.09,0.59,-0.22,6.2e-02
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{vertDispBotNwettingRegNonZero.csv}\tabvertDispBotNwettingRegNonZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\vertDispBotNwettingRegNonZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for bottom position with wetting at nonzero surface tension.]{Table of linear regressions of log-scaled x variables and Spearman rank correlations for \textbf{bottom position with wetting} at nonzero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $y = b*log_{10}(Re_{ink}) + c$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4[+1]}{before row=\hline}
# ]\tabvertDispBotNwettingRegNonZero
# \label{tab:vertDispBotNwettingRegNonZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\vertDispBotNwettingRegNonZero.tex
# ---------------------------
#
#
# \begin{filecontents*}{vertDispBotNwettingRegZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $Re_{ink}$,0.04,-0.15,0.10,-0.18,1.3e-01
# $Re_{sup}$,0.09,0.22,1.07,0.22,7.8e-02
# $Re_{ink}\times Re_{sup}$,0.01,0.03,0.65,0.02,8.6e-01
# $Re_{ink}/Re_{sup}$,0.20,-0.28,0.52,-0.42,4.1e-04
# $Bm_{ink}$,0.08,-0.21,0.18,-0.01,9.1e-01
# $Bm_{sup}$,0.00,0.02,0.50,0.14,2.7e-01
# $Bm_{ink}\times Bm_{sup}$,0.04,-0.11,0.20,-0.07,5.4e-01
# $Bm_{ink}/Bm_{sup}$,0.07,-0.19,0.42,-0.12,3.2e-01
# $\eta_{ink}$,0.00,0.02,0.47,0.05,6.8e-01
# $\eta_{sup}$,0.04,-0.19,0.57,-0.21,9.4e-02
# $\eta_{ink}\times \eta_{sup}$,0.01,-0.07,0.53,-0.10,4.0e-01
# $\eta_{ink}/\eta_{sup}$,0.04,0.17,0.53,0.25,4.2e-02
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{vertDispBotNwettingRegZero.csv}\tabvertDispBotNwettingRegZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\vertDispBotNwettingRegZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for bottom position with wetting in water/Laponite inks.]{Table of linear regressions of log-scaled x variables and Spearman rank correlations for \textbf{bottom position with wetting} in water/Laponite inks. For example, ${Re}_{ink}$ indicates a regression fit to $y = b*log_{10}(Re_{ink}) + c$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4}{before row=\hline}
# ]\tabvertDispBotNwettingRegZero
# \label{tab:vertDispBotNwettingRegZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\vertDispBotNwettingRegZero.tex
# ---------------------------
#
#
# \begin{filecontents*}{vertDispBotNnonwettingRegNonZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $Ca$,0.00,-0.02,0.20,-0.09,3.5e-01
# $\bm{Ca_{ink}}$,$\bm{0.31}$,-0.32,-0.03,$\bm{-0.62}$,$\bm{2.4e-13}$
# $Ca_{sup}$,0.04,0.11,0.24,0.07,4.7e-01
# $Ca_{ink}\times Ca_{sup}$,0.05,-0.09,0.12,-0.28,2.7e-03
# $\bm{Ca_{ink}/Ca_{sup}}$,$\bm{0.30}$,-0.22,0.11,$\bm{-0.62}$,$\bm{1.6e-13}$
# $\bm{\overline{d_{PR.ink}}}$,$\bm{0.39}$,-0.30,-0.35,$\bm{-0.70}$,$\bm{6.5e-18}$
# $\overline{d_{PR.sup}}$,0.11,0.08,0.36,0.21,2.8e-02
# $\overline{d_{PR.ink}}\times \overline{d_{PR.sup}}$,0.00,-0.00,0.21,-0.11,2.5e-01
# $\overline{d_{PR.ink}}/\overline{d_{PR.sup}}$,0.27,-0.10,0.20,-0.48,6.7e-08
# $We_{ink}$,0.18,-0.19,-0.37,-0.32,5.1e-04
# $We_{sup}$,0.00,-0.00,0.20,0.09,3.3e-01
# $We_{ink}\times We_{sup}$,0.05,-0.05,-0.11,-0.10,2.8e-01
# $\bm{We_{ink}/We_{sup}}$,$\bm{0.39}$,-0.42,0.12,$\bm{-0.57}$,$\bm{3.1e-11}$
# $Oh_{ink}$,0.17,-0.33,0.48,-0.41,5.4e-06
# $Oh_{sup}$,0.04,0.09,0.10,0.22,2.1e-02
# $Oh_{ink}\times Oh_{sup}$,0.00,-0.02,0.26,-0.01,9.0e-01
# $Oh_{ink}/Oh_{sup}$,0.13,-0.14,0.16,-0.29,1.6e-03
# $Re_{ink}$,0.00,0.01,0.24,0.09,3.2e-01
# $Re_{sup}$,0.02,-0.05,0.07,-0.19,3.9e-02
# $Re_{ink}\times Re_{sup}$,0.01,-0.03,0.05,-0.17,7.3e-02
# $Re_{ink}/Re_{sup}$,0.02,0.05,0.20,0.17,6.6e-02
# $Bm_{ink}$,0.03,-0.35,-0.19,-0.23,1.3e-02
# $\bm{Bm_{sup}}$,$\bm{0.22}$,0.19,0.46,$\bm{0.53}$,$\bm{2.0e-09}$
# $Bm_{ink}\times Bm_{sup}$,0.21,0.20,0.71,0.49,3.5e-08
# $Bm_{ink}/Bm_{sup}$,0.21,-0.17,0.24,-0.40,1.3e-05
# $\eta_{ink}$,0.02,-0.13,0.20,-0.14,1.3e-01
# $\eta_{sup}$,0.10,0.13,0.17,0.28,2.6e-03
# $\eta_{ink}\times \eta_{sup}$,0.05,0.08,0.19,0.22,2.1e-02
# $\eta_{ink}/\eta_{sup}$,0.13,-0.14,0.15,-0.30,1.3e-03
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{vertDispBotNnonwettingRegNonZero.csv}\tabvertDispBotNnonwettingRegNonZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\vertDispBotNnonwettingRegNonZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for bottom position without wetting at nonzero surface tension.]{Table of linear regressions of log-scaled x variables and Spearman rank correlations for \textbf{bottom position without wetting} at nonzero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $y = b*log_{10}(Re_{ink}) + c$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4[+1]}{before row=\hline}
# ]\tabvertDispBotNnonwettingRegNonZero
# \label{tab:vertDispBotNnonwettingRegNonZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\vertDispBotNnonwettingRegNonZero.tex
# ---------------------------
#
#
# \begin{filecontents*}{vertDispBotNnonwettingRegZero.csv}
# variables,$r^2$,b,c,Spearman coeff,Spearman p
# $Re_{ink}$,0.06,-0.11,-0.04,-0.26,1.5e-01
# $Re_{sup}$,0.09,0.15,0.62,0.28,1.1e-01
# $Re_{ink}\times Re_{sup}$,0.00,0.01,0.33,-0.08,6.7e-01
# $\bm{Re_{ink}/Re_{sup}}$,$\bm{0.32}$,-0.27,0.10,$\bm{-0.54}$,$\bm{9.3e-04}$
# $Bm_{ink}$,0.01,0.85,1.26,0.35,4.3e-02
# $Bm_{sup}$,0.03,0.13,0.48,-0.18,3.1e-01
# $Bm_{ink}\times Bm_{sup}$,0.03,0.14,0.65,0.03,8.5e-01
# $Bm_{ink}/Bm_{sup}$,0.02,-0.11,0.33,0.36,3.8e-02
# $\eta_{ink}$,0.07,0.24,0.14,0.34,5.0e-02
# $\eta_{sup}$,0.03,-0.13,0.30,-0.21,2.4e-01
# $\eta_{ink}\times \eta_{sup}$,0.00,0.02,0.28,0.11,5.3e-01
# $\eta_{ink}/\eta_{sup}$,0.13,0.26,0.14,0.49,3.4e-03
# \end{filecontents*}
# \pgfplotstableread[col sep=comma]{vertDispBotNnonwettingRegZero.csv}\tabvertDispBotNnonwettingRegZero
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\vertDispBotNnonwettingRegZeroImport.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for bottom position without wetting in water/Laponite inks.]{Table of linear regressions of log-scaled x variables and Spearman rank correlations for \textbf{bottom position without wetting} in water/Laponite inks. For example, ${Re}_{ink}$ indicates a regression fit to $y = b*log_{10}(Re_{ink}) + c$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \pgfplotstabletypeset[
# 	col sep=comma,
# 	string type,
# 	columns/variables/.style={column type=l},
# 	columns/$r^2$/.style={column type=l},
# 	columns/b/.style={column type=l},
# 	columns/c/.style={column type=l},
# 	columns/Spearman coeff/.style={column type=l},
# 	columns/Spearman p/.style={column type=l},
# 	every head row/.style={after row=\hline},
# 	every nth row={4}{before row=\hline}
# ]\tabvertDispBotNnonwettingRegZero
# \label{tab:vertDispBotNnonwettingRegZero}
# \end{table}
#
# -------------
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results/singleLines\regressions\vertDispBotNnonwettingRegZero.tex
# ---------------------------
