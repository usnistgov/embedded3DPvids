# %% [markdown]
# # statistical analysis of metrics

# %% [markdown]
# Leanne Friedrich 10/08/21

# %% [markdown]
# ## initialization

# %%
# %load_ext autoreload
# %autoreload 2
LOGGERDEFINED = False

# %%
import os
import sys
sys.path.append("../")
from py.config import cfg
import py.logs as logs
import py.metrics as me
from printVals import *
from plainIm import plainIm
import matplotlib.pyplot as plt
import metricPlots as mp
import regression as rg
import matplotlib.cm as cm
LOGGERDEFINED = logs.openLog('vidSummaries.ipynb', LOGGERDEFINED, level='DEBUG', exportLog=False)

# %% [markdown]
# ## analyzing data

# %%
ss,u = me.importStillsSummary(diag=True)
seg, useg = me.importStillsSummary(file='segmentsSummary.csv', diag=False)
ss = ss.merge(seg[['folder', 'horiz_segments']], on='folder', suffixes=['', '_manual'])
# Out:
# Independents: ['folder', 'bn', 'date', 'sigma', 'di', 'do', 'fluFile', 'calibFile', 'viscRatio', 'vRatio', 'ReRatio', 'rGrav', 'dEst', 'hDragP', 'vDragP', 'int_CaInv', 'int_Re', 'pressureCh0', 'ink_shortname', 'ink_days', 'ink_rheModifier', 'ink_surfactant', 'ink_dye', 'ink_var', 'ink_val', 'ink_base', 'ink_type', 'ink_tau0', 'ink_eta0', 'ink_density', 'ink_v', 'ink_rate', 'ink_visc0', 'ink_CaInv', 'ink_Re', 'ink_WeInv', 'ink_OhInv', 'ink_dPR', 'ink_dnormInv', 'ink_Bm', 'sup_shortname', 'sup_days', 'sup_rheModifier', 'sup_surfactant', 'sup_dye', 'sup_var', 'sup_val', 'sup_base', 'sup_type', 'sup_tau0', 'sup_eta0', 'sup_density', 'sup_v', 'sup_rate', 'sup_visc0', 'sup_CaInv', 'sup_Re', 'sup_WeInv', 'sup_OhInv', 'sup_dPR', 'sup_dnormInv', 'sup_Bm', 'sup_Ca', 'ink_Ca', 'sweepType', 'sup_dnorm', 'ink_dnorm', 'sup_We', 'ink_We', 'sup_Oh', 'ink_Oh', 'int_Ca']
#
# Dependents: ['xs_aspect', 'xs_xshift', 'xs_yshift', 'xs_area', 'xs_areaN', 'xs_wN', 'xs_hN', 'xs_roughness', 'vert_wN', 'vert_hN', 'vert_vN', 'vert_vintegral', 'vert_viN', 'vert_vleak', 'vert_vleakN', 'vert_roughness', 'vert_meanTN', 'vert_stdevTN', 'vert_minmaxTN', 'horiz_segments', 'horiz_maxlenN', 'horiz_totlenN', 'horiz_vN', 'horiz_roughness', 'horiz_meanTN', 'horiz_stdevTN', 'horiz_minmaxTN', 'vHorizEst']

# %%
vs,uv = me.importStillsSummary(file='videoSummary.csv', diag=True)
# Out:
# Independents: ['folder', 'bn', 'date', 'sigma', 'di', 'do', 'fluFile', 'calibFile', 'viscRatio', 'vRatio', 'ReRatio', 'rGrav', 'dEst', 'hDragP', 'vDragP', 'int_CaInv', 'int_Re', 'pressureCh0', 'ink_shortname', 'ink_days', 'ink_rheModifier', 'ink_surfactant', 'ink_dye', 'ink_var', 'ink_val', 'ink_base', 'ink_type', 'ink_tau0', 'ink_eta0', 'ink_density', 'ink_v', 'ink_rate', 'ink_visc0', 'ink_CaInv', 'ink_Re', 'ink_WeInv', 'ink_OhInv', 'ink_dPR', 'ink_dnormInv', 'ink_Bm', 'sup_shortname', 'sup_days', 'sup_rheModifier', 'sup_surfactant', 'sup_dye', 'sup_var', 'sup_val', 'sup_base', 'sup_type', 'sup_tau0', 'sup_eta0', 'sup_density', 'sup_v', 'sup_rate', 'sup_visc0', 'sup_CaInv', 'sup_Re', 'sup_WeInv', 'sup_OhInv', 'sup_dPR', 'sup_dnormInv', 'sup_Bm', 'sup_Ca', 'ink_Ca', 'sweepType', 'sup_dnorm', 'ink_dnorm', 'sup_We', 'ink_We', 'sup_Oh', 'ink_Oh', 'int_Ca']
#
# Dependents: ['projectionN', 'projectionN_N', 'projShiftN', 'projShiftN_N', 'vertDispBotN', 'vertDispBotN_N', 'vertDispTopN', 'vertDispTopN_N', 'vertDispMidN', 'vertDispMidN_N']

# %% [markdown]
# ## regression tables

# %%
xsregs = mp.regressionTable(ss, 'xs_aspect', nickname = 'cross-section aspect ratio', printOut=True, export=True)
varlist = [('vert_meanTN', 'normalized vertical line thickness'), 
           ('vert_hN', 'normalized vertical line length'), 
           ('vert_stdevTN', 'normalized vertical line thickness variation')]
vertregs = [mp.regressionTable(ss, i[0], nickname=i[1], logy=False, export=True, printOut=True) for i in varlist]
varlist = [('horiz_totlenN', 'normalized horizontal line total length', False),
           ('horiz_maxlenN', 'normalized horizontal line max segment length', False),
          ('horiz_segments_manual', 'number of horizontal line segments', False),
           ('horiz_roughness', 'horizontal line roughness', False)]
horizregs = [mp.regressionTable(ss, i[0], nickname=i[1], export=True, printOut=True, logy=i[2]) for i in varlist]
# Out:
# \begin{table}
# \centering
# \caption[Linear regressions for cross-section aspect ratio at nonzero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{cross-section aspect ratio} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:xs_aspectRegNonZero}
# \begin{tabular}{llrrll}
#                                   variables &       $r^2$ &     b &     c & spearman coeff &     spearman p \\
#                                   $\bm{Ca}$ & $\bm{0.29}$ &  0.09 &  0.10 &    $\bm{0.64}$ & $\bm{3.0e-20}$ \\
#                                  $Ca_{ink}$ &        0.06 &  0.06 &  0.14 &           0.27 &        4.0e-04 \\
#                                  $Ca_{sup}$ &        0.20 &  0.08 &  0.10 &           0.56 &        1.4e-14 \\
#                     $\bm{Ca_{ink}Ca_{sup}}$ & $\bm{0.28}$ &  0.08 &  0.14 &    $\bm{0.60}$ & $\bm{4.7e-17}$ \\
#                         $Ca_{ink}/Ca_{sup}$ &        0.04 & -0.03 &  0.10 &          -0.24 &        2.4e-03 \\
# 		\hline
#                                $d_{PR,ink}$ &        0.04 & -0.04 &  0.16 &          -0.17 &        3.4e-02 \\
#                                $d_{PR,sup}$ &        0.09 & -0.03 &  0.15 &          -0.48 &        7.8e-11 \\
#                      $d_{PR,ink}d_{PR,sup}$ &        0.18 & -0.04 &  0.22 &          -0.50 &        1.6e-11 \\
#                     $d_{PR,ink}/d_{PR,sup}$ &        0.02 &  0.01 &  0.11 &           0.25 &        1.5e-03 \\
# 		\hline
#                        $d_{Est}/d_{PR,ink}$ &        0.07 &  0.05 &  0.19 &           0.29 &        2.2e-04 \\
#                   $\bm{d_{Est}/d_{PR,sup}}$ & $\bm{0.11}$ &  0.03 &  0.16 &    $\bm{0.56}$ & $\bm{8.6e-15}$ \\
# $\bm{d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}}$ & $\bm{0.23}$ &  0.05 &  0.25 &    $\bm{0.59}$ & $\bm{6.2e-17}$ \\
#     $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$ &        0.02 & -0.01 &  0.11 &          -0.25 &        1.5e-03 \\
# 		\hline
#                                  $We_{ink}$ &        0.09 &  0.04 &  0.24 &           0.29 &        2.1e-04 \\
#                                  $We_{sup}$ &        0.01 &  0.01 &  0.14 &           0.08 &        3.1e-01 \\
#                          $We_{ink}We_{sup}$ &        0.04 &  0.01 &  0.19 &           0.21 &        7.3e-03 \\
#                         $We_{ink}/We_{sup}$ &        0.12 &  0.09 &  0.13 &           0.20 &        1.2e-02 \\
# 		\hline
#                                  $Oh_{ink}$ &        0.00 &  0.01 &  0.10 &           0.03 &        6.7e-01 \\
#                                  $Oh_{sup}$ &        0.13 &  0.05 &  0.04 &           0.48 &        1.3e-10 \\
#                          $Oh_{ink}Oh_{sup}$ &        0.13 &  0.05 & -0.01 &           0.42 &        2.6e-08 \\
#                         $Oh_{ink}/Oh_{sup}$ &        0.08 & -0.04 &  0.10 &          -0.39 &        2.2e-07 \\
# 		\hline
#                                  $Re_{ink}$ &        0.03 &  0.04 &  0.20 &           0.20 &        1.2e-02 \\
#                                  $Re_{sup}$ &        0.06 & -0.03 &  0.04 &          -0.26 &        6.6e-04 \\
#                          $Re_{ink}Re_{sup}$ &        0.01 & -0.01 &  0.06 &          -0.12 &        1.1e-01 \\
#                         $Re_{ink}/Re_{sup}$ &        0.12 &  0.04 &  0.10 &           0.45 &        1.3e-09 \\
# 		\hline
#                                  $Bm_{ink}$ &        0.00 &  0.00 &  0.12 &           0.06 &        4.7e-01 \\
#                                  $Bm_{sup}$ &        0.01 &  0.01 &  0.13 &           0.22 &        4.7e-03 \\
#                          $Bm_{ink}Bm_{sup}$ &        0.01 &  0.02 &  0.15 &           0.10 &        2.0e-01 \\
#                         $Bm_{ink}/Bm_{sup}$ &        0.01 & -0.01 &  0.12 &          -0.17 &        2.8e-02 \\
# 		\hline
#                                $\eta_{ink}$ &        0.01 & -0.03 &  0.11 &          -0.18 &        2.4e-02 \\
#                                $\eta_{sup}$ &        0.05 &  0.03 &  0.10 &           0.28 &        3.8e-04 \\
#                      $\eta_{ink}\eta_{sup}$ &        0.02 &  0.01 &  0.11 &           0.15 &        5.4e-02 \\
#                     $\eta_{ink}/\eta_{sup}$ &        0.08 & -0.04 &  0.09 &          -0.39 &        2.7e-07 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\xs_aspectRegNonZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for cross-section aspect ratio at zero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{cross-section aspect ratio} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:xs_aspectRegZero}
# \begin{tabular}{llrrll}
#                    variables &       $r^2$ &     b &     c & spearman coeff &     spearman p \\
#                   $Re_{ink}$ &        0.21 &  0.14 &  0.62 &           0.45 &        2.9e-07 \\
#                   $Re_{sup}$ &        0.24 & -0.15 & -0.17 &          -0.52 &        2.8e-09 \\
#           $Re_{ink}Re_{sup}$ &        0.00 & -0.00 &  0.24 &           0.01 &        9.2e-01 \\
#     $\bm{Re_{ink}/Re_{sup}}$ & $\bm{0.62}$ &  0.20 &  0.20 &    $\bm{0.78}$ & $\bm{2.6e-25}$ \\
# 		\hline
#                   $Bm_{ink}$ &        0.11 & -0.13 &  0.08 &          -0.51 &        3.7e-09 \\
#                   $Bm_{sup}$ &        0.14 &  1.00 &  1.43 &           0.47 &        1.1e-07 \\
#           $Bm_{ink}Bm_{sup}$ &        0.08 & -0.11 & -0.02 &          -0.12 &        2.0e-01 \\
#     $\bm{Bm_{ink}/Bm_{sup}}$ & $\bm{0.15}$ & -0.15 &  0.23 &   $\bm{-0.58}$ & $\bm{8.5e-12}$ \\
# 		\hline
#                 $\eta_{ink}$ &        0.25 & -0.22 &  0.30 &          -0.48 &        4.7e-08 \\
#                 $\eta_{sup}$ &        0.34 &  0.26 &  0.09 &           0.57 &        1.4e-11 \\
#       $\eta_{ink}\eta_{sup}$ &        0.00 &  0.01 &  0.24 &           0.05 &        6.1e-01 \\
# $\bm{\eta_{ink}/\eta_{sup}}$ & $\bm{0.64}$ & -0.27 &  0.15 &   $\bm{-0.80}$ & $\bm{2.1e-27}$ \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\xs_aspectRegZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized vertical line thickness at nonzero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized vertical line thickness} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:vert_meanTNRegNonZero}
# \begin{tabular}{llrrll}
#                                   variables &       $r^2$ &     b &    c & spearman coeff &     spearman p \\
#                                   $\bm{Ca}$ & $\bm{0.68}$ & -0.64 & 1.34 &   $\bm{-0.87}$ & $\bm{1.6e-50}$ \\
#                                  $Ca_{ink}$ &        0.04 & -0.24 & 1.14 &          -0.20 &        1.1e-02 \\
#                             $\bm{Ca_{sup}}$ & $\bm{0.62}$ & -0.64 & 1.33 &   $\bm{-0.84}$ & $\bm{9.5e-44}$ \\
#                     $\bm{Ca_{ink}Ca_{sup}}$ & $\bm{0.63}$ & -0.55 & 1.08 &   $\bm{-0.80}$ & $\bm{3.2e-36}$ \\
#                         $Ca_{ink}/Ca_{sup}$ &        0.24 &  0.31 & 1.42 &           0.48 &        1.2e-10 \\
# 		\hline
#                                $d_{PR,ink}$ &        0.04 &  0.18 & 1.00 &           0.17 &        2.8e-02 \\
#                           $\bm{d_{PR,sup}}$ & $\bm{0.39}$ &  0.28 & 0.90 &    $\bm{0.74}$ & $\bm{1.2e-28}$ \\
#                 $\bm{d_{PR,ink}d_{PR,sup}}$ & $\bm{0.59}$ &  0.37 & 0.29 &    $\bm{0.80}$ & $\bm{3.8e-36}$ \\
#                     $d_{PR,ink}/d_{PR,sup}$ &        0.17 & -0.15 & 1.26 &          -0.41 &        8.9e-08 \\
# 		\hline
#                        $d_{Est}/d_{PR,ink}$ &        0.06 & -0.22 & 0.89 &          -0.26 &        9.8e-04 \\
#                   $\bm{d_{Est}/d_{PR,sup}}$ & $\bm{0.41}$ & -0.29 & 0.83 &   $\bm{-0.79}$ & $\bm{6.4e-35}$ \\
# $\bm{d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}}$ & $\bm{0.66}$ & -0.38 & 0.10 &   $\bm{-0.86}$ & $\bm{2.7e-47}$ \\
#     $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$ &        0.17 &  0.15 & 1.26 &           0.41 &        9.0e-08 \\
# 		\hline
#                                  $We_{ink}$ &        0.04 & -0.15 & 0.81 &          -0.19 &        1.6e-02 \\
#                                  $We_{sup}$ &        0.00 & -0.03 & 1.17 &          -0.09 &        2.8e-01 \\
#                          $We_{ink}We_{sup}$ &        0.02 & -0.05 & 0.98 &          -0.14 &        7.1e-02 \\
#                         $We_{ink}/We_{sup}$ &        0.09 & -0.40 & 1.16 &          -0.09 &        2.3e-01 \\
# 		\hline
#                                  $Oh_{ink}$ &        0.01 & -0.12 & 1.36 &          -0.08 &        3.2e-01 \\
#                             $\bm{Oh_{sup}}$ & $\bm{0.45}$ & -0.49 & 1.96 &   $\bm{-0.75}$ & $\bm{3.4e-30}$ \\
#                     $\bm{Oh_{ink}Oh_{sup}}$ & $\bm{0.47}$ & -0.48 & 2.42 &   $\bm{-0.71}$ & $\bm{4.4e-26}$ \\
#                         $Oh_{ink}/Oh_{sup}$ &        0.29 &  0.33 & 1.40 &           0.57 &        5.6e-15 \\
# 		\hline
#                                  $Re_{ink}$ &        0.01 & -0.08 & 1.04 &          -0.12 &        1.5e-01 \\
#                                  $Re_{sup}$ &        0.25 &  0.27 & 2.01 &           0.46 &        1.4e-09 \\
#                          $Re_{ink}Re_{sup}$ &        0.12 &  0.15 & 2.03 &           0.31 &        8.7e-05 \\
#                    $\bm{Re_{ink}/Re_{sup}}$ & $\bm{0.31}$ & -0.32 & 1.36 &   $\bm{-0.59}$ & $\bm{1.2e-16}$ \\
# 		\hline
#                                  $Bm_{ink}$ &        0.01 & -0.29 & 0.92 &          -0.11 &        1.6e-01 \\
#                                  $Bm_{sup}$ &        0.12 & -0.28 & 0.85 &          -0.37 &        1.4e-06 \\
#                          $Bm_{ink}Bm_{sup}$ &        0.15 & -0.34 & 0.38 &          -0.35 &        5.3e-06 \\
#                         $Bm_{ink}/Bm_{sup}$ &        0.08 &  0.21 & 1.19 &           0.20 &        1.1e-02 \\
# 		\hline
#                                $\eta_{ink}$ &        0.00 &  0.08 & 1.25 &           0.11 &        1.7e-01 \\
#                                $\eta_{sup}$ &        0.24 & -0.28 & 1.38 &          -0.46 &        6.7e-10 \\
#                      $\eta_{ink}\eta_{sup}$ &        0.14 & -0.18 & 1.31 &          -0.33 &        2.2e-05 \\
#                $\bm{\eta_{ink}/\eta_{sup}}$ & $\bm{0.29}$ &  0.33 & 1.43 &    $\bm{0.57}$ & $\bm{5.2e-15}$ \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\vert_meanTNRegNonZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized vertical line thickness at zero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized vertical line thickness} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:vert_meanTNRegZero}
# \begin{tabular}{llrrll}
#                    variables &       $r^2$ &     b &    c & spearman coeff &     spearman p \\
#                   $Re_{ink}$ &        0.15 & -0.17 & 0.15 &          -0.37 &        5.7e-05 \\
#                   $Re_{sup}$ &        0.04 &  0.08 & 0.82 &           0.37 &        6.8e-05 \\
#           $Re_{ink}Re_{sup}$ &        0.01 & -0.03 & 0.41 &          -0.02 &        8.3e-01 \\
#     $\bm{Re_{ink}/Re_{sup}}$ & $\bm{0.22}$ & -0.17 & 0.63 &   $\bm{-0.61}$ & $\bm{1.2e-12}$ \\
# 		\hline
#                   $Bm_{ink}$ &        0.03 &  0.10 & 0.72 &           0.36 &        1.3e-04 \\
#                   $Bm_{sup}$ &        0.00 &  0.02 & 0.61 &          -0.12 &        2.1e-01 \\
#           $Bm_{ink}Bm_{sup}$ &        0.03 &  0.10 & 0.84 &           0.23 &        1.4e-02 \\
#          $Bm_{ink}/Bm_{sup}$ &        0.03 &  0.10 & 0.60 &           0.37 &        6.6e-05 \\
# 		\hline
#                 $\eta_{ink}$ &        0.18 &  0.28 & 0.53 &           0.40 &        1.9e-05 \\
#                 $\eta_{sup}$ &        0.02 & -0.09 & 0.64 &          -0.33 &        4.4e-04 \\
#       $\eta_{ink}\eta_{sup}$ &        0.04 &  0.08 & 0.51 &           0.05 &        6.2e-01 \\
# $\bm{\eta_{ink}/\eta_{sup}}$ & $\bm{0.16}$ &  0.20 & 0.67 &    $\bm{0.56}$ & $\bm{2.5e-10}$ \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\vert_meanTNRegZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized vertical line length at nonzero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized vertical line length} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:vert_hNRegNonZero}
# \begin{tabular}{llrrll}
#                                   variables &       $r^2$ &     b &     c & spearman coeff &     spearman p \\
#                                   $\bm{Ca}$ & $\bm{0.66}$ &  0.49 &  0.53 &    $\bm{0.87}$ & $\bm{2.3e-49}$ \\
#                                  $Ca_{ink}$ &        0.03 &  0.15 &  0.67 &           0.17 &        3.5e-02 \\
#                             $\bm{Ca_{sup}}$ & $\bm{0.56}$ &  0.47 &  0.54 &    $\bm{0.81}$ & $\bm{6.1e-39}$ \\
#                          $Ca_{ink}Ca_{sup}$ &        0.54 &  0.39 &  0.72 &           0.76 &        9.5e-32 \\
#                         $Ca_{ink}/Ca_{sup}$ &        0.23 & -0.24 &  0.47 &          -0.49 &        5.6e-11 \\
# 		\hline
#                                $d_{PR,ink}$ &        0.02 & -0.09 &  0.73 &          -0.13 &        1.1e-01 \\
#                           $\bm{d_{PR,sup}}$ & $\bm{0.32}$ & -0.20 &  0.84 &   $\bm{-0.71}$ & $\bm{2.5e-26}$ \\
#                 $\bm{d_{PR,ink}d_{PR,sup}}$ & $\bm{0.45}$ & -0.25 &  1.24 &   $\bm{-0.73}$ & $\bm{1.3e-27}$ \\
#                     $d_{PR,ink}/d_{PR,sup}$ &        0.15 &  0.11 &  0.59 &           0.43 &        1.5e-08 \\
# 		\hline
#                        $d_{Est}/d_{PR,ink}$ &        0.04 &  0.14 &  0.82 &           0.21 &        6.5e-03 \\
#                   $\bm{d_{Est}/d_{PR,sup}}$ & $\bm{0.35}$ &  0.21 &  0.90 &    $\bm{0.77}$ & $\bm{7.8e-33}$ \\
# $\bm{d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}}$ & $\bm{0.53}$ &  0.27 &  1.39 &    $\bm{0.79}$ & $\bm{1.5e-35}$ \\
#     $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$ &        0.15 & -0.11 &  0.59 &          -0.43 &        1.5e-08 \\
# 		\hline
#                                  $We_{ink}$ &        0.07 &  0.16 &  1.06 &           0.27 &        4.9e-04 \\
#                                  $We_{sup}$ &        0.00 &  0.04 &  0.71 &           0.16 &        4.5e-02 \\
#                          $We_{ink}We_{sup}$ &        0.03 &  0.05 &  0.89 &           0.23 &        3.0e-03 \\
#                         $We_{ink}/We_{sup}$ &        0.14 &  0.39 &  0.68 &           0.06 &        4.2e-01 \\
# 		\hline
#                                  $Oh_{ink}$ &        0.00 & -0.06 &  0.66 &          -0.05 &        5.1e-01 \\
#                             $\bm{Oh_{sup}}$ & $\bm{0.39}$ &  0.35 &  0.09 &    $\bm{0.71}$ & $\bm{1.7e-25}$ \\
#                          $Oh_{ink}Oh_{sup}$ &        0.34 &  0.31 & -0.16 &           0.60 &        3.0e-17 \\
#                         $Oh_{ink}/Oh_{sup}$ &        0.30 & -0.26 &  0.48 &          -0.59 &        2.2e-16 \\
# 		\hline
#                                  $Re_{ink}$ &        0.05 &  0.17 &  1.02 &           0.26 &        8.8e-04 \\
#                                  $Re_{sup}$ &        0.20 & -0.19 &  0.07 &          -0.41 &        5.7e-08 \\
#                          $Re_{ink}Re_{sup}$ &        0.07 & -0.09 &  0.16 &          -0.20 &        1.2e-02 \\
#                    $\bm{Re_{ink}/Re_{sup}}$ & $\bm{0.35}$ &  0.26 &  0.51 &    $\bm{0.63}$ & $\bm{1.0e-18}$ \\
# 		\hline
#                                  $Bm_{ink}$ &        0.00 & -0.02 &  0.59 &          -0.01 &        8.9e-01 \\
#                                  $Bm_{sup}$ &        0.07 &  0.17 &  0.84 &           0.34 &        8.0e-06 \\
#                          $Bm_{ink}Bm_{sup}$ &        0.08 &  0.19 &  1.09 &           0.25 &        1.5e-03 \\
#                         $Bm_{ink}/Bm_{sup}$ &        0.06 & -0.14 &  0.64 &          -0.24 &        2.1e-03 \\
# 		\hline
#                                $\eta_{ink}$ &        0.04 & -0.22 &  0.59 &          -0.24 &        2.6e-03 \\
#                                $\eta_{sup}$ &        0.19 &  0.20 &  0.51 &           0.43 &        2.0e-08 \\
#                      $\eta_{ink}\eta_{sup}$ &        0.08 &  0.10 &  0.56 &           0.24 &        2.2e-03 \\
#                $\bm{\eta_{ink}/\eta_{sup}}$ & $\bm{0.31}$ & -0.26 &  0.45 &   $\bm{-0.59}$ & $\bm{1.9e-16}$ \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\vert_hNRegNonZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized vertical line length at zero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized vertical line length} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:vert_hNRegZero}
# \begin{tabular}{llrrll}
#               variables & $r^2$ &     b &     c & spearman coeff & spearman p \\
#              $Re_{ink}$ &  0.00 &  0.01 &  1.31 &           0.07 &    4.6e-01 \\
#              $Re_{sup}$ &  0.00 &  0.01 &  1.29 &          -0.10 &    2.9e-01 \\
#      $Re_{ink}Re_{sup}$ &  0.00 &  0.01 &  1.32 &          -0.00 &    9.9e-01 \\
#     $Re_{ink}/Re_{sup}$ &  0.00 &  0.00 &  1.27 &           0.14 &    1.4e-01 \\
# 		\hline
#              $Bm_{ink}$ &  0.02 & -0.13 &  1.08 &          -0.36 &    1.3e-04 \\
#              $Bm_{sup}$ &  0.05 & -1.34 & -0.30 &          -0.42 &    6.1e-06 \\
#      $Bm_{ink}Bm_{sup}$ &  0.03 & -0.16 &  0.86 &          -0.43 &    3.2e-06 \\
#     $Bm_{ink}/Bm_{sup}$ &  0.02 & -0.11 &  1.25 &          -0.31 &    1.1e-03 \\
# 		\hline
#            $\eta_{ink}$ &  0.05 & -0.24 &  1.32 &          -0.27 &    5.1e-03 \\
#            $\eta_{sup}$ &  0.03 & -0.16 &  1.37 &          -0.04 &    6.6e-01 \\
#  $\eta_{ink}\eta_{sup}$ &  0.07 & -0.18 &  1.42 &          -0.20 &    3.6e-02 \\
# $\eta_{ink}/\eta_{sup}$ &  0.00 & -0.03 &  1.25 &          -0.18 &    6.7e-02 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\vert_hNRegZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized vertical line thickness variation at nonzero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized vertical line thickness variation} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:vert_stdevTNRegNonZero}
# \begin{tabular}{llrrll}
#                               variables & $r^2$ &     b &    c & spearman coeff & spearman p \\
#                                    $Ca$ &  0.06 &  0.00 & 0.00 &           0.28 &    3.5e-04 \\
#                              $Ca_{ink}$ &  0.02 &  0.00 & 0.00 &           0.15 &    6.7e-02 \\
#                              $Ca_{sup}$ &  0.12 &  0.00 & 0.00 &           0.35 &    6.2e-06 \\
#                      $Ca_{ink}Ca_{sup}$ &  0.14 &  0.00 & 0.00 &           0.45 &    3.4e-09 \\
#                     $Ca_{ink}/Ca_{sup}$ &  0.04 & -0.00 & 0.00 &          -0.27 &    6.1e-04 \\
# 		\hline
#                            $d_{PR,ink}$ &  0.01 & -0.00 & 0.00 &          -0.10 &    2.1e-01 \\
#                            $d_{PR,sup}$ &  0.06 & -0.00 & 0.00 &          -0.38 &    8.6e-07 \\
#                  $d_{PR,ink}d_{PR,sup}$ &  0.09 & -0.00 & 0.00 &          -0.36 &    3.4e-06 \\
#                 $d_{PR,ink}/d_{PR,sup}$ &  0.03 &  0.00 & 0.00 &           0.26 &    8.0e-04 \\
# 		\hline
#                    $d_{Est}/d_{PR,ink}$ &  0.00 &  0.00 & 0.00 &           0.04 &    6.3e-01 \\
#                    $d_{Est}/d_{PR,sup}$ &  0.05 &  0.00 & 0.00 &           0.30 &    1.2e-04 \\
#  $d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}$ &  0.07 &  0.00 & 0.00 &           0.29 &    1.6e-04 \\
# $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$ &  0.03 & -0.00 & 0.00 &          -0.26 &    7.8e-04 \\
# 		\hline
#                              $We_{ink}$ &  0.07 &  0.00 & 0.00 &           0.15 &    5.7e-02 \\
#                              $We_{sup}$ &  0.15 &  0.00 & 0.00 &           0.33 &    2.3e-05 \\
#                      $We_{ink}We_{sup}$ &  0.12 &  0.00 & 0.00 &           0.25 &    1.7e-03 \\
#                     $We_{ink}/We_{sup}$ &  0.07 & -0.00 & 0.00 &          -0.26 &    9.4e-04 \\
# 		\hline
#                              $Oh_{ink}$ &  0.01 & -0.00 & 0.00 &           0.06 &    4.4e-01 \\
#                              $Oh_{sup}$ &  0.01 &  0.00 & 0.00 &           0.20 &    1.2e-02 \\
#                      $Oh_{ink}Oh_{sup}$ &  0.00 &  0.00 & 0.00 &           0.18 &    1.9e-02 \\
#                     $Oh_{ink}/Oh_{sup}$ &  0.02 & -0.00 & 0.00 &          -0.18 &    2.2e-02 \\
# 		\hline
#                              $Re_{ink}$ &  0.05 &  0.00 & 0.00 &           0.08 &    3.4e-01 \\
#                              $Re_{sup}$ &  0.00 &  0.00 & 0.00 &          -0.01 &    8.9e-01 \\
#                      $Re_{ink}Re_{sup}$ &  0.02 &  0.00 & 0.00 &           0.03 &    7.2e-01 \\
#                     $Re_{ink}/Re_{sup}$ &  0.00 &  0.00 & 0.00 &           0.13 &    9.6e-02 \\
# 		\hline
#                              $Bm_{ink}$ &  0.01 & -0.00 & 0.00 &           0.04 &    6.3e-01 \\
#                              $Bm_{sup}$ &  0.01 &  0.00 & 0.00 &           0.32 &    4.3e-05 \\
#                      $Bm_{ink}Bm_{sup}$ &  0.01 &  0.00 & 0.00 &           0.14 &    7.2e-02 \\
#                     $Bm_{ink}/Bm_{sup}$ &  0.02 & -0.00 & 0.00 &          -0.15 &    5.3e-02 \\
# 		\hline
#                            $\eta_{ink}$ &  0.02 & -0.00 & 0.00 &          -0.07 &    3.5e-01 \\
#                            $\eta_{sup}$ &  0.00 &  0.00 & 0.00 &           0.11 &    1.6e-01 \\
#                  $\eta_{ink}\eta_{sup}$ &  0.00 &  0.00 & 0.00 &           0.02 &    7.6e-01 \\
#                 $\eta_{ink}/\eta_{sup}$ &  0.02 & -0.00 & 0.00 &          -0.18 &    2.2e-02 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\vert_stdevTNRegNonZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized vertical line thickness variation at zero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized vertical line thickness variation} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:vert_stdevTNRegZero}
# \begin{tabular}{llrrll}
#               variables & $r^2$ &     b &    c & spearman coeff & spearman p \\
#              $Re_{ink}$ &  0.00 &  0.00 & 0.00 &          -0.03 &    7.5e-01 \\
#              $Re_{sup}$ &  0.15 &  0.00 & 0.01 &           0.33 &    5.2e-04 \\
#      $Re_{ink}Re_{sup}$ &  0.07 &  0.00 & 0.01 &           0.18 &    5.4e-02 \\
#     $Re_{ink}/Re_{sup}$ &  0.09 & -0.00 & 0.00 &          -0.31 &    8.7e-04 \\
# 		\hline
#              $Bm_{ink}$ &  0.02 & -0.00 & 0.00 &          -0.12 &    2.1e-01 \\
#              $Bm_{sup}$ &  0.00 & -0.00 & 0.00 &          -0.10 &    3.2e-01 \\
#      $Bm_{ink}Bm_{sup}$ &  0.02 & -0.00 & 0.00 &          -0.16 &    9.3e-02 \\
#     $Bm_{ink}/Bm_{sup}$ &  0.02 & -0.00 & 0.00 &          -0.12 &    2.1e-01 \\
# 		\hline
#            $\eta_{ink}$ &  0.01 & -0.00 & 0.00 &          -0.05 &    6.0e-01 \\
#            $\eta_{sup}$ &  0.07 & -0.00 & 0.00 &          -0.27 &    4.3e-03 \\
#  $\eta_{ink}\eta_{sup}$ &  0.06 & -0.00 & 0.00 &          -0.22 &    2.4e-02 \\
# $\eta_{ink}/\eta_{sup}$ &  0.02 &  0.00 & 0.00 &           0.15 &    1.3e-01 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\vert_stdevTNRegZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized horizontal line total length at nonzero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized horizontal line total length} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:horiz_totlenNRegNonZero}
# \begin{tabular}{llrrll}
#                                   variables &       $r^2$ &     b &    c & spearman coeff &     spearman p \\
#                                   $\bm{Ca}$ & $\bm{0.54}$ &  0.35 & 0.60 &    $\bm{0.83}$ & $\bm{1.6e-36}$ \\
#                                  $Ca_{ink}$ &        0.06 &  0.20 & 0.75 &           0.24 &        4.9e-03 \\
#                             $\bm{Ca_{sup}}$ & $\bm{0.39}$ &  0.32 & 0.61 &    $\bm{0.75}$ & $\bm{6.3e-27}$ \\
#                     $\bm{Ca_{ink}Ca_{sup}}$ & $\bm{0.52}$ &  0.34 & 0.78 &    $\bm{0.77}$ & $\bm{1.0e-28}$ \\
#                         $Ca_{ink}/Ca_{sup}$ &        0.13 & -0.14 & 0.56 &          -0.41 &        4.4e-07 \\
# 		\hline
#                                $d_{PR,ink}$ &        0.04 & -0.13 & 0.84 &          -0.17 &        3.8e-02 \\
#                           $\bm{d_{PR,sup}}$ & $\bm{0.18}$ & -0.12 & 0.79 &   $\bm{-0.63}$ & $\bm{3.4e-17}$ \\
#                 $\bm{d_{PR,ink}d_{PR,sup}}$ & $\bm{0.32}$ & -0.18 & 1.11 &   $\bm{-0.67}$ & $\bm{1.2e-19}$ \\
#                     $d_{PR,ink}/d_{PR,sup}$ &        0.07 &  0.06 & 0.64 &           0.39 &        2.0e-06 \\
# 		\hline
#                        $d_{Est}/d_{PR,ink}$ &        0.09 &  0.19 & 0.96 &           0.32 &        1.0e-04 \\
#                   $\bm{d_{Est}/d_{PR,sup}}$ & $\bm{0.21}$ &  0.13 & 0.83 &    $\bm{0.72}$ & $\bm{2.5e-24}$ \\
# $\bm{d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}}$ & $\bm{0.42}$ &  0.20 & 1.26 &    $\bm{0.78}$ & $\bm{2.2e-30}$ \\
#     $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$ &        0.07 & -0.06 & 0.64 &          -0.39 &        1.9e-06 \\
# 		\hline
#                                  $We_{ink}$ &        0.07 &  0.13 & 1.02 &           0.25 &        2.2e-03 \\
#                                  $We_{sup}$ &        0.00 & -0.02 & 0.60 &           0.03 &        7.1e-01 \\
#                          $We_{ink}We_{sup}$ &        0.01 &  0.03 & 0.81 &           0.16 &        6.3e-02 \\
#                         $We_{ink}/We_{sup}$ &        0.22 &  0.36 & 0.72 &           0.24 &        4.1e-03 \\
# 		\hline
#                                  $Oh_{ink}$ &        0.00 &  0.05 & 0.60 &           0.01 &        9.1e-01 \\
#                             $\bm{Oh_{sup}}$ & $\bm{0.32}$ &  0.25 & 0.27 &    $\bm{0.70}$ & $\bm{3.2e-22}$ \\
#                          $Oh_{ink}Oh_{sup}$ &        0.32 &  0.24 & 0.05 &           0.61 &        1.5e-15 \\
#                         $Oh_{ink}/Oh_{sup}$ &        0.22 & -0.18 & 0.56 &          -0.58 &        4.0e-14 \\
# 		\hline
#                                  $Re_{ink}$ &        0.02 &  0.08 & 0.84 &           0.18 &        2.8e-02 \\
#                                  $Re_{sup}$ &        0.21 & -0.16 & 0.20 &          -0.50 &        1.5e-10 \\
#                          $Re_{ink}Re_{sup}$ &        0.09 & -0.08 & 0.24 &          -0.30 &        3.1e-04 \\
#                    $\bm{Re_{ink}/Re_{sup}}$ & $\bm{0.29}$ &  0.19 & 0.57 &    $\bm{0.63}$ & $\bm{2.5e-17}$ \\
# 		\hline
#                                  $Bm_{ink}$ &        0.00 &  0.06 & 0.72 &           0.00 &        9.8e-01 \\
#                                  $Bm_{sup}$ &        0.02 &  0.07 & 0.75 &           0.34 &        3.5e-05 \\
#                          $Bm_{ink}Bm_{sup}$ &        0.02 &  0.08 & 0.86 &           0.20 &        1.5e-02 \\
#                         $Bm_{ink}/Bm_{sup}$ &        0.01 & -0.05 & 0.66 &          -0.25 &        2.6e-03 \\
# 		\hline
#                                $\eta_{ink}$ &        0.01 & -0.08 & 0.65 &          -0.15 &        7.7e-02 \\
#                                $\eta_{sup}$ &        0.17 &  0.15 & 0.56 &           0.52 &        5.1e-11 \\
#                      $\eta_{ink}\eta_{sup}$ &        0.09 &  0.09 & 0.60 &           0.34 &        3.9e-05 \\
#                $\bm{\eta_{ink}/\eta_{sup}}$ & $\bm{0.22}$ & -0.18 & 0.54 &   $\bm{-0.58}$ & $\bm{5.6e-14}$ \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\horiz_totlenNRegNonZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized horizontal line total length at zero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized horizontal line total length} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:horiz_totlenNRegZero}
# \begin{tabular}{llrrll}
#               variables & $r^2$ &     b &    c & spearman coeff & spearman p \\
#              $Re_{ink}$ &  0.00 & -0.03 & 0.87 &          -0.04 &    6.9e-01 \\
#              $Re_{sup}$ &  0.02 & -0.06 & 0.79 &          -0.12 &    2.0e-01 \\
#      $Re_{ink}Re_{sup}$ &  0.01 & -0.04 & 0.76 &          -0.09 &    3.4e-01 \\
#     $Re_{ink}/Re_{sup}$ &  0.00 &  0.02 & 0.95 &           0.13 &    1.8e-01 \\
# 		\hline
#              $Bm_{ink}$ &  0.01 & -0.06 & 0.88 &          -0.10 &    2.8e-01 \\
#              $Bm_{sup}$ &  0.00 & -0.13 & 0.80 &          -0.10 &    2.7e-01 \\
#      $Bm_{ink}Bm_{sup}$ &  0.01 & -0.06 & 0.81 &          -0.13 &    1.5e-01 \\
#     $Bm_{ink}/Bm_{sup}$ &  0.01 & -0.05 & 0.95 &          -0.20 &    2.9e-02 \\
# 		\hline
#            $\eta_{ink}$ &  0.00 & -0.01 & 0.96 &          -0.08 &    3.7e-01 \\
#            $\eta_{sup}$ &  0.00 &  0.00 & 0.96 &           0.03 &    7.6e-01 \\
#  $\eta_{ink}\eta_{sup}$ &  0.00 & -0.01 & 0.96 &          -0.02 &    8.6e-01 \\
# $\eta_{ink}/\eta_{sup}$ &  0.00 & -0.01 & 0.95 &          -0.10 &    2.7e-01 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\horiz_totlenNRegZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized horizontal line max segment length at nonzero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized horizontal line max segment length} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:horiz_maxlenNRegNonZero}
# \begin{tabular}{llrrll}
#                                   variables &       $r^2$ &     b &     c & spearman coeff &     spearman p \\
#                                   $\bm{Ca}$ & $\bm{0.49}$ &  0.37 &  0.55 &    $\bm{0.78}$ & $\bm{4.1e-30}$ \\
#                                  $Ca_{ink}$ &        0.11 &  0.29 &  0.75 &           0.33 &        7.0e-05 \\
#                                  $Ca_{sup}$ &        0.34 &  0.33 &  0.56 &           0.70 &        8.4e-22 \\
#                     $\bm{Ca_{ink}Ca_{sup}}$ & $\bm{0.53}$ &  0.38 &  0.75 &    $\bm{0.76}$ & $\bm{6.6e-28}$ \\
#                         $Ca_{ink}/Ca_{sup}$ &        0.08 & -0.13 &  0.52 &          -0.31 &        2.0e-04 \\
# 		\hline
#                                $d_{PR,ink}$ &        0.08 & -0.20 &  0.88 &          -0.26 &        1.9e-03 \\
#                                $d_{PR,sup}$ &        0.15 & -0.13 &  0.75 &          -0.57 &        1.7e-13 \\
#                 $\bm{d_{PR,ink}d_{PR,sup}}$ & $\bm{0.32}$ & -0.20 &  1.12 &   $\bm{-0.65}$ & $\bm{1.5e-18}$ \\
#                     $d_{PR,ink}/d_{PR,sup}$ &        0.04 &  0.05 &  0.59 &           0.29 &        5.8e-04 \\
# 		\hline
#                        $d_{Est}/d_{PR,ink}$ &        0.14 &  0.26 &  1.03 &           0.41 &        4.7e-07 \\
#                        $d_{Est}/d_{PR,sup}$ &        0.19 &  0.14 &  0.80 &           0.67 &        1.7e-19 \\
# $\bm{d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}}$ & $\bm{0.43}$ &  0.23 &  1.29 &    $\bm{0.77}$ & $\bm{2.1e-29}$ \\
#     $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$ &        0.04 & -0.05 &  0.59 &          -0.29 &        5.7e-04 \\
# 		\hline
#                                  $We_{ink}$ &        0.07 &  0.14 &  1.03 &           0.24 &        3.7e-03 \\
#                                  $We_{sup}$ &        0.00 & -0.02 &  0.54 &           0.00 &        9.9e-01 \\
#                          $We_{ink}We_{sup}$ &        0.01 &  0.03 &  0.79 &           0.13 &        1.2e-01 \\
#                         $We_{ink}/We_{sup}$ &        0.24 &  0.42 &  0.69 &           0.30 &        3.0e-04 \\
# 		\hline
#                                  $Oh_{ink}$ &        0.02 &  0.14 &  0.47 &           0.10 &        2.2e-01 \\
#                             $\bm{Oh_{sup}}$ & $\bm{0.28}$ &  0.27 &  0.20 &    $\bm{0.65}$ & $\bm{2.1e-18}$ \\
#                     $\bm{Oh_{ink}Oh_{sup}}$ & $\bm{0.32}$ &  0.27 & -0.07 &    $\bm{0.60}$ & $\bm{2.1e-15}$ \\
#                         $Oh_{ink}/Oh_{sup}$ &        0.16 & -0.17 &  0.51 &          -0.49 &        4.8e-10 \\
# 		\hline
#                                  $Re_{ink}$ &        0.01 &  0.05 &  0.74 &           0.12 &        1.5e-01 \\
#                                  $Re_{sup}$ &        0.18 & -0.17 &  0.13 &          -0.47 &        3.5e-09 \\
#                          $Re_{ink}Re_{sup}$ &        0.09 & -0.09 &  0.14 &          -0.30 &        2.7e-04 \\
#                    $\bm{Re_{ink}/Re_{sup}}$ & $\bm{0.23}$ &  0.19 &  0.52 &    $\bm{0.56}$ & $\bm{4.6e-13}$ \\
# 		\hline
#                                  $Bm_{ink}$ &        0.00 &  0.14 &  0.77 &           0.07 &        4.3e-01 \\
#                                  $Bm_{sup}$ &        0.01 &  0.07 &  0.70 &           0.28 &        8.2e-04 \\
#                          $Bm_{ink}Bm_{sup}$ &        0.02 &  0.09 &  0.84 &           0.21 &        1.4e-02 \\
#                         $Bm_{ink}/Bm_{sup}$ &        0.01 & -0.05 &  0.61 &          -0.18 &        3.1e-02 \\
# 		\hline
#                                $\eta_{ink}$ &        0.00 & -0.02 &  0.60 &          -0.08 &        3.7e-01 \\
#                                $\eta_{sup}$ &        0.14 &  0.16 &  0.51 &           0.47 &        4.0e-09 \\
#                      $\eta_{ink}\eta_{sup}$ &        0.09 &  0.10 &  0.55 &           0.34 &        4.6e-05 \\
#                     $\eta_{ink}/\eta_{sup}$ &        0.16 & -0.17 &  0.49 &          -0.49 &        6.5e-10 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\horiz_maxlenNRegNonZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized horizontal line max segment length at zero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized horizontal line max segment length} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:horiz_maxlenNRegZero}
# \begin{tabular}{llrrll}
#               variables & $r^2$ &     b &    c & spearman coeff & spearman p \\
#              $Re_{ink}$ &  0.01 & -0.04 & 0.83 &          -0.06 &    5.3e-01 \\
#              $Re_{sup}$ &  0.02 & -0.07 & 0.74 &          -0.13 &    1.6e-01 \\
#      $Re_{ink}Re_{sup}$ &  0.02 & -0.04 & 0.71 &          -0.10 &    2.7e-01 \\
#     $Re_{ink}/Re_{sup}$ &  0.00 &  0.02 & 0.93 &           0.11 &    2.6e-01 \\
# 		\hline
#              $Bm_{ink}$ &  0.01 & -0.05 & 0.86 &          -0.09 &    3.1e-01 \\
#              $Bm_{sup}$ &  0.00 & -0.25 & 0.64 &          -0.14 &    1.4e-01 \\
#      $Bm_{ink}Bm_{sup}$ &  0.01 & -0.06 & 0.79 &          -0.14 &    1.3e-01 \\
#     $Bm_{ink}/Bm_{sup}$ &  0.01 & -0.05 & 0.92 &          -0.18 &    5.2e-02 \\
# 		\hline
#            $\eta_{ink}$ &  0.00 & -0.01 & 0.93 &          -0.07 &    4.6e-01 \\
#            $\eta_{sup}$ &  0.00 &  0.00 & 0.93 &           0.03 &    7.6e-01 \\
#  $\eta_{ink}\eta_{sup}$ &  0.00 & -0.00 & 0.94 &          -0.01 &    9.5e-01 \\
# $\eta_{ink}/\eta_{sup}$ &  0.00 & -0.01 & 0.93 &          -0.08 &    3.7e-01 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\horiz_maxlenNRegZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for number of horizontal line segments at nonzero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{number of horizontal line segments} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:horiz_segments_manualRegNonZero}
# \begin{tabular}{llrrll}
#                               variables &       $r^2$ &      b &     c & spearman coeff &     spearman p \\
#                                    $Ca$ &        0.02 &  -1.54 &  5.62 &          -0.26 &        8.5e-04 \\
#                         $\bm{Ca_{ink}}$ & $\bm{0.12}$ &  -5.66 &  2.89 &   $\bm{-0.59}$ & $\bm{6.2e-17}$ \\
#                              $Ca_{sup}$ &        0.01 &   0.92 &  5.26 &          -0.18 &        2.4e-02 \\
#                      $Ca_{ink}Ca_{sup}$ &        0.02 &  -1.57 &  4.92 &          -0.40 &        8.3e-08 \\
#                     $Ca_{ink}/Ca_{sup}$ &        0.06 &  -2.37 &  4.01 &          -0.31 &        4.4e-05 \\
# 		\hline
#                       $\bm{d_{PR,ink}}$ & $\bm{0.10}$ &   4.18 & -0.25 &    $\bm{0.52}$ & $\bm{5.4e-13}$ \\
#                            $d_{PR,sup}$ &        0.01 &  -0.77 &  6.31 &           0.01 &        9.1e-01 \\
#                  $d_{PR,ink}d_{PR,sup}$ &        0.00 &   0.36 &  4.48 &           0.26 &        8.1e-04 \\
#                 $d_{PR,ink}/d_{PR,sup}$ &        0.05 &   1.13 &  5.21 &           0.32 &        3.2e-05 \\
# 		\hline
#               $\bm{d_{Est}/d_{PR,ink}}$ & $\bm{0.18}$ &  -5.59 & -3.37 &   $\bm{-0.63}$ & $\bm{8.1e-20}$ \\
#                    $d_{Est}/d_{PR,sup}$ &        0.00 &   0.36 &  5.90 &          -0.10 &        1.9e-01 \\
#  $d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}$ &        0.03 &  -1.23 &  1.74 &          -0.37 &        9.9e-07 \\
# $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$ &        0.05 &  -1.13 &  5.21 &          -0.32 &        3.3e-05 \\
# 		\hline
#                              $We_{ink}$ &        0.03 &  -2.05 & -0.50 &          -0.23 &        3.2e-03 \\
#                              $We_{sup}$ &        0.04 &   2.15 & 11.07 &           0.03 &        7.2e-01 \\
#                      $We_{ink}We_{sup}$ &        0.00 &   0.06 &  5.69 &          -0.11 &        1.8e-01 \\
#                     $We_{ink}/We_{sup}$ &        0.41 & -11.32 &  2.87 &          -0.39 &        3.4e-07 \\
# 		\hline
#                              $Oh_{ink}$ &        0.07 &  -6.13 & 11.47 &          -0.46 &        4.2e-10 \\
#                              $Oh_{sup}$ &        0.00 &  -0.39 &  5.96 &          -0.12 &        1.3e-01 \\
#                      $Oh_{ink}Oh_{sup}$ &        0.03 &  -1.68 &  9.52 &          -0.28 &        2.5e-04 \\
#                     $Oh_{ink}/Oh_{sup}$ &        0.01 &  -0.75 &  5.04 &          -0.13 &        8.9e-02 \\
# 		\hline
#                              $Re_{ink}$ &        0.00 &   0.79 &  7.31 &           0.08 &        3.0e-01 \\
#                              $Re_{sup}$ &        0.01 &   0.86 &  7.80 &           0.04 &        6.3e-01 \\
#                      $Re_{ink}Re_{sup}$ &        0.01 &   0.66 &  8.84 &           0.06 &        4.4e-01 \\
#                     $Re_{ink}/Re_{sup}$ &        0.01 &  -0.66 &  5.63 &           0.01 &        9.1e-01 \\
# 		\hline
#                              $Bm_{ink}$ &        0.02 &  -5.60 & -0.91 &          -0.31 &        4.8e-05 \\
#                              $Bm_{sup}$ &        0.02 &   1.62 &  7.62 &           0.23 &        3.2e-03 \\
#                      $Bm_{ink}Bm_{sup}$ &        0.01 &   1.31 &  8.68 &           0.02 &        7.5e-01 \\
#                     $Bm_{ink}/Bm_{sup}$ &        0.02 &  -1.64 &  5.80 &          -0.25 &        1.4e-03 \\
# 		\hline
#                            $\eta_{ink}$ &        0.01 &  -2.31 &  5.18 &          -0.15 &        5.8e-02 \\
#                            $\eta_{sup}$ &        0.00 &   0.25 &  5.27 &           0.04 &        6.0e-01 \\
#                  $\eta_{ink}\eta_{sup}$ &        0.00 &  -0.13 &  5.45 &          -0.03 &        6.8e-01 \\
#                 $\eta_{ink}/\eta_{sup}$ &        0.01 &  -0.77 &  4.94 &          -0.14 &        8.3e-02 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\horiz_segments_manualRegNonZero.tex
# ---------------------------
#
#
# INFO: All horiz_segments_manual values the same for zero surface tension
# \begin{table}
# \centering
# \caption[Linear regressions for horizontal line roughness at nonzero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{horizontal line roughness} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:horiz_roughnessRegNonZero}
# \begin{tabular}{llrrll}
#                               variables &       $r^2$ &     b &    c & spearman coeff &     spearman p \\
#                               $\bm{Ca}$ & $\bm{0.00}$ & -0.00 & 0.01 &    $\bm{0.68}$ & $\bm{1.2e-20}$ \\
#                              $Ca_{ink}$ &        0.00 &  0.00 & 0.01 &          -0.02 &        8.6e-01 \\
#                         $\bm{Ca_{sup}}$ & $\bm{0.00}$ &  0.00 & 0.01 &    $\bm{0.62}$ & $\bm{1.9e-16}$ \\
#                      $Ca_{ink}Ca_{sup}$ &        0.00 &  0.00 & 0.01 &           0.53 &        1.1e-11 \\
#                     $Ca_{ink}/Ca_{sup}$ &        0.00 &  0.00 & 0.01 &          -0.57 &        2.2e-13 \\
# 		\hline
#                            $d_{PR,ink}$ &        0.00 & -0.00 & 0.01 &           0.05 &        5.4e-01 \\
#                       $\bm{d_{PR,sup}}$ & $\bm{0.00}$ & -0.00 & 0.01 &   $\bm{-0.65}$ & $\bm{9.5e-19}$ \\
#                  $d_{PR,ink}d_{PR,sup}$ &        0.00 & -0.00 & 0.01 &          -0.52 &        3.6e-11 \\
#                 $d_{PR,ink}/d_{PR,sup}$ &        0.00 &  0.00 & 0.01 &           0.58 &        6.9e-14 \\
# 		\hline
#                    $d_{Est}/d_{PR,ink}$ &        0.00 &  0.00 & 0.01 &           0.03 &        6.8e-01 \\
#               $\bm{d_{Est}/d_{PR,sup}}$ & $\bm{0.00}$ &  0.00 & 0.01 &    $\bm{0.70}$ & $\bm{4.8e-22}$ \\
#  $d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}$ &        0.00 &  0.00 & 0.01 &           0.59 &        9.2e-15 \\
# $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$ &        0.00 & -0.00 & 0.01 &          -0.58 &        6.6e-14 \\
# 		\hline
#                              $We_{ink}$ &        0.00 & -0.00 & 0.00 &           0.16 &        5.5e-02 \\
#                              $We_{sup}$ &        0.00 &  0.00 & 0.01 &           0.05 &        5.8e-01 \\
#                      $We_{ink}We_{sup}$ &        0.00 & -0.00 & 0.01 &           0.13 &        1.1e-01 \\
#                     $We_{ink}/We_{sup}$ &        0.00 & -0.00 & 0.01 &           0.04 &        6.6e-01 \\
# 		\hline
#                              $Oh_{ink}$ &        0.00 &  0.00 & 0.00 &          -0.17 &        4.9e-02 \\
#                         $\bm{Oh_{sup}}$ & $\bm{0.00}$ & -0.00 & 0.01 &    $\bm{0.63}$ & $\bm{7.8e-17}$ \\
#                      $Oh_{ink}Oh_{sup}$ &        0.00 &  0.00 & 0.01 &           0.45 &        1.5e-08 \\
#                $\bm{Oh_{ink}/Oh_{sup}}$ & $\bm{0.00}$ &  0.00 & 0.01 &   $\bm{-0.64}$ & $\bm{8.7e-18}$ \\
# 		\hline
#                              $Re_{ink}$ &        0.00 & -0.00 & 0.00 &           0.18 &        3.0e-02 \\
#                              $Re_{sup}$ &        0.00 &  0.00 & 0.01 &          -0.49 &        4.2e-10 \\
#                      $Re_{ink}Re_{sup}$ &        0.00 & -0.00 & 0.01 &          -0.28 &        7.5e-04 \\
#                $\bm{Re_{ink}/Re_{sup}}$ & $\bm{0.00}$ & -0.00 & 0.01 &    $\bm{0.63}$ & $\bm{4.7e-17}$ \\
# 		\hline
#                              $Bm_{ink}$ &        0.01 &  0.01 & 0.02 &          -0.11 &        2.0e-01 \\
#                         $\bm{Bm_{sup}}$ & $\bm{0.00}$ &  0.00 & 0.01 &    $\bm{0.53}$ & $\bm{1.7e-11}$ \\
#                      $Bm_{ink}Bm_{sup}$ &        0.00 &  0.00 & 0.01 &           0.30 &        2.8e-04 \\
#                     $Bm_{ink}/Bm_{sup}$ &        0.00 & -0.00 & 0.01 &          -0.41 &        3.8e-07 \\
# 		\hline
#                            $\eta_{ink}$ &        0.01 &  0.01 & 0.01 &          -0.15 &        8.3e-02 \\
#                            $\eta_{sup}$ &        0.00 &  0.00 & 0.01 &           0.56 &        5.7e-13 \\
#                  $\eta_{ink}\eta_{sup}$ &        0.00 &  0.00 & 0.01 &           0.35 &        2.0e-05 \\
#            $\bm{\eta_{ink}/\eta_{sup}}$ & $\bm{0.00}$ &  0.00 & 0.01 &   $\bm{-0.64}$ & $\bm{9.9e-18}$ \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\horiz_roughnessRegNonZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for horizontal line roughness at zero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{horizontal line roughness} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:horiz_roughnessRegZero}
# \begin{tabular}{llrrll}
#               variables & $r^2$ &     b &     c & spearman coeff & spearman p \\
#              $Re_{ink}$ &  0.00 & -0.02 &  0.27 &          -0.07 &    4.7e-01 \\
#              $Re_{sup}$ &  0.09 & -0.12 & -0.01 &          -0.37 &    4.2e-05 \\
#      $Re_{ink}Re_{sup}$ &  0.05 & -0.05 &  0.03 &          -0.26 &    5.2e-03 \\
#     $Re_{ink}/Re_{sup}$ &  0.04 &  0.07 &  0.31 &           0.16 &    9.1e-02 \\
# 		\hline
#              $Bm_{ink}$ &  0.00 & -0.04 &  0.28 &          -0.01 &    8.7e-01 \\
#              $Bm_{sup}$ &  0.10 &  1.10 &  1.62 &           0.33 &    2.8e-04 \\
#      $Bm_{ink}Bm_{sup}$ &  0.00 & -0.01 &  0.29 &           0.14 &    1.4e-01 \\
#     $Bm_{ink}/Bm_{sup}$ &  0.01 & -0.06 &  0.31 &          -0.14 &    1.2e-01 \\
# 		\hline
#            $\eta_{ink}$ &  0.00 &  0.02 &  0.32 &           0.06 &    5.1e-01 \\
#            $\eta_{sup}$ &  0.14 &  0.22 &  0.19 &           0.37 &    3.4e-05 \\
#  $\eta_{ink}\eta_{sup}$ &  0.08 &  0.11 &  0.23 &           0.29 &    1.5e-03 \\
# $\eta_{ink}/\eta_{sup}$ &  0.06 & -0.11 &  0.28 &          -0.21 &    2.3e-02 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\horiz_roughnessRegZero.tex
# ---------------------------
