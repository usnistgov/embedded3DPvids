# %% [markdown]
# # statistical analysis of metrics

# %% [markdown]
# Leanne Friedrich 10/08/21

# %% [markdown]
# ## initialization

# %%
# %load_ext autoreload
# %autoreload 2
LOGGERDEFINED = False

# %%
import os
import sys
sys.path.append("../")
from py.config import cfg
import py.logs as logs
import py.metrics as me
from printVals import *
from plainIm import plainIm
import matplotlib.pyplot as plt
import metricPlots as mp
import regression as rg
import matplotlib.cm as cm
LOGGERDEFINED = logs.openLog('vidSummaries.ipynb', LOGGERDEFINED, level='DEBUG', exportLog=False)

# %% [markdown]
# ## analyzing data

# %%
ss,u = me.importStillsSummary(diag=True)
seg, useg = me.importStillsSummary(file='segmentsSummary.csv', diag=False)
ss = ss.merge(seg[['folder', 'horiz_segments']], on='folder', suffixes=['', '_manual'], how='left')
# Out:
# Independents: ['folder', 'bn', 'date', 'sigma', 'di', 'do', 'fluFile', 'calibFile', 'viscRatio', 'vRatio', 'ReRatio', 'rGrav', 'dEst', 'hDragP', 'vDragP', 'int_CaInv', 'int_Re', 'pressureCh0', 'ink_shortname', 'ink_days', 'ink_rheModifier', 'ink_surfactant', 'ink_dye', 'ink_var', 'ink_val', 'ink_base', 'ink_type', 'ink_tau0', 'ink_eta0', 'ink_density', 'ink_v', 'ink_rate', 'ink_visc0', 'ink_CaInv', 'ink_Re', 'ink_WeInv', 'ink_OhInv', 'ink_dPR', 'ink_dnormInv', 'ink_Bm', 'sup_shortname', 'sup_days', 'sup_rheModifier', 'sup_surfactant', 'sup_dye', 'sup_var', 'sup_val', 'sup_base', 'sup_type', 'sup_tau0', 'sup_eta0', 'sup_density', 'sup_v', 'sup_rate', 'sup_visc0', 'sup_CaInv', 'sup_Re', 'sup_WeInv', 'sup_OhInv', 'sup_dPR', 'sup_dnormInv', 'sup_Bm', 'sup_Ca', 'ink_Ca', 'sweepType', 'sup_dnorm', 'ink_dnorm', 'sup_We', 'ink_We', 'sup_Oh', 'ink_Oh', 'int_Ca']
#
# Dependents: ['xs_aspect', 'xs_xshift', 'xs_yshift', 'xs_area', 'xs_areaN', 'xs_wN', 'xs_hN', 'xs_roughness', 'vert_wN', 'vert_hN', 'vert_vN', 'vert_vintegral', 'vert_viN', 'vert_vleak', 'vert_vleakN', 'vert_roughness', 'vert_meanTN', 'vert_stdevTN', 'vert_minmaxTN', 'horiz_segments', 'horiz_maxlenN', 'horiz_totlenN', 'horiz_vN', 'horiz_roughness', 'horiz_meanTN', 'horiz_stdevTN', 'horiz_minmaxTN', 'vHorizEst']

# %%
vs,uv = me.importStillsSummary(file='videoSummary.csv', diag=True)
# Out:
# Independents: ['folder', 'bn', 'date', 'sigma', 'di', 'do', 'fluFile', 'calibFile', 'viscRatio', 'vRatio', 'ReRatio', 'rGrav', 'dEst', 'hDragP', 'vDragP', 'int_CaInv', 'int_Re', 'pressureCh0', 'ink_shortname', 'ink_days', 'ink_rheModifier', 'ink_surfactant', 'ink_dye', 'ink_var', 'ink_val', 'ink_base', 'ink_type', 'ink_tau0', 'ink_eta0', 'ink_density', 'ink_v', 'ink_rate', 'ink_visc0', 'ink_CaInv', 'ink_Re', 'ink_WeInv', 'ink_OhInv', 'ink_dPR', 'ink_dnormInv', 'ink_Bm', 'sup_shortname', 'sup_days', 'sup_rheModifier', 'sup_surfactant', 'sup_dye', 'sup_var', 'sup_val', 'sup_base', 'sup_type', 'sup_tau0', 'sup_eta0', 'sup_density', 'sup_v', 'sup_rate', 'sup_visc0', 'sup_CaInv', 'sup_Re', 'sup_WeInv', 'sup_OhInv', 'sup_dPR', 'sup_dnormInv', 'sup_Bm', 'sup_Ca', 'ink_Ca', 'sweepType', 'sup_dnorm', 'ink_dnorm', 'sup_We', 'ink_We', 'sup_Oh', 'ink_Oh', 'int_Ca']
#
# Dependents: ['projectionN', 'projShiftN', 'vertDispBotN', 'vertDispTopN', 'vertDispMidN']

# %% [markdown]
# ## regression tables

# %%
xsregs = mp.regressionTable(ss, 'xs_aspect', nickname = 'cross-section aspect ratio', printOut=True, export=True)
varlist = [('vert_meanTN', 'normalized vertical line thickness'), 
           ('vert_hN', 'normalized vertical line length'), 
           ('vert_stdevTN', 'normalized vertical line thickness variation')]
vertregs = [mp.regressionTable(ss, i[0], nickname=i[1], logy=False, export=True, printOut=True) for i in varlist]
varlist = [('horiz_totlenN', 'normalized horizontal line total length', False),
           ('horiz_maxlenN', 'normalized horizontal line max segment length', False),
          ('horiz_segments_manual', 'number of horizontal line segments', False),
           ('horiz_roughness', 'horizontal line roughness', False)]
horizregs = [mp.regressionTable(ss, i[0], nickname=i[1], export=True, printOut=True, logy=i[2]) for i in varlist]
# Out:
# \begin{table}
# \centering
# \caption[Linear regressions for cross-section aspect ratio at nonzero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{cross-section aspect ratio} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:xs_aspectRegNonZero}
# \begin{tabular}{llrrll}
#                                   variables &       $r^2$ &     b &     c & spearman coeff &     spearman p \\
#                                   $\bm{Ca}$ & $\bm{0.33}$ &  0.10 &  0.10 &    $\bm{0.67}$ & $\bm{1.1e-27}$ \\
#                                  $Ca_{ink}$ &        0.04 &  0.05 &  0.14 &           0.25 &        3.3e-04 \\
#                             $\bm{Ca_{sup}}$ & $\bm{0.26}$ &  0.10 &  0.10 &    $\bm{0.61}$ & $\bm{3.9e-22}$ \\
#                          $Ca_{ink}Ca_{sup}$ &        0.28 &  0.08 &  0.14 &           0.59 &        1.7e-20 \\
#                         $Ca_{ink}/Ca_{sup}$ &        0.07 & -0.04 &  0.10 &          -0.31 &        5.4e-06 \\
# 		\hline
#                                $d_{PR,ink}$ &        0.03 & -0.04 &  0.17 &          -0.17 &        1.4e-02 \\
#                           $\bm{d_{PR,sup}}$ & $\bm{0.13}$ & -0.04 &  0.16 &   $\bm{-0.54}$ & $\bm{9.0e-17}$ \\
#                 $\bm{d_{PR,ink}d_{PR,sup}}$ & $\bm{0.22}$ & -0.05 &  0.25 &   $\bm{-0.55}$ & $\bm{2.2e-17}$ \\
#                     $d_{PR,ink}/d_{PR,sup}$ &        0.04 &  0.02 &  0.12 &           0.29 &        3.0e-05 \\
# 		\hline
#                        $d_{Est}/d_{PR,ink}$ &        0.05 &  0.05 &  0.19 &           0.26 &        2.1e-04 \\
#                   $\bm{d_{Est}/d_{PR,sup}}$ & $\bm{0.15}$ &  0.04 &  0.18 &    $\bm{0.60}$ & $\bm{6.1e-21}$ \\
# $\bm{d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}}$ & $\bm{0.27}$ &  0.06 &  0.28 &    $\bm{0.62}$ & $\bm{2.2e-22}$ \\
#     $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$ &        0.04 & -0.02 &  0.12 &          -0.29 &        3.1e-05 \\
# 		\hline
#                                  $We_{ink}$ &        0.05 &  0.04 &  0.23 &           0.25 &        4.1e-04 \\
#                                  $We_{sup}$ &        0.00 &  0.01 &  0.15 &           0.12 &        8.3e-02 \\
#                          $We_{ink}We_{sup}$ &        0.02 &  0.01 &  0.19 &           0.22 &        1.6e-03 \\
#                         $We_{ink}/We_{sup}$ &        0.08 &  0.08 &  0.14 &           0.09 &        2.3e-01 \\
# 		\hline
#                                  $Oh_{ink}$ &        0.00 &  0.02 &  0.10 &           0.06 &        4.2e-01 \\
#                             $\bm{Oh_{sup}}$ & $\bm{0.17}$ &  0.07 &  0.01 &    $\bm{0.53}$ & $\bm{6.0e-16}$ \\
#                          $Oh_{ink}Oh_{sup}$ &        0.17 &  0.07 & -0.04 &           0.47 &        1.5e-12 \\
#                         $Oh_{ink}/Oh_{sup}$ &        0.11 & -0.05 &  0.10 &          -0.43 &        1.8e-10 \\
# 		\hline
#                                  $Re_{ink}$ &        0.02 &  0.03 &  0.19 &           0.15 &        3.6e-02 \\
#                                  $Re_{sup}$ &        0.08 & -0.04 &  0.01 &          -0.29 &        2.5e-05 \\
#                          $Re_{ink}Re_{sup}$ &        0.03 & -0.02 &  0.03 &          -0.17 &        1.6e-02 \\
#                         $Re_{ink}/Re_{sup}$ &        0.14 &  0.05 &  0.10 &           0.48 &        5.0e-13 \\
# 		\hline
#                                  $Bm_{ink}$ &        0.00 &  0.03 &  0.16 &           0.08 &        2.3e-01 \\
#                                  $Bm_{sup}$ &        0.02 &  0.03 &  0.16 &           0.25 &        3.0e-04 \\
#                          $Bm_{ink}Bm_{sup}$ &        0.03 &  0.03 &  0.20 &           0.18 &        9.3e-03 \\
#                         $Bm_{ink}/Bm_{sup}$ &        0.01 & -0.02 &  0.12 &          -0.18 &        1.1e-02 \\
# 		\hline
#                                $\eta_{ink}$ &        0.01 & -0.03 &  0.12 &          -0.13 &        6.5e-02 \\
#                                $\eta_{sup}$ &        0.08 &  0.04 &  0.10 &           0.30 &        1.6e-05 \\
#                      $\eta_{ink}\eta_{sup}$ &        0.04 &  0.02 &  0.11 &           0.19 &        7.6e-03 \\
#                     $\eta_{ink}/\eta_{sup}$ &        0.11 & -0.05 &  0.09 &          -0.43 &        2.2e-10 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\xs_aspectRegNonZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for cross-section aspect ratio at zero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{cross-section aspect ratio} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:xs_aspectRegZero}
# \begin{tabular}{llrrll}
#                    variables &       $r^2$ &     b &     c & spearman coeff &     spearman p \\
#                   $Re_{ink}$ &        0.21 &  0.14 &  0.62 &           0.45 &        2.9e-07 \\
#                   $Re_{sup}$ &        0.24 & -0.15 & -0.17 &          -0.52 &        2.8e-09 \\
#           $Re_{ink}Re_{sup}$ &        0.00 & -0.00 &  0.24 &           0.01 &        9.2e-01 \\
#     $\bm{Re_{ink}/Re_{sup}}$ & $\bm{0.62}$ &  0.20 &  0.20 &    $\bm{0.78}$ & $\bm{2.6e-25}$ \\
# 		\hline
#                   $Bm_{ink}$ &        0.11 & -0.13 &  0.08 &          -0.51 &        3.7e-09 \\
#                   $Bm_{sup}$ &        0.14 &  1.00 &  1.43 &           0.47 &        1.1e-07 \\
#           $Bm_{ink}Bm_{sup}$ &        0.08 & -0.11 & -0.02 &          -0.12 &        2.0e-01 \\
#     $\bm{Bm_{ink}/Bm_{sup}}$ & $\bm{0.15}$ & -0.15 &  0.23 &   $\bm{-0.58}$ & $\bm{8.5e-12}$ \\
# 		\hline
#                 $\eta_{ink}$ &        0.25 & -0.22 &  0.30 &          -0.48 &        4.7e-08 \\
#                 $\eta_{sup}$ &        0.34 &  0.26 &  0.09 &           0.57 &        1.4e-11 \\
#       $\eta_{ink}\eta_{sup}$ &        0.00 &  0.01 &  0.24 &           0.05 &        6.1e-01 \\
# $\bm{\eta_{ink}/\eta_{sup}}$ & $\bm{0.64}$ & -0.27 &  0.15 &   $\bm{-0.80}$ & $\bm{2.1e-27}$ \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\xs_aspectRegZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized vertical line thickness at nonzero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized vertical line thickness} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:vert_meanTNRegNonZero}
# \begin{tabular}{llrrll}
#                                   variables &       $r^2$ &     b &    c & spearman coeff &     spearman p \\
#                                   $\bm{Ca}$ & $\bm{0.68}$ & -0.66 & 1.38 &   $\bm{-0.87}$ & $\bm{2.2e-62}$ \\
#                                  $Ca_{ink}$ &        0.07 & -0.28 & 1.14 &          -0.25 &        3.2e-04 \\
#                             $\bm{Ca_{sup}}$ & $\bm{0.59}$ & -0.65 & 1.37 &   $\bm{-0.83}$ & $\bm{3.5e-52}$ \\
#                     $\bm{Ca_{ink}Ca_{sup}}$ & $\bm{0.60}$ & -0.52 & 1.13 &   $\bm{-0.79}$ & $\bm{8.3e-44}$ \\
#                         $Ca_{ink}/Ca_{sup}$ &        0.20 &  0.30 & 1.44 &           0.45 &        2.6e-11 \\
# 		\hline
#                                $d_{PR,ink}$ &        0.06 &  0.21 & 0.98 &           0.21 &        2.3e-03 \\
#                           $\bm{d_{PR,sup}}$ & $\bm{0.38}$ &  0.29 & 0.93 &    $\bm{0.74}$ & $\bm{1.7e-36}$ \\
#                 $\bm{d_{PR,ink}d_{PR,sup}}$ & $\bm{0.58}$ &  0.37 & 0.35 &    $\bm{0.79}$ & $\bm{5.6e-44}$ \\
#                     $d_{PR,ink}/d_{PR,sup}$ &        0.15 & -0.14 & 1.29 &          -0.39 &        1.1e-08 \\
# 		\hline
#                        $d_{Est}/d_{PR,ink}$ &        0.08 & -0.25 & 0.87 &          -0.29 &        2.7e-05 \\
#                   $\bm{d_{Est}/d_{PR,sup}}$ & $\bm{0.41}$ & -0.30 & 0.85 &   $\bm{-0.80}$ & $\bm{3.2e-45}$ \\
# $\bm{d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}}$ & $\bm{0.64}$ & -0.38 & 0.15 &   $\bm{-0.85}$ & $\bm{5.8e-56}$ \\
#     $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$ &        0.15 &  0.14 & 1.29 &           0.39 &        1.1e-08 \\
# 		\hline
#                                  $We_{ink}$ &        0.04 & -0.16 & 0.81 &          -0.18 &        9.3e-03 \\
#                                  $We_{sup}$ &        0.00 & -0.03 & 1.18 &          -0.12 &        9.4e-02 \\
#                          $We_{ink}We_{sup}$ &        0.02 & -0.05 & 0.98 &          -0.16 &        2.1e-02 \\
#                         $We_{ink}/We_{sup}$ &        0.08 & -0.39 & 1.18 &          -0.04 &        6.0e-01 \\
# 		\hline
#                                  $Oh_{ink}$ &        0.02 & -0.24 & 1.50 &          -0.15 &        3.3e-02 \\
#                             $\bm{Oh_{sup}}$ & $\bm{0.44}$ & -0.50 & 2.00 &   $\bm{-0.75}$ & $\bm{7.8e-38}$ \\
#                     $\bm{Oh_{ink}Oh_{sup}}$ & $\bm{0.48}$ & -0.49 & 2.47 &   $\bm{-0.72}$ & $\bm{2.2e-33}$ \\
#                         $Oh_{ink}/Oh_{sup}$ &        0.26 &  0.33 & 1.42 &           0.54 &        1.3e-16 \\
# 		\hline
#                                  $Re_{ink}$ &        0.00 & -0.05 & 1.15 &          -0.06 &        3.7e-01 \\
#                                  $Re_{sup}$ &        0.24 &  0.28 & 2.04 &           0.44 &        5.6e-11 \\
#                          $Re_{ink}Re_{sup}$ &        0.13 &  0.16 & 2.09 &           0.32 &        3.8e-06 \\
#                    $\bm{Re_{ink}/Re_{sup}}$ & $\bm{0.29}$ & -0.33 & 1.39 &   $\bm{-0.58}$ & $\bm{3.9e-19}$ \\
# 		\hline
#                                  $Bm_{ink}$ &        0.01 & -0.33 & 0.90 &          -0.13 &        6.8e-02 \\
#                                  $Bm_{sup}$ &        0.11 & -0.29 & 0.87 &          -0.36 &        1.3e-07 \\
#                          $Bm_{ink}Bm_{sup}$ &        0.15 & -0.34 & 0.41 &          -0.35 &        4.0e-07 \\
#                         $Bm_{ink}/Bm_{sup}$ &        0.08 &  0.21 & 1.21 &           0.20 &        3.8e-03 \\
# 		\hline
#                                $\eta_{ink}$ &        0.00 & -0.01 & 1.26 &           0.04 &        5.5e-01 \\
#                                $\eta_{sup}$ &        0.23 & -0.29 & 1.41 &          -0.45 &        3.7e-11 \\
#                      $\eta_{ink}\eta_{sup}$ &        0.15 & -0.19 & 1.34 &          -0.34 &        7.2e-07 \\
#                $\bm{\eta_{ink}/\eta_{sup}}$ & $\bm{0.26}$ &  0.33 & 1.46 &    $\bm{0.54}$ & $\bm{1.2e-16}$ \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\vert_meanTNRegNonZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized vertical line thickness at zero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized vertical line thickness} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:vert_meanTNRegZero}
# \begin{tabular}{llrrll}
#                    variables &       $r^2$ &     b &    c & spearman coeff &     spearman p \\
#                   $Re_{ink}$ &        0.15 & -0.17 & 0.14 &          -0.39 &        1.8e-05 \\
#                   $Re_{sup}$ &        0.04 &  0.09 & 0.83 &           0.38 &        4.4e-05 \\
#           $Re_{ink}Re_{sup}$ &        0.02 & -0.03 & 0.40 &          -0.04 &        6.7e-01 \\
#     $\bm{Re_{ink}/Re_{sup}}$ & $\bm{0.23}$ & -0.17 & 0.63 &   $\bm{-0.62}$ & $\bm{2.2e-13}$ \\
# 		\hline
#                   $Bm_{ink}$ &        0.03 &  0.10 & 0.73 &           0.38 &        3.9e-05 \\
#                   $Bm_{sup}$ &        0.00 & -0.09 & 0.48 &          -0.14 &        1.4e-01 \\
#           $Bm_{ink}Bm_{sup}$ &        0.03 &  0.10 & 0.84 &           0.23 &        1.4e-02 \\
#          $Bm_{ink}/Bm_{sup}$ &        0.03 &  0.10 & 0.61 &           0.39 &        2.0e-05 \\
# 		\hline
#                 $\eta_{ink}$ &        0.18 &  0.28 & 0.53 &           0.41 &        5.5e-06 \\
#                 $\eta_{sup}$ &        0.02 & -0.09 & 0.65 &          -0.34 &        2.3e-04 \\
#       $\eta_{ink}\eta_{sup}$ &        0.04 &  0.09 & 0.52 &           0.07 &        4.8e-01 \\
# $\bm{\eta_{ink}/\eta_{sup}}$ & $\bm{0.17}$ &  0.19 & 0.67 &    $\bm{0.57}$ & $\bm{5.3e-11}$ \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\vert_meanTNRegZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized vertical line length at nonzero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized vertical line length} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:vert_hNRegNonZero}
# \begin{tabular}{llrrll}
#                                   variables &       $r^2$ &     b &     c & spearman coeff &     spearman p \\
#                                   $\bm{Ca}$ & $\bm{0.66}$ &  0.50 &  0.50 &    $\bm{0.86}$ & $\bm{2.2e-59}$ \\
#                                  $Ca_{ink}$ &        0.05 &  0.19 &  0.67 &           0.23 &        8.6e-04 \\
#                             $\bm{Ca_{sup}}$ & $\bm{0.54}$ &  0.47 &  0.51 &    $\bm{0.80}$ & $\bm{1.4e-46}$ \\
#                          $Ca_{ink}Ca_{sup}$ &        0.54 &  0.38 &  0.68 &           0.76 &        2.2e-39 \\
#                         $Ca_{ink}/Ca_{sup}$ &        0.19 & -0.22 &  0.45 &          -0.44 &        7.1e-11 \\
# 		\hline
#                                $d_{PR,ink}$ &        0.04 & -0.13 &  0.76 &          -0.18 &        8.8e-03 \\
#                           $\bm{d_{PR,sup}}$ & $\bm{0.31}$ & -0.20 &  0.82 &   $\bm{-0.71}$ & $\bm{7.8e-32}$ \\
#                 $\bm{d_{PR,ink}d_{PR,sup}}$ & $\bm{0.45}$ & -0.25 &  1.20 &   $\bm{-0.73}$ & $\bm{4.1e-34}$ \\
#                     $d_{PR,ink}/d_{PR,sup}$ &        0.13 &  0.10 &  0.57 &           0.39 &        1.6e-08 \\
# 		\hline
#                        $d_{Est}/d_{PR,ink}$ &        0.06 &  0.17 &  0.85 &           0.26 &        1.5e-04 \\
#                   $\bm{d_{Est}/d_{PR,sup}}$ & $\bm{0.34}$ &  0.21 &  0.87 &    $\bm{0.77}$ & $\bm{5.7e-40}$ \\
# $\bm{d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}}$ & $\bm{0.53}$ &  0.26 &  1.36 &    $\bm{0.78}$ & $\bm{9.8e-43}$ \\
#     $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$ &        0.13 & -0.10 &  0.57 &          -0.39 &        1.4e-08 \\
# 		\hline
#                                  $We_{ink}$ &        0.09 &  0.17 &  1.07 &           0.28 &        7.7e-05 \\
#                                  $We_{sup}$ &        0.01 &  0.05 &  0.71 &           0.19 &        5.9e-03 \\
#                          $We_{ink}We_{sup}$ &        0.04 &  0.06 &  0.91 &           0.26 &        2.2e-04 \\
#                         $We_{ink}/We_{sup}$ &        0.13 &  0.38 &  0.67 &           0.02 &        7.3e-01 \\
# 		\hline
#                                  $Oh_{ink}$ &        0.00 &  0.03 &  0.55 &           0.04 &        6.1e-01 \\
#                             $\bm{Oh_{sup}}$ & $\bm{0.37}$ &  0.35 &  0.07 &    $\bm{0.70}$ & $\bm{6.8e-31}$ \\
#                          $Oh_{ink}Oh_{sup}$ &        0.34 &  0.32 & -0.20 &           0.61 &        3.7e-22 \\
#                         $Oh_{ink}/Oh_{sup}$ &        0.27 & -0.26 &  0.46 &          -0.55 &        5.1e-17 \\
# 		\hline
#                                  $Re_{ink}$ &        0.04 &  0.16 &  0.96 &           0.21 &        2.4e-03 \\
#                                  $Re_{sup}$ &        0.19 & -0.19 &  0.06 &          -0.38 &        1.9e-08 \\
#                          $Re_{ink}Re_{sup}$ &        0.07 & -0.09 &  0.13 &          -0.21 &        3.5e-03 \\
#                    $\bm{Re_{ink}/Re_{sup}}$ & $\bm{0.32}$ &  0.26 &  0.49 &    $\bm{0.59}$ & $\bm{3.3e-20}$ \\
# 		\hline
#                                  $Bm_{ink}$ &        0.00 &  0.02 &  0.61 &           0.03 &        6.6e-01 \\
#                                  $Bm_{sup}$ &        0.07 &  0.17 &  0.82 &           0.31 &        7.8e-06 \\
#                          $Bm_{ink}Bm_{sup}$ &        0.08 &  0.19 &  1.05 &           0.24 &        6.7e-04 \\
#                         $Bm_{ink}/Bm_{sup}$ &        0.05 & -0.13 &  0.62 &          -0.22 &        2.0e-03 \\
# 		\hline
#                                $\eta_{ink}$ &        0.03 & -0.17 &  0.57 &          -0.18 &        1.0e-02 \\
#                                $\eta_{sup}$ &        0.17 &  0.19 &  0.49 &           0.39 &        1.4e-08 \\
#                      $\eta_{ink}\eta_{sup}$ &        0.08 &  0.10 &  0.54 &           0.24 &        6.3e-04 \\
#                $\bm{\eta_{ink}/\eta_{sup}}$ & $\bm{0.27}$ & -0.26 &  0.43 &   $\bm{-0.55}$ & $\bm{4.3e-17}$ \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\vert_hNRegNonZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized vertical line length at zero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized vertical line length} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:vert_hNRegZero}
# \begin{tabular}{llrrll}
#               variables & $r^2$ &     b &     c & spearman coeff & spearman p \\
#              $Re_{ink}$ &  0.00 &  0.03 &  1.35 &           0.11 &    2.7e-01 \\
#              $Re_{sup}$ &  0.00 &  0.00 &  1.27 &          -0.11 &    2.3e-01 \\
#      $Re_{ink}Re_{sup}$ &  0.00 &  0.02 &  1.34 &           0.02 &    8.0e-01 \\
#     $Re_{ink}/Re_{sup}$ &  0.00 &  0.02 &  1.26 &           0.18 &    6.2e-02 \\
# 		\hline
#              $Bm_{ink}$ &  0.03 & -0.14 &  1.07 &          -0.38 &    3.2e-05 \\
#              $Bm_{sup}$ &  0.03 & -1.11 & -0.05 &          -0.38 &    3.2e-05 \\
#      $Bm_{ink}Bm_{sup}$ &  0.04 & -0.16 &  0.85 &          -0.43 &    2.8e-06 \\
#     $Bm_{ink}/Bm_{sup}$ &  0.02 & -0.11 &  1.24 &          -0.33 &    3.5e-04 \\
# 		\hline
#            $\eta_{ink}$ &  0.06 & -0.26 &  1.32 &          -0.29 &    1.7e-03 \\
#            $\eta_{sup}$ &  0.02 & -0.15 &  1.35 &          -0.02 &    8.7e-01 \\
#  $\eta_{ink}\eta_{sup}$ &  0.07 & -0.19 &  1.42 &          -0.22 &    2.1e-02 \\
# $\eta_{ink}/\eta_{sup}$ &  0.01 & -0.06 &  1.24 &          -0.21 &    2.6e-02 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\vert_hNRegZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized vertical line thickness variation at nonzero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized vertical line thickness variation} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:vert_stdevTNRegNonZero}
# \begin{tabular}{llrrll}
#                               variables & $r^2$ &     b &    c & spearman coeff & spearman p \\
#                                    $Ca$ &  0.02 &  0.00 & 0.00 &           0.32 &    4.7e-06 \\
#                              $Ca_{ink}$ &  0.00 &  0.00 & 0.00 &           0.17 &    1.9e-02 \\
#                              $Ca_{sup}$ &  0.08 &  0.00 & 0.00 &           0.39 &    1.4e-08 \\
#                      $Ca_{ink}Ca_{sup}$ &  0.06 &  0.00 & 0.00 &           0.46 &    9.8e-12 \\
#                     $Ca_{ink}/Ca_{sup}$ &  0.04 & -0.00 & 0.00 &          -0.27 &    1.3e-04 \\
# 		\hline
#                            $d_{PR,ink}$ &  0.00 & -0.00 & 0.00 &          -0.14 &    4.4e-02 \\
#                            $d_{PR,sup}$ &  0.05 & -0.00 & 0.00 &          -0.42 &    7.8e-10 \\
#                  $d_{PR,ink}d_{PR,sup}$ &  0.05 & -0.00 & 0.00 &          -0.41 &    1.3e-09 \\
#                 $d_{PR,ink}/d_{PR,sup}$ &  0.03 &  0.00 & 0.00 &           0.25 &    3.7e-04 \\
# 		\hline
#                    $d_{Est}/d_{PR,ink}$ &  0.00 & -0.00 & 0.00 &           0.08 &    2.5e-01 \\
#                    $d_{Est}/d_{PR,sup}$ &  0.03 &  0.00 & 0.00 &           0.34 &    7.0e-07 \\
#  $d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}$ &  0.02 &  0.00 & 0.00 &           0.34 &    7.0e-07 \\
# $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$ &  0.03 & -0.00 & 0.00 &          -0.25 &    3.8e-04 \\
# 		\hline
#                              $We_{ink}$ &  0.01 &  0.00 & 0.00 &           0.11 &    1.1e-01 \\
#                              $We_{sup}$ &  0.11 &  0.00 & 0.00 &           0.35 &    3.0e-07 \\
#                      $We_{ink}We_{sup}$ &  0.04 &  0.00 & 0.00 &           0.26 &    2.6e-04 \\
#                     $We_{ink}/We_{sup}$ &  0.23 & -0.00 & 0.00 &          -0.30 &    1.7e-05 \\
# 		\hline
#                              $Oh_{ink}$ &  0.00 & -0.00 & 0.00 &           0.14 &    4.1e-02 \\
#                              $Oh_{sup}$ &  0.01 &  0.00 & 0.00 &           0.24 &    8.3e-04 \\
#                      $Oh_{ink}Oh_{sup}$ &  0.00 &  0.00 & 0.00 &           0.25 &    2.8e-04 \\
#                     $Oh_{ink}/Oh_{sup}$ &  0.01 & -0.00 & 0.00 &          -0.17 &    1.8e-02 \\
# 		\hline
#                              $Re_{ink}$ &  0.00 &  0.00 & 0.00 &           0.01 &    8.9e-01 \\
#                              $Re_{sup}$ &  0.00 &  0.00 & 0.00 &          -0.02 &    7.9e-01 \\
#                      $Re_{ink}Re_{sup}$ &  0.01 &  0.00 & 0.00 &          -0.01 &    9.1e-01 \\
#                     $Re_{ink}/Re_{sup}$ &  0.00 & -0.00 & 0.00 &           0.10 &    1.8e-01 \\
# 		\hline
#                              $Bm_{ink}$ &  0.00 & -0.00 & 0.00 &           0.09 &    2.2e-01 \\
#                              $Bm_{sup}$ &  0.01 &  0.00 & 0.00 &           0.30 &    2.3e-05 \\
#                      $Bm_{ink}Bm_{sup}$ &  0.01 &  0.00 & 0.00 &           0.17 &    1.9e-02 \\
#                     $Bm_{ink}/Bm_{sup}$ &  0.01 & -0.00 & 0.00 &          -0.13 &    7.8e-02 \\
# 		\hline
#                            $\eta_{ink}$ &  0.00 & -0.00 & 0.00 &          -0.02 &    8.0e-01 \\
#                            $\eta_{sup}$ &  0.00 &  0.00 & 0.00 &           0.12 &    9.4e-02 \\
#                  $\eta_{ink}\eta_{sup}$ &  0.00 &  0.00 & 0.00 &           0.06 &    4.0e-01 \\
#                 $\eta_{ink}/\eta_{sup}$ &  0.01 & -0.00 & 0.00 &          -0.17 &    1.8e-02 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\vert_stdevTNRegNonZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized vertical line thickness variation at zero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized vertical line thickness variation} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:vert_stdevTNRegZero}
# \begin{tabular}{llrrll}
#               variables & $r^2$ &     b &    c & spearman coeff & spearman p \\
#              $Re_{ink}$ &  0.00 &  0.00 & 0.00 &          -0.03 &    7.7e-01 \\
#              $Re_{sup}$ &  0.15 &  0.00 & 0.01 &           0.32 &    6.0e-04 \\
#      $Re_{ink}Re_{sup}$ &  0.07 &  0.00 & 0.01 &           0.18 &    5.7e-02 \\
#     $Re_{ink}/Re_{sup}$ &  0.08 & -0.00 & 0.00 &          -0.30 &    1.3e-03 \\
# 		\hline
#              $Bm_{ink}$ &  0.02 & -0.00 & 0.00 &          -0.12 &    2.0e-01 \\
#              $Bm_{sup}$ &  0.00 & -0.00 & 0.00 &          -0.09 &    3.3e-01 \\
#      $Bm_{ink}Bm_{sup}$ &  0.02 & -0.00 & 0.00 &          -0.16 &    9.3e-02 \\
#     $Bm_{ink}/Bm_{sup}$ &  0.02 & -0.00 & 0.00 &          -0.12 &    1.9e-01 \\
# 		\hline
#            $\eta_{ink}$ &  0.01 & -0.00 & 0.00 &          -0.05 &    5.8e-01 \\
#            $\eta_{sup}$ &  0.07 & -0.00 & 0.00 &          -0.26 &    5.0e-03 \\
#  $\eta_{ink}\eta_{sup}$ &  0.06 & -0.00 & 0.00 &          -0.21 &    2.6e-02 \\
# $\eta_{ink}/\eta_{sup}$ &  0.01 &  0.00 & 0.00 &           0.13 &    1.6e-01 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\vert_stdevTNRegZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized horizontal line total length at nonzero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized horizontal line total length} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:horiz_totlenNRegNonZero}
# \begin{tabular}{llrrll}
#                                   variables &       $r^2$ &     b &    c & spearman coeff &     spearman p \\
#                                   $\bm{Ca}$ & $\bm{0.56}$ &  0.35 & 0.60 &    $\bm{0.83}$ & $\bm{1.8e-38}$ \\
#                                  $Ca_{ink}$ &        0.07 &  0.20 & 0.75 &           0.25 &        2.4e-03 \\
#                             $\bm{Ca_{sup}}$ & $\bm{0.39}$ &  0.31 & 0.61 &    $\bm{0.75}$ & $\bm{2.0e-27}$ \\
#                     $\bm{Ca_{ink}Ca_{sup}}$ & $\bm{0.54}$ &  0.34 & 0.78 &    $\bm{0.78}$ & $\bm{8.6e-31}$ \\
#                         $Ca_{ink}/Ca_{sup}$ &        0.12 & -0.14 & 0.56 &          -0.39 &        1.5e-06 \\
# 		\hline
#                                $d_{PR,ink}$ &        0.04 & -0.13 & 0.83 &          -0.17 &        3.7e-02 \\
#                           $\bm{d_{PR,sup}}$ & $\bm{0.18}$ & -0.12 & 0.79 &   $\bm{-0.63}$ & $\bm{2.9e-17}$ \\
#                 $\bm{d_{PR,ink}d_{PR,sup}}$ & $\bm{0.33}$ & -0.18 & 1.11 &   $\bm{-0.67}$ & $\bm{4.5e-20}$ \\
#                     $d_{PR,ink}/d_{PR,sup}$ &        0.07 &  0.06 & 0.63 &           0.38 &        2.3e-06 \\
# 		\hline
#                        $d_{Est}/d_{PR,ink}$ &        0.10 &  0.19 & 0.96 &           0.33 &        6.0e-05 \\
#                   $\bm{d_{Est}/d_{PR,sup}}$ & $\bm{0.22}$ &  0.13 & 0.83 &    $\bm{0.73}$ & $\bm{2.1e-25}$ \\
# $\bm{d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}}$ & $\bm{0.44}$ &  0.20 & 1.26 &    $\bm{0.79}$ & $\bm{5.9e-32}$ \\
#     $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$ &        0.07 & -0.06 & 0.63 &          -0.38 &        2.1e-06 \\
# 		\hline
#                                  $We_{ink}$ &        0.08 &  0.13 & 1.04 &           0.27 &        1.1e-03 \\
#                                  $We_{sup}$ &        0.00 & -0.02 & 0.59 &           0.01 &        8.6e-01 \\
#                          $We_{ink}We_{sup}$ &        0.02 &  0.03 & 0.82 &           0.15 &        6.9e-02 \\
#                         $We_{ink}/We_{sup}$ &        0.22 &  0.33 & 0.72 &           0.25 &        2.6e-03 \\
# 		\hline
#                                  $Oh_{ink}$ &        0.00 &  0.04 & 0.61 &           0.01 &        9.1e-01 \\
#                             $\bm{Oh_{sup}}$ & $\bm{0.32}$ &  0.25 & 0.27 &    $\bm{0.70}$ & $\bm{1.5e-22}$ \\
#                          $Oh_{ink}Oh_{sup}$ &        0.32 &  0.24 & 0.07 &           0.60 &        9.6e-16 \\
#                         $Oh_{ink}/Oh_{sup}$ &        0.22 & -0.18 & 0.55 &          -0.58 &        1.3e-14 \\
# 		\hline
#                                  $Re_{ink}$ &        0.02 &  0.09 & 0.86 &           0.19 &        2.0e-02 \\
#                                  $Re_{sup}$ &        0.21 & -0.15 & 0.21 &          -0.51 &        4.3e-11 \\
#                          $Re_{ink}Re_{sup}$ &        0.08 & -0.07 & 0.26 &          -0.30 &        2.4e-04 \\
#                    $\bm{Re_{ink}/Re_{sup}}$ & $\bm{0.31}$ &  0.19 & 0.57 &    $\bm{0.64}$ & $\bm{2.1e-18}$ \\
# 		\hline
#                                  $Bm_{ink}$ &        0.00 &  0.01 & 0.65 &          -0.02 &        8.4e-01 \\
#                                  $Bm_{sup}$ &        0.02 &  0.08 & 0.75 &           0.34 &        3.4e-05 \\
#                          $Bm_{ink}Bm_{sup}$ &        0.02 &  0.08 & 0.85 &           0.20 &        1.8e-02 \\
#                         $Bm_{ink}/Bm_{sup}$ &        0.02 & -0.06 & 0.66 &          -0.27 &        1.0e-03 \\
# 		\hline
#                                $\eta_{ink}$ &        0.01 & -0.08 & 0.64 &          -0.15 &        7.9e-02 \\
#                                $\eta_{sup}$ &        0.17 &  0.15 & 0.56 &           0.52 &        2.3e-11 \\
#                      $\eta_{ink}\eta_{sup}$ &        0.09 &  0.09 & 0.60 &           0.34 &        2.7e-05 \\
#                $\bm{\eta_{ink}/\eta_{sup}}$ & $\bm{0.22}$ & -0.18 & 0.53 &   $\bm{-0.58}$ & $\bm{1.8e-14}$ \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\horiz_totlenNRegNonZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized horizontal line total length at zero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized horizontal line total length} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:horiz_totlenNRegZero}
# \begin{tabular}{llrrll}
#               variables & $r^2$ &     b &    c & spearman coeff & spearman p \\
#              $Re_{ink}$ &  0.00 & -0.02 & 0.96 &           0.00 &    9.8e-01 \\
#              $Re_{sup}$ &  0.04 & -0.06 & 0.85 &          -0.19 &    4.3e-02 \\
#      $Re_{ink}Re_{sup}$ &  0.03 & -0.03 & 0.86 &          -0.07 &    4.5e-01 \\
#     $Re_{ink}/Re_{sup}$ &  0.01 &  0.02 & 1.00 &           0.11 &    2.6e-01 \\
# 		\hline
#              $Bm_{ink}$ &  0.06 & -0.08 & 0.90 &          -0.19 &    4.5e-02 \\
#              $Bm_{sup}$ &  0.06 & -0.50 & 0.42 &          -0.36 &    1.2e-04 \\
#      $Bm_{ink}Bm_{sup}$ &  0.08 & -0.09 & 0.78 &          -0.31 &    9.8e-04 \\
#     $Bm_{ink}/Bm_{sup}$ &  0.04 & -0.07 & 0.99 &          -0.14 &    1.6e-01 \\
# 		\hline
#            $\eta_{ink}$ &  0.01 & -0.03 & 1.02 &          -0.14 &    1.5e-01 \\
#            $\eta_{sup}$ &  0.00 & -0.01 & 1.01 &           0.01 &    9.3e-01 \\
#  $\eta_{ink}\eta_{sup}$ &  0.01 & -0.02 & 1.03 &          -0.11 &    2.7e-01 \\
# $\eta_{ink}/\eta_{sup}$ &  0.00 & -0.02 & 1.00 &          -0.10 &    3.0e-01 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\horiz_totlenNRegZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized horizontal line max segment length at nonzero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized horizontal line max segment length} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:horiz_maxlenNRegNonZero}
# \begin{tabular}{llrrll}
#                                   variables &       $r^2$ &     b &     c & spearman coeff &     spearman p \\
#                                   $\bm{Ca}$ & $\bm{0.47}$ &  0.38 &  0.54 &    $\bm{0.76}$ & $\bm{2.9e-29}$ \\
#                                  $Ca_{ink}$ &        0.12 &  0.32 &  0.75 &           0.36 &        9.3e-06 \\
#                                  $Ca_{sup}$ &        0.29 &  0.32 &  0.55 &           0.66 &        1.2e-19 \\
#                     $\bm{Ca_{ink}Ca_{sup}}$ & $\bm{0.49}$ &  0.39 &  0.74 &    $\bm{0.75}$ & $\bm{4.0e-27}$ \\
#                         $Ca_{ink}/Ca_{sup}$ &        0.06 & -0.11 &  0.52 &          -0.24 &        3.4e-03 \\
# 		\hline
#                                $d_{PR,ink}$ &        0.08 & -0.21 &  0.89 &          -0.27 &        1.2e-03 \\
#                                $d_{PR,sup}$ &        0.13 & -0.12 &  0.73 &          -0.53 &        8.1e-12 \\
#                 $\bm{d_{PR,ink}d_{PR,sup}}$ & $\bm{0.29}$ & -0.20 &  1.10 &   $\bm{-0.62}$ & $\bm{6.2e-17}$ \\
#                     $d_{PR,ink}/d_{PR,sup}$ &        0.03 &  0.05 &  0.58 &           0.24 &        3.3e-03 \\
# 		\hline
#                        $d_{Est}/d_{PR,ink}$ &        0.16 &  0.28 &  1.06 &           0.44 &        3.9e-08 \\
#                        $d_{Est}/d_{PR,sup}$ &        0.17 &  0.14 &  0.78 &           0.65 &        1.5e-18 \\
# $\bm{d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}}$ & $\bm{0.42}$ &  0.23 &  1.29 &    $\bm{0.76}$ & $\bm{3.5e-29}$ \\
#     $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$ &        0.03 & -0.05 &  0.58 &          -0.24 &        3.1e-03 \\
# 		\hline
#                                  $We_{ink}$ &        0.08 &  0.16 &  1.07 &           0.27 &        1.1e-03 \\
#                                  $We_{sup}$ &        0.01 & -0.04 &  0.47 &          -0.04 &        6.1e-01 \\
#                          $We_{ink}We_{sup}$ &        0.01 &  0.03 &  0.77 &           0.12 &        1.4e-01 \\
#                         $We_{ink}/We_{sup}$ &        0.30 &  0.45 &  0.69 &           0.35 &        1.8e-05 \\
# 		\hline
#                                  $Oh_{ink}$ &        0.02 &  0.15 &  0.45 &           0.11 &        1.9e-01 \\
#                             $\bm{Oh_{sup}}$ & $\bm{0.26}$ &  0.26 &  0.20 &    $\bm{0.62}$ & $\bm{4.7e-17}$ \\
#                     $\bm{Oh_{ink}Oh_{sup}}$ & $\bm{0.30}$ &  0.27 & -0.07 &    $\bm{0.58}$ & $\bm{2.3e-14}$ \\
#                         $Oh_{ink}/Oh_{sup}$ &        0.15 & -0.17 &  0.50 &          -0.47 &        1.8e-09 \\
# 		\hline
#                                  $Re_{ink}$ &        0.01 &  0.07 &  0.76 &           0.14 &        9.9e-02 \\
#                                  $Re_{sup}$ &        0.18 & -0.17 &  0.11 &          -0.46 &        3.8e-09 \\
#                          $Re_{ink}Re_{sup}$ &        0.08 & -0.09 &  0.14 &          -0.29 &        3.8e-04 \\
#                    $\bm{Re_{ink}/Re_{sup}}$ & $\bm{0.24}$ &  0.20 &  0.51 &    $\bm{0.56}$ & $\bm{1.3e-13}$ \\
# 		\hline
#                                  $Bm_{ink}$ &        0.00 &  0.09 &  0.69 &           0.04 &        6.0e-01 \\
#                                  $Bm_{sup}$ &        0.01 &  0.07 &  0.68 &           0.24 &        3.6e-03 \\
#                          $Bm_{ink}Bm_{sup}$ &        0.02 &  0.08 &  0.79 &           0.17 &        3.8e-02 \\
#                         $Bm_{ink}/Bm_{sup}$ &        0.01 & -0.05 &  0.60 &          -0.19 &        2.2e-02 \\
# 		\hline
#                                $\eta_{ink}$ &        0.00 & -0.02 &  0.59 &          -0.07 &        4.2e-01 \\
#                                $\eta_{sup}$ &        0.13 &  0.16 &  0.50 &           0.45 &        1.2e-08 \\
#                      $\eta_{ink}\eta_{sup}$ &        0.08 &  0.10 &  0.54 &           0.32 &        6.7e-05 \\
#                     $\eta_{ink}/\eta_{sup}$ &        0.15 & -0.17 &  0.48 &          -0.47 &        2.4e-09 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\horiz_maxlenNRegNonZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for normalized horizontal line max segment length at zero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{normalized horizontal line max segment length} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:horiz_maxlenNRegZero}
# \begin{tabular}{llrrll}
#               variables & $r^2$ &     b &    c & spearman coeff & spearman p \\
#              $Re_{ink}$ &  0.01 & -0.02 & 0.94 &          -0.01 &    8.8e-01 \\
#              $Re_{sup}$ &  0.03 & -0.05 & 0.85 &          -0.18 &    6.4e-02 \\
#      $Re_{ink}Re_{sup}$ &  0.03 & -0.03 & 0.84 &          -0.08 &    4.4e-01 \\
#     $Re_{ink}/Re_{sup}$ &  0.00 &  0.01 & 1.00 &           0.09 &    3.7e-01 \\
# 		\hline
#              $Bm_{ink}$ &  0.05 & -0.07 & 0.90 &          -0.16 &    9.2e-02 \\
#              $Bm_{sup}$ &  0.06 & -0.55 & 0.35 &          -0.37 &    6.2e-05 \\
#      $Bm_{ink}Bm_{sup}$ &  0.07 & -0.08 & 0.79 &          -0.30 &    1.8e-03 \\
#     $Bm_{ink}/Bm_{sup}$ &  0.03 & -0.06 & 0.99 &          -0.10 &    3.0e-01 \\
# 		\hline
#            $\eta_{ink}$ &  0.00 & -0.02 & 1.01 &          -0.11 &    2.4e-01 \\
#            $\eta_{sup}$ &  0.00 & -0.01 & 1.01 &          -0.01 &    9.4e-01 \\
#  $\eta_{ink}\eta_{sup}$ &  0.00 & -0.02 & 1.01 &          -0.10 &    3.0e-01 \\
# $\eta_{ink}/\eta_{sup}$ &  0.00 & -0.01 & 1.00 &          -0.07 &    4.7e-01 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\horiz_maxlenNRegZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for number of horizontal line segments at nonzero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{number of horizontal line segments} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:horiz_segments_manualRegNonZero}
# \begin{tabular}{llrrll}
#                               variables &       $r^2$ &      b &     c & spearman coeff &     spearman p \\
#                                    $Ca$ &        0.02 &  -1.54 &  5.62 &          -0.26 &        8.5e-04 \\
#                         $\bm{Ca_{ink}}$ & $\bm{0.12}$ &  -5.66 &  2.89 &   $\bm{-0.59}$ & $\bm{6.2e-17}$ \\
#                              $Ca_{sup}$ &        0.01 &   0.92 &  5.26 &          -0.18 &        2.4e-02 \\
#                      $Ca_{ink}Ca_{sup}$ &        0.02 &  -1.57 &  4.92 &          -0.40 &        8.3e-08 \\
#                     $Ca_{ink}/Ca_{sup}$ &        0.06 &  -2.37 &  4.01 &          -0.31 &        4.4e-05 \\
# 		\hline
#                       $\bm{d_{PR,ink}}$ & $\bm{0.10}$ &   4.18 & -0.25 &    $\bm{0.52}$ & $\bm{5.4e-13}$ \\
#                            $d_{PR,sup}$ &        0.01 &  -0.77 &  6.31 &           0.01 &        9.1e-01 \\
#                  $d_{PR,ink}d_{PR,sup}$ &        0.00 &   0.36 &  4.48 &           0.26 &        8.1e-04 \\
#                 $d_{PR,ink}/d_{PR,sup}$ &        0.05 &   1.13 &  5.21 &           0.32 &        3.2e-05 \\
# 		\hline
#               $\bm{d_{Est}/d_{PR,ink}}$ & $\bm{0.18}$ &  -5.59 & -3.37 &   $\bm{-0.63}$ & $\bm{8.1e-20}$ \\
#                    $d_{Est}/d_{PR,sup}$ &        0.00 &   0.36 &  5.90 &          -0.10 &        1.9e-01 \\
#  $d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}$ &        0.03 &  -1.23 &  1.74 &          -0.37 &        9.9e-07 \\
# $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$ &        0.05 &  -1.13 &  5.21 &          -0.32 &        3.3e-05 \\
# 		\hline
#                              $We_{ink}$ &        0.03 &  -2.05 & -0.50 &          -0.23 &        3.2e-03 \\
#                              $We_{sup}$ &        0.04 &   2.15 & 11.07 &           0.03 &        7.2e-01 \\
#                      $We_{ink}We_{sup}$ &        0.00 &   0.06 &  5.69 &          -0.11 &        1.8e-01 \\
#                     $We_{ink}/We_{sup}$ &        0.41 & -11.32 &  2.87 &          -0.39 &        3.4e-07 \\
# 		\hline
#                              $Oh_{ink}$ &        0.07 &  -6.13 & 11.47 &          -0.46 &        4.2e-10 \\
#                              $Oh_{sup}$ &        0.00 &  -0.39 &  5.96 &          -0.12 &        1.3e-01 \\
#                      $Oh_{ink}Oh_{sup}$ &        0.03 &  -1.68 &  9.52 &          -0.28 &        2.5e-04 \\
#                     $Oh_{ink}/Oh_{sup}$ &        0.01 &  -0.75 &  5.04 &          -0.13 &        8.9e-02 \\
# 		\hline
#                              $Re_{ink}$ &        0.00 &   0.79 &  7.31 &           0.08 &        3.0e-01 \\
#                              $Re_{sup}$ &        0.01 &   0.86 &  7.80 &           0.04 &        6.3e-01 \\
#                      $Re_{ink}Re_{sup}$ &        0.01 &   0.66 &  8.84 &           0.06 &        4.4e-01 \\
#                     $Re_{ink}/Re_{sup}$ &        0.01 &  -0.66 &  5.63 &           0.01 &        9.1e-01 \\
# 		\hline
#                              $Bm_{ink}$ &        0.02 &  -5.60 & -0.91 &          -0.31 &        4.8e-05 \\
#                              $Bm_{sup}$ &        0.02 &   1.62 &  7.62 &           0.23 &        3.2e-03 \\
#                      $Bm_{ink}Bm_{sup}$ &        0.01 &   1.31 &  8.68 &           0.02 &        7.5e-01 \\
#                     $Bm_{ink}/Bm_{sup}$ &        0.02 &  -1.64 &  5.80 &          -0.25 &        1.4e-03 \\
# 		\hline
#                            $\eta_{ink}$ &        0.01 &  -2.31 &  5.18 &          -0.15 &        5.8e-02 \\
#                            $\eta_{sup}$ &        0.00 &   0.25 &  5.27 &           0.04 &        6.0e-01 \\
#                  $\eta_{ink}\eta_{sup}$ &        0.00 &  -0.13 &  5.45 &          -0.03 &        6.8e-01 \\
#                 $\eta_{ink}/\eta_{sup}$ &        0.01 &  -0.77 &  4.94 &          -0.14 &        8.3e-02 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\horiz_segments_manualRegNonZero.tex
# ---------------------------
#
#
# INFO: All horiz_segments_manual values the same for zero surface tension
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for horizontal line roughness at nonzero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{horizontal line roughness} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:horiz_roughnessRegNonZero}
# \begin{tabular}{llrrll}
#                                   variables &       $r^2$ &     b &     c & spearman coeff &     spearman p \\
#                                   $\bm{Ca}$ & $\bm{0.00}$ &  0.00 &  0.01 &    $\bm{0.69}$ & $\bm{5.8e-22}$ \\
#                                  $Ca_{ink}$ &        0.00 &  0.00 &  0.01 &           0.07 &        3.9e-01 \\
#                                  $Ca_{sup}$ &        0.00 & -0.00 &  0.01 &           0.59 &        6.0e-15 \\
#                          $Ca_{ink}Ca_{sup}$ &        0.00 &  0.00 &  0.01 &           0.53 &        5.5e-12 \\
#                         $Ca_{ink}/Ca_{sup}$ &        0.00 &  0.00 &  0.01 &          -0.45 &        1.4e-08 \\
# 		\hline
#                                $d_{PR,ink}$ &        0.00 & -0.00 &  0.01 &          -0.01 &        9.2e-01 \\
#                           $\bm{d_{PR,sup}}$ & $\bm{0.00}$ &  0.00 &  0.01 &   $\bm{-0.58}$ & $\bm{9.3e-15}$ \\
#                      $d_{PR,ink}d_{PR,sup}$ &        0.00 & -0.00 &  0.01 &          -0.48 &        9.3e-10 \\
#                     $d_{PR,ink}/d_{PR,sup}$ &        0.00 & -0.00 &  0.01 &           0.48 &        9.2e-10 \\
# 		\hline
#                        $d_{Est}/d_{PR,ink}$ &        0.01 &  0.00 &  0.01 &           0.15 &        7.5e-02 \\
#                   $\bm{d_{Est}/d_{PR,sup}}$ & $\bm{0.00}$ &  0.00 &  0.01 &    $\bm{0.67}$ & $\bm{1.5e-20}$ \\
# $\bm{d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}}$ & $\bm{0.00}$ &  0.00 &  0.01 &    $\bm{0.61}$ & $\bm{3.8e-16}$ \\
#     $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$ &        0.00 &  0.00 &  0.01 &          -0.48 &        7.9e-10 \\
# 		\hline
#                                  $We_{ink}$ &        0.00 & -0.00 &  0.00 &           0.21 &        1.2e-02 \\
#                                  $We_{sup}$ &        0.01 & -0.00 & -0.00 &          -0.03 &        7.5e-01 \\
#                          $We_{ink}We_{sup}$ &        0.00 & -0.00 & -0.00 &           0.11 &        1.8e-01 \\
#                         $We_{ink}/We_{sup}$ &        0.01 &  0.00 &  0.01 &           0.16 &        6.1e-02 \\
# 		\hline
#                                  $Oh_{ink}$ &        0.01 &  0.01 & -0.00 &          -0.13 &        1.2e-01 \\
#                             $\bm{Oh_{sup}}$ & $\bm{0.00}$ &  0.00 &  0.00 &    $\bm{0.61}$ & $\bm{1.6e-16}$ \\
#                          $Oh_{ink}Oh_{sup}$ &        0.00 &  0.00 &  0.00 &           0.45 &        1.2e-08 \\
#                    $\bm{Oh_{ink}/Oh_{sup}}$ & $\bm{0.00}$ &  0.00 &  0.01 &   $\bm{-0.61}$ & $\bm{1.6e-16}$ \\
# 		\hline
#                                  $Re_{ink}$ &        0.01 & -0.00 & -0.00 &           0.19 &        2.2e-02 \\
#                                  $Re_{sup}$ &        0.00 & -0.00 &  0.00 &          -0.50 &        9.3e-11 \\
#                          $Re_{ink}Re_{sup}$ &        0.01 & -0.00 & -0.00 &          -0.28 &        6.0e-04 \\
#                    $\bm{Re_{ink}/Re_{sup}}$ & $\bm{0.00}$ &  0.00 &  0.01 &    $\bm{0.65}$ & $\bm{3.7e-19}$ \\
# 		\hline
#                                  $Bm_{ink}$ &        0.01 &  0.02 &  0.03 &          -0.09 &        2.8e-01 \\
#                                  $Bm_{sup}$ &        0.00 &  0.00 &  0.01 &           0.43 &        6.0e-08 \\
#                          $Bm_{ink}Bm_{sup}$ &        0.00 &  0.00 &  0.01 &           0.25 &        2.2e-03 \\
#                         $Bm_{ink}/Bm_{sup}$ &        0.00 &  0.00 &  0.01 &          -0.37 &        4.9e-06 \\
# 		\hline
#                                $\eta_{ink}$ &        0.01 &  0.01 &  0.01 &          -0.13 &        1.1e-01 \\
#                                $\eta_{sup}$ &        0.00 &  0.00 &  0.00 &           0.54 &        1.2e-12 \\
#                      $\eta_{ink}\eta_{sup}$ &        0.01 &  0.00 &  0.00 &           0.34 &        2.0e-05 \\
#                $\bm{\eta_{ink}/\eta_{sup}}$ & $\bm{0.00}$ &  0.00 &  0.01 &   $\bm{-0.61}$ & $\bm{2.2e-16}$ \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\horiz_roughnessRegNonZero.tex
# ---------------------------
#
#
# \begin{table}
# \centering
# \caption[Linear regressions for horizontal line roughness at zero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{horizontal line roughness} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:horiz_roughnessRegZero}
# \begin{tabular}{llrrll}
#                    variables &       $r^2$ &     b &     c & spearman coeff &     spearman p \\
#                   $Re_{ink}$ &        0.05 &  0.07 &  0.35 &           0.23 &        1.6e-02 \\
#              $\bm{Re_{sup}}$ & $\bm{0.34}$ & -0.21 & -0.43 &   $\bm{-0.64}$ & $\bm{8.3e-14}$ \\
#           $Re_{ink}Re_{sup}$ &        0.03 & -0.04 & -0.04 &          -0.22 &        2.3e-02 \\
#     $\bm{Re_{ink}/Re_{sup}}$ & $\bm{0.40}$ &  0.17 &  0.12 &    $\bm{0.66}$ & $\bm{5.7e-15}$ \\
# 		\hline
#                   $Bm_{ink}$ &        0.08 & -0.11 &  0.01 &          -0.40 &        1.5e-05 \\
#                   $Bm_{sup}$ &        0.29 &  1.40 &  1.81 &           0.44 &        1.7e-06 \\
#           $Bm_{ink}Bm_{sup}$ &        0.04 & -0.08 & -0.03 &          -0.04 &        6.9e-01 \\
#     $\bm{Bm_{ink}/Bm_{sup}}$ & $\bm{0.13}$ & -0.15 &  0.14 &   $\bm{-0.60}$ & $\bm{7.8e-12}$ \\
# 		\hline
#                 $\eta_{ink}$ &        0.11 & -0.14 &  0.20 &          -0.29 &        2.6e-03 \\
#            $\bm{\eta_{sup}}$ & $\bm{0.44}$ &  0.32 & -0.05 &    $\bm{0.74}$ & $\bm{7.5e-20}$ \\
#       $\eta_{ink}\eta_{sup}$ &        0.03 &  0.06 &  0.12 &           0.24 &        1.4e-02 \\
# $\bm{\eta_{ink}/\eta_{sup}}$ & $\bm{0.53}$ & -0.25 &  0.06 &   $\bm{-0.76}$ & $\bm{2.2e-21}$ \\
# 		\hline
# \end{tabular}
# \end{table}
#
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\regressions\horiz_roughnessRegZero.tex
# ---------------------------

# %%
mp.regressionTable(vs, 'vertDispBotN', nickname='bottom position', export=False, printOut=True, logy=False)
# Out:
# \begin{table}
# \centering
# \caption[Linear regressions for bottom position at nonzero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{bottom position} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:vertDispBotNRegNonZero}
# \begin{tabular}{llrrll}
#                               variables & $r^2$ &     b &     c & spearman coeff & spearman p \\
#                                    $Ca$ &  0.00 & -0.02 &  0.39 &           0.02 &    8.1e-01 \\
#                              $Ca_{ink}$ &  0.09 & -0.35 &  0.24 &          -0.26 &    1.5e-04 \\
#                              $Ca_{sup}$ &  0.00 &  0.06 &  0.37 &           0.13 &    7.3e-02 \\
#                      $Ca_{ink}Ca_{sup}$ &  0.02 & -0.09 &  0.36 &          -0.05 &    4.7e-01 \\
#                     $Ca_{ink}/Ca_{sup}$ &  0.06 & -0.17 &  0.28 &          -0.27 &    1.0e-04 \\
# 		\hline
#                            $d_{PR,ink}$ &  0.07 &  0.25 &  0.06 &           0.19 &    7.3e-03 \\
#                            $d_{PR,sup}$ &  0.02 & -0.07 &  0.46 &          -0.20 &    4.2e-03 \\
#                  $d_{PR,ink}d_{PR,sup}$ &  0.00 &  0.00 &  0.38 &          -0.09 &    1.8e-01 \\
#                 $d_{PR,ink}/d_{PR,sup}$ &  0.05 &  0.08 &  0.37 &           0.21 &    2.2e-03 \\
# 		\hline
#                    $d_{Est}/d_{PR,ink}$ &  0.10 & -0.29 & -0.06 &          -0.28 &    4.0e-05 \\
#                    $d_{Est}/d_{PR,sup}$ &  0.01 &  0.05 &  0.46 &           0.11 &    1.3e-01 \\
#  $d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}$ &  0.00 & -0.03 &  0.30 &          -0.00 &    9.9e-01 \\
# $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$ &  0.05 & -0.08 &  0.37 &          -0.21 &    2.3e-03 \\
# 		\hline
#                              $We_{ink}$ &  0.02 & -0.13 &  0.03 &          -0.13 &    5.9e-02 \\
#                              $We_{sup}$ &  0.00 &  0.01 &  0.42 &           0.13 &    7.4e-02 \\
#                      $We_{ink}We_{sup}$ &  0.01 & -0.03 &  0.22 &           0.02 &    7.6e-01 \\
#                     $We_{ink}/We_{sup}$ &  0.09 & -0.43 &  0.29 &          -0.40 &    2.6e-09 \\
# 		\hline
#                              $Oh_{ink}$ &  0.07 & -0.45 &  0.83 &          -0.21 &    3.3e-03 \\
#                              $Oh_{sup}$ &  0.00 &  0.04 &  0.32 &           0.08 &    2.4e-01 \\
#                      $Oh_{ink}Oh_{sup}$ &  0.01 & -0.05 &  0.52 &           0.04 &    5.5e-01 \\
#                     $Oh_{ink}/Oh_{sup}$ &  0.03 & -0.11 &  0.33 &          -0.14 &    4.4e-02 \\
# 		\hline
#                              $Re_{ink}$ &  0.01 &  0.09 &  0.60 &           0.04 &    6.0e-01 \\
#                              $Re_{sup}$ &  0.00 & -0.02 &  0.33 &          -0.03 &    6.4e-01 \\
#                      $Re_{ink}Re_{sup}$ &  0.00 &  0.00 &  0.40 &          -0.04 &    6.2e-01 \\
#                     $Re_{ink}/Re_{sup}$ &  0.01 &  0.05 &  0.37 &           0.08 &    2.9e-01 \\
# 		\hline
#                              $Bm_{ink}$ &  0.00 & -0.17 &  0.19 &          -0.04 &    6.1e-01 \\
#                              $Bm_{sup}$ &  0.03 &  0.16 &  0.60 &           0.16 &    2.7e-02 \\
#                      $Bm_{ink}Bm_{sup}$ &  0.03 &  0.16 &  0.79 &           0.20 &    4.0e-03 \\
#                     $Bm_{ink}/Bm_{sup}$ &  0.03 & -0.14 &  0.42 &          -0.09 &    1.8e-01 \\
# 		\hline
#                            $\eta_{ink}$ &  0.04 & -0.28 &  0.36 &          -0.09 &    2.1e-01 \\
#                            $\eta_{sup}$ &  0.00 &  0.04 &  0.36 &           0.06 &    3.8e-01 \\
#                  $\eta_{ink}\eta_{sup}$ &  0.00 & -0.01 &  0.39 &           0.02 &    7.9e-01 \\
#                 $\eta_{ink}/\eta_{sup}$ &  0.03 & -0.11 &  0.32 &          -0.14 &    4.2e-02 \\
# 		\hline
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption[Linear regressions for bottom position at zero surface tension]{Table of linear regressions of log-scaled variables and Spearman rank correlations for \textbf{bottom position} at non-zero surface tension. For example, ${Re}_{ink}$ indicates a regression fit to $h/w = 10^c*Re_{ink}^b$. A Spearman rank correlation coefficient of -1 or 1 indicates a strong correlation. Variables are defined in table \ref{tab:variableDefs}.}
# \label{tab:vertDispBotNRegZero}
# \begin{tabular}{llrrll}
#               variables & $r^2$ &     b &     c & spearman coeff & spearman p \\
#              $Re_{ink}$ &  0.03 & -0.12 &  0.13 &          -0.17 &    8.2e-02 \\
#              $Re_{sup}$ &  0.08 &  0.21 &  1.02 &           0.24 &    1.4e-02 \\
#      $Re_{ink}Re_{sup}$ &  0.00 &  0.03 &  0.61 &           0.00 &    9.6e-01 \\
#     $Re_{ink}/Re_{sup}$ &  0.14 & -0.23 &  0.49 &          -0.37 &    1.4e-04 \\
# 		\hline
#              $Bm_{ink}$ &  0.07 & -0.25 &  0.10 &          -0.12 &    2.1e-01 \\
#              $Bm_{sup}$ &  0.01 &  0.50 &  1.02 &           0.01 &    9.2e-01 \\
#      $Bm_{ink}Bm_{sup}$ &  0.06 & -0.23 & -0.15 &          -0.07 &    4.8e-01 \\
#     $Bm_{ink}/Bm_{sup}$ &  0.07 & -0.26 &  0.39 &          -0.24 &    1.5e-02 \\
# 		\hline
#            $\eta_{ink}$ &  0.00 & -0.02 &  0.45 &           0.00 &    9.8e-01 \\
#            $\eta_{sup}$ &  0.03 & -0.20 &  0.56 &          -0.17 &    8.6e-02 \\
#  $\eta_{ink}\eta_{sup}$ &  0.02 & -0.10 &  0.52 &          -0.09 &    3.6e-01 \\
# $\eta_{ink}/\eta_{sup}$ &  0.01 &  0.10 &  0.47 &           0.15 &    1.4e-01 \\
# 		\hline
# \end{tabular}
# \end{table}
# [                                 variables $r^2$         b     c  \
#  0                                     $Ca$  0.00 -2.02e-02  0.39
#  1                               $Ca_{ink}$  0.09 -3.50e-01  0.24
#  2                               $Ca_{sup}$  0.00  5.98e-02  0.37
#  3                       $Ca_{ink}Ca_{sup}$  0.02 -9.06e-02  0.36
#  4                      $Ca_{ink}/Ca_{sup}$  0.06 -1.66e-01  0.28
#  0                             $d_{PR,ink}$  0.07  2.47e-01  0.06
#  1                             $d_{PR,sup}$  0.02 -6.62e-02  0.46
#  2                   $d_{PR,ink}d_{PR,sup}$  0.00  1.95e-03  0.38
#  3                  $d_{PR,ink}/d_{PR,sup}$  0.05  8.45e-02  0.37
#  0                     $d_{Est}/d_{PR,ink}$  0.10 -2.88e-01 -0.06
#  1                     $d_{Est}/d_{PR,sup}$  0.01  5.27e-02  0.46
#  2   $d_{Est}/d_{PR,ink}d_{Est}/d_{PR,sup}$  0.00 -2.81e-02  0.30
#  3  $d_{Est}/d_{PR,ink}/d_{Est}/d_{PR,sup}$  0.05 -8.45e-02  0.37
#  0                               $We_{ink}$  0.02 -1.25e-01  0.03
#  1                               $We_{sup}$  0.00  1.42e-02  0.42
#  2                       $We_{ink}We_{sup}$  0.01 -2.93e-02  0.22
#  3                      $We_{ink}/We_{sup}$  0.09 -4.31e-01  0.29
#  0                               $Oh_{ink}$  0.07 -4.46e-01  0.83
#  1                               $Oh_{sup}$  0.00  4.09e-02  0.32
#  2                       $Oh_{ink}Oh_{sup}$  0.01 -5.40e-02  0.52
#  3                      $Oh_{ink}/Oh_{sup}$  0.03 -1.09e-01  0.33
#  0                               $Re_{ink}$  0.01  8.71e-02  0.60
#  1                               $Re_{sup}$  0.00 -1.98e-02  0.33
#  2                       $Re_{ink}Re_{sup}$  0.00  2.80e-03  0.40
#  3                      $Re_{ink}/Re_{sup}$  0.01  4.95e-02  0.37
#  0                               $Bm_{ink}$  0.00 -1.70e-01  0.19
#  1                               $Bm_{sup}$  0.03  1.59e-01  0.60
#  2                       $Bm_{ink}Bm_{sup}$  0.03  1.62e-01  0.79
#  3                      $Bm_{ink}/Bm_{sup}$  0.03 -1.38e-01  0.42
#  0                             $\eta_{ink}$  0.04 -2.84e-01  0.36
#  1                             $\eta_{sup}$  0.00  4.12e-02  0.36
#  2                   $\eta_{ink}\eta_{sup}$  0.00 -7.85e-03  0.39
#  3                  $\eta_{ink}/\eta_{sup}$  0.03 -1.10e-01  0.32
#
#    spearman coeff spearman p
#  0           0.02    8.1e-01
#  1          -0.26    1.5e-04
#  2           0.13    7.3e-02
#  3          -0.05    4.7e-01
#  4          -0.27    1.0e-04
#  0           0.19    7.3e-03
#  1          -0.20    4.2e-03
#  2          -0.09    1.8e-01
#  3           0.21    2.2e-03
#  0          -0.28    4.0e-05
#  1           0.11    1.3e-01
#  2          -0.00    9.9e-01
#  3          -0.21    2.3e-03
#  0          -0.13    5.9e-02
#  1           0.13    7.4e-02
#  2           0.02    7.6e-01
#  3          -0.40    2.6e-09
#  0          -0.21    3.3e-03
#  1           0.08    2.4e-01
#  2           0.04    5.5e-01
#  3          -0.14    4.4e-02
#  0           0.04    6.0e-01
#  1          -0.03    6.4e-01
#  2          -0.04    6.2e-01
#  3           0.08    2.9e-01
#  0          -0.04    6.1e-01
#  1           0.16    2.7e-02
#  2           0.20    4.0e-03
#  3          -0.09    1.8e-01
#  0          -0.09    2.1e-01
#  1           0.06    3.8e-01
#  2           0.02    7.9e-01
#  3          -0.14    4.2e-02  ,
#                   variables $r^2$     b     c spearman coeff spearman p
#  0               $Re_{ink}$  0.03 -0.12  0.13          -0.17    8.2e-02
#  1               $Re_{sup}$  0.08  0.21  1.02           0.24    1.4e-02
#  2       $Re_{ink}Re_{sup}$  0.00  0.03  0.61           0.00    9.6e-01
#  3      $Re_{ink}/Re_{sup}$  0.14 -0.23  0.49          -0.37    1.4e-04
#  0               $Bm_{ink}$  0.07 -0.25  0.10          -0.12    2.1e-01
#  1               $Bm_{sup}$  0.01  0.50  1.02           0.01    9.2e-01
#  2       $Bm_{ink}Bm_{sup}$  0.06 -0.23 -0.15          -0.07    4.8e-01
#  3      $Bm_{ink}/Bm_{sup}$  0.07 -0.26  0.39          -0.24    1.5e-02
#  0             $\eta_{ink}$  0.00 -0.02  0.45           0.00    9.8e-01
#  1             $\eta_{sup}$  0.03 -0.20  0.56          -0.17    8.6e-02
#  2   $\eta_{ink}\eta_{sup}$  0.02 -0.10  0.52          -0.09    3.6e-01
#  3  $\eta_{ink}/\eta_{sup}$  0.01  0.10  0.47           0.15    1.4e-01]
