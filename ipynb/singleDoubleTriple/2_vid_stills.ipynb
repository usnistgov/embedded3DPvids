# %% [markdown]
# # Making stills of singleDoubleTriple lines

# %% [markdown]
# ## Initialization

# %%
# %load_ext autoreload
# %autoreload 2
LOGGERDEFINED = False

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
module_path = os.path.abspath(os.path.join('..'))
sys.path.append(module_path)
sys.path.append(os.path.dirname(module_path))
from py.tools.config import cfg
import py.tools.logs as logs
import py.vid.v_tools as vt
import py.progDim.prog_dim as pg
from py.im.imshow import imshow
import py.file_handling as fh
LOGGERDEFINED = logs.openLog('vidAnalysis.ipynb', LOGGERDEFINED, level='DEBUG', exportLog=False)

# %%
fh.openExplorer(folder)

# %% [markdown]
# ### get programmed dimension

# %%
pg.exportAllDimsRecursive(os.path.join(cfg.path.server, r'singleDoubleTriple\SO_S20-0.5\I_SO6-S20-0.5_S_4.00\I_SO6-S20-0.5_S_4.00_230215\disturbXS2_1_+y_0.625'), overwrite=True)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\lmf1\Miniconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\lmf1\AppData\Local\Temp\1\ipykernel_17512\3281058532.py", line 1, in <module>
#     pg.exportAllDimsRecursive(os.path.join(cfg.path.server, r'singleDoubleTriple\SO_S20-0.5\I_SO6-S20-0.5_S_4.00\I_SO6-S20-0.5_S_4.00_230215\disturbXS2_1_+y_0.625'), overwrite=True)
#   File "C:\Users\lmf1\Documents\GitHub\embedded3DPvids\py\progDim\prog_dim.py", line 90, in exportAllDimsRecursive
#     return fl.run()
#   File "C:\Users\lmf1\Documents\GitHub\embedded3DPvids\py\file_handling.py", line 1250, in run
#     self.runFolder(folder)
#   File "C:\Users\lmf1\Documents\GitHub\embedded3DPvids\py\file_handling.py", line 1239, in runFolder
#     raise e
# ...

# %%
pgd = pg.getProgDims(os.path.join(cfg.path.server, r'singleDoubleTriple\SO_S20-0.5\I_SO6-S20-0.5_S_4.00\I_SO6-S20-0.5_S_4.00_230215\disturbXS2_1_+y_0.625'))
pgd.getProgDims(diag=True)
# Out:
# KeyboardInterrupt

# %% [markdown]
# ## make stills

# %%
folder = os.path.join(cfg.path.server, r'singleDoubleTriple\SO_S20-0.5\I_SO6-S20-0.5_S_4.00\I_SO6-S20-0.5_S_4.00_230215')
errorList = vt.setManualStillTime(folder, 0.55, canMatch=['Horiz3_1', 'Horiz3_2', 'Vert2_2', 'Vert2_1'])
errorList
# Out:
# INFO: Exported //cfs2e.nist.gov/642/internal/3D Printing Lab/Shopbot/videos\singleDoubleTriple\SO_S20-0.5\I_SO6-S20-0.5_S_4.00\I_SO6-S20-0.5_S_4.00_230215\disturbHoriz3_1_0.500\disturbHoriz3_1_0.500_vidStats_I_SO6-S20-0.5_S_4.00_230215_165954_2.csv
# INFO: Exported //cfs2e.nist.gov/642/internal/3D Printing Lab/Shopbot/videos\singleDoubleTriple\SO_S20-0.5\I_SO6-S20-0.5_S_4.00\I_SO6-S20-0.5_S_4.00_230215\disturbHoriz3_1_0.500\disturbHoriz3_1_0.500_vstill_HOh1_l0w1p1_I_SO6-S20-0.5_S_4.00_230215_165954_2.png
# INFO: Exported //cfs2e.nist.gov/642/internal/3D Printing Lab/Shopbot/videos\singleDoubleTriple\SO_S20-0.5\I_SO6-S20-0.5_S_4.00\I_SO6-S20-0.5_S_4.00_230215\disturbHoriz3_1_0.500\disturbHoriz3_1_0.500_vstill_HOh1_l0w1p2_I_SO6-S20-0.5_S_4.00_230215_165954_2.png
# ...

# %%
errorList3 = vt.exportStillsRecursive(os.path.join(cfg.path.server, r'singleDoubleTriple\SO_S20-0.5\I_SO6-S20-0.5_S_4.00\I_SO6-S20-0.5_S_4.00_230215\disturbHoriz3_3_0.625')
                                      , overwrite=False, overwriteDims=False, canMatch=['Vert', 'Horiz'])

# %%
errorList3
# Out:
# []
