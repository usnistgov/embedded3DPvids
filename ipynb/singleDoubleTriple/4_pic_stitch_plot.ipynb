# %% [markdown]
# # Plotting data from videos
# Leanne Friedrich 5/22/21

# %% [markdown]
# ## initialization

# %%
# %load_ext autoreload
# %autoreload 2
LOGGERDEFINED = False
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
sys.path.append("../")
sys.path.append("../../")
import py.file_handling as fh
from py.tools.config import cfg
import py.tools.logs as logs
from py.pic_plots_SDT import *
import pandas as pd
LOGGERDEFINED = logs.openLog('pic_stitch_plot.ipynb', LOGGERDEFINED, level='DEBUG', exportLog=False)
IMFOLDER = os.path.join(cfg.path.fig, 'singleDoubleTriple', 'images')

# %% [markdown]
# ## plot images

# %% [markdown]
# #### Silicone oil LapRD

# %%
mp2 = multiPlotsSDT(os.path.join(cfg.path.server,'singleDoubleTriple', 'SO'), IMFOLDER)
# Out:
# ['SO9', 'SO10', 'SO11']

# %%
mp2.keyPlots(overwrite=True)
# Out:
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\HIx1\SO\l2wo1_l2do1_SO_xvar_ink.var_yvar_sup.var_spacing_0.875
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\HIx1\SO\l2w_l2d_SO_xvar_ink.var_yvar_sup.var_spacing_0.875
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\HIx1\SO\l2wo1_l2do1_SO_xvar_self.spacing_yvar_sup.var_ink_SO11_I_SO11
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\HIx1\SO\l2w_l2d_SO_xvar_self.spacing_yvar_sup.var_ink_SO11_I_SO11
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\HOx1\SO\l2wo1_l2do1_SO_xvar_ink.var_yvar_sup.var_spacing_0.875
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\HOx1\SO\l2w_l2d_SO_xvar_ink.var_yvar_sup.var_spacing_0.875
# ...

# %%
[mp2.plot(f'HOx{i+1}', spacing=0.875, export=True, showFig=True, overwrite=True, removeBackground=False) for i in range(3)]
# Out:
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\HOx1\SO\l2wo1_l2do1_SO_xvar_ink.var_yvar_sup.var_spacing_0.875
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\HOx1\SO\l2w_l2d_SO_xvar_ink.var_yvar_sup.var_spacing_0.875
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\HOx2\SO\l2w1o1_l2w2o1_l2do1_SO_xvar_ink.var_yvar_sup.var_spacing_0.875
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\HOx2\SO\l2w1_l2w2_l2d_SO_xvar_ink.var_yvar_sup.var_spacing_0.875
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\HOx3\SO\l2w1o1_l2w2o1_l2w3o1_SO_xvar_ink.var_yvar_sup.var_spacing_0.875
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\HOx3\SO\l2w1_l2w2_l2w3_SO_xvar_ink.var_yvar_sup.var_spacing_0.875
# [None, None, None]

# %%
[mp2.plot('V1', ink=mp2.inkList[i], overwrite=True, export=True, showFig=True) for i in range(3)]
# Out:
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\V1\SO\l2wo1_l2do1_SO_xvar_self.spacing_yvar_sup.var_ink_SO9_I_SO9
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\V1\SO\l2w_l2d_SO_xvar_self.spacing_yvar_sup.var_ink_SO9_I_SO9
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\V1\SO\l2wo1_l2do1_SO_xvar_self.spacing_yvar_sup.var_ink_SO10_I_SO10
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\V1\SO\l2w_l2d_SO_xvar_self.spacing_yvar_sup.var_ink_SO10_I_SO10
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\V1\SO\l2wo1_l2do1_SO_xvar_self.spacing_yvar_sup.var_ink_SO11_I_SO11
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\singleDoubleTriple\images\V1\SO\l2w_l2d_SO_xvar_self.spacing_yvar_sup.var_ink_SO11_I_SO11
# [None, None, None]
