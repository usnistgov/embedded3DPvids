# %% [markdown]
# # Analyzing images of SDT under lines

# %% [markdown]
# Leanne Friedrich 4/27/23

# %% [markdown]
# ## Initialization

# %%
# %load_ext autoreload
# %autoreload 2
LOGGERDEFINED = False

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
module_path = os.path.abspath(os.path.join('..'))
sys.path.append(module_path)
sys.path.append(os.path.dirname(module_path))
from py.tools.config import cfg
import py.tools.logs as logs
import py.vid.v_tools as vt
import py.metrics.m_SDT as me
from py.im.imshow import imshow
import py.file.file_handling as fh
import py.vid.noz_detect as nt
import pandas as pd
from py.full_sequence import SDTWorkflow, fullSequencer
LOGGERDEFINED = logs.openLog('still_measure_under.ipynb', LOGGERDEFINED, level='DEBUG', exportLog=False)

# %% [markdown]
# # make measurements and summaries and summary table

# %%
fstr = r'SDT'
folder = os.path.join(cfg.path.server, fstr)
sv = me.summarizerUnderSDT(folder, overwriteMeasure=False, overwriteSummary=False, folderFile=cfg.path.folderList)

# %%
sv.run()
sv.export()
# Out:
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\SDT\summaries\UnderSDTSummaries.csv
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\SDT\summaries\UnderSDTSummaries_gname.csv
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\SDT\summaries\UnderSDTFailures.csv

# %%
sv.folderErrorList
# Out:
# []

# %%
fh.openExplorer(sv.folderErrorList[5]['folder'])

# %%
for f in sv.folderErrorList:
    sw = SDTWorkflow(f['folder'])
    sw.run()

# %% [markdown]
# # plot single folders

# %%
fstr = r'SDT\PDMSS\I_PDMSS7.5_S_3.00\I_PDMSS7.5_S_3.00_230920\disturbUnder_2_1.000'
folder = os.path.join(cfg.path.server, fstr)
fv = me.folderUnderSDT(folder, overwriteMeasure=False, overwriteSummary=False, diag=0, overrideSegment=False)
fv.measureFolder();
fv.summarize();

# %%
fv.failures.loc[1]['file']

# %%
fv.plotValue('wn', fn=os.path.join(cfg.path.fig, r'SDT\images\plots', f'disturb_rupture_w3.png'))
# Out:
# INFO: Exported C:/Users/lmf1/OneDriveNIST/NIST/data/shopbot/results\SDT\images\plots\disturb_rupture_w3.png and .svg
